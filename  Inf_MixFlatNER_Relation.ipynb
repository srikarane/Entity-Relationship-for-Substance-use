# %%
#import evaluate

# %%
import json
import pandas as pd
from transformers import BertTokenizerFast, BertModel, AdamW, get_linear_schedule_with_warmup, DataCollatorForTokenClassification
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import classification_report
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn.utils.rnn import pad_sequence
from tqdm import tqdm, trange
import itertools

# %%
#metric=evaluate.load("seqeval")
device= torch.device("cuda" if torch.cuda.is_available() else "cpu")
bert_model_name='emilyalsentzer/Bio_ClinicalBERT'
tokenizer = BertTokenizerFast.from_pretrained(bert_model_name)
num_freeze_layers=6
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]

# %%
eps=1e-8
learning_rate=7e-5
weight_decay=0.01
num_train_epochs=15
patience=5
batch_size=16
max_len=512

# %%
discarded_enities=['EnvironmentalExposure','SexualHistory','InfectiousDiseases','PhysicalActivity','Residence','LivingSituation','MaritalStatus','Occupation']
discarded_roles=['LivingStatus','Other','MedicalCondition','Extent','History']
save_model_path='/content/drive/MyDrive/PHD_assessment_gmu/models/'
project_directory='/content/drive/MyDrive/PHD_assessment_gmu/'
raw_dataset_path=project_directory+'data/'+'SocialHistoryMTSamples.json'
train_dataset_path=project_directory+'data/'+'train_dataset.pth'
test_dataset_path=project_directory+'data/'+'test_dataset.pth'

# %%
id_label_status={0:'O',1:'B-Status',2:'I-Status'}
id_label_method={0:'O',1:'B-Method',2:'I-Method'}
id_label_role={0:'O',1:'B-Type',2:'I-Type',3:'B-Amount',4:'I-Amount',5:'B-Temporal',6:'I-Temporal',7:'B-Frequency',8:'I-Frequency',9:'B-QuitHistory',10:'I-QuitHistory',11:'B-ExposureHistory',12:'I-ExposureHistory',13:'B-Location',14:'I-Location'}
id_label_event={0:'No Relation',1:'Relation'}

label_id_status = {v: k for k, v in id_label_status.items()}
label_id_method = {v: k for k, v in id_label_method.items()}
label_id_role = {v: k for k, v in id_label_role.items()}
label_id_ent = {'B-Alcohol':1,
 'B-Drug':3,
 'B-Family':5,
 'B-Tobacco':7,
 'I-Alcohol':2,
 'I-Drug':4,
 'I-Family':6,
 'I-Tobacco':8,
 'O':0}
id_label_ent = {v: k for k, v in label_id_ent.items()}
label_id_event = {v: k for k, v in id_label_event.items()}

# %% [markdown]
# ### Label generation

# %%
class GenerateLabel:

  @staticmethod
  def generate_enity_labels(entity_list, token_len, token_offsets):
    # Initialize a list to store the BIO labels for each token

    entity_labels = [label_id_ent['O']] * token_len
    for entity in entity_list:
        category = entity['entity_category']
        if category not in discarded_enities:
          entity_start_pos = int(entity['entity_strt_pos'])
          entity_end_pos = int(entity['entity_end_pos'])-1

          # Find tokens that correspond to the entity's position
          entity_start_token = None
          entity_end_token = None

          for i, (start_offset, end_offset) in enumerate(token_offsets):
              if entity_start_token is None and start_offset >= entity_start_pos:
                  entity_start_token = i
              if end_offset > entity_end_pos:
                  entity_end_token = i
                  break

          # Assign BIO labels to the tokens
          if entity_start_token is not None:
            entity_labels[entity_start_token] = label_id_ent['B-' + category]
            if entity_end_token is not None:
              entity_labels[entity_start_token + 1:entity_end_token + 1] = [label_id_ent['I-' + category]] * (entity_end_token - entity_start_token)

    return entity_labels

  @staticmethod
  def generate_role_labels(role_list, token_len, token_offsets):
    # Initialize a list to store the BIO labels for each token
    role_labels = [label_id_role['O']] * token_len
    status_labels = [label_id_status['O']] * token_len
    method_labels = [label_id_method['O']] * token_len

    for role in role_list:
        category = role['entity_category']
        entity_start_pos = int(role['entity_strt_pos'])
        entity_end_pos = int(role['entity_end_pos'])-1
        if category in discarded_roles:
          continue
        # Find tokens that correspond to the entity's position
        entity_start_token = None
        entity_end_token = None

        for i, (start_offset, end_offset) in enumerate(token_offsets):
            if entity_start_token is None and start_offset >= entity_start_pos:
                entity_start_token = i
            if end_offset > entity_end_pos:
                entity_end_token = i
                break

        # Assign BIO labels to the tokens
        if category == 'Status':
          if entity_start_token is not None:
            status_labels[entity_start_token] = label_id_status['B-' + category]
            if entity_end_token is not None:
                status_labels[entity_start_token + 1:entity_end_token + 1] = [label_id_status['I-' + category]] * (entity_end_token - entity_start_token)

        elif category == 'Method':
          if entity_start_token is not None:
            method_labels[entity_start_token] = label_id_method['B-' + category]
            if entity_end_token is not None:
                method_labels[entity_start_token + 1:entity_end_token + 1] = [label_id_method['I-' + category]] * (entity_end_token - entity_start_token)

        else:
          if entity_start_token is not None:
            role_labels[entity_start_token] = label_id_role['B-' + category]
            if entity_end_token is not None:
                role_labels[entity_start_token + 1:entity_end_token + 1] = [label_id_role['I-' + category]] * (entity_end_token - entity_start_token)


    return role_labels, status_labels, method_labels

  @staticmethod
  def generate_relation_labels( token_offsets, data):
    entity_token_indices = {}
    role_token_indices = {}

    entity_list = data.get('entity_list', [])
    role_list = data.get('role_list', [])
    events_list = data.get('events_list', [])

    # Create a dictionary to map entity IDs to their token indices
    for entity in entity_list:
        entity_id = entity['entity_id']
        entity_start_pos = int(entity['entity_strt_pos'])
        entity_end_pos = int(entity['entity_end_pos'])-1
        if entity['entity_category'] in discarded_enities:
          continue
        # Find tokens that correspond to the entity's position
        entity_start_token = None
        entity_end_token = None

        for i, (start_offset, end_offset) in enumerate(token_offsets):
            if entity_start_token is None and start_offset >= entity_start_pos:
                entity_start_token = i
            if end_offset > entity_end_pos:
                entity_end_token = i
                break

        if entity_start_token is not None:
            entity_token_indices[entity_id] = (entity_start_token, entity_end_token,entity['entity_category'])

    # Create a dictionary to map event-related role IDs to their token indices
    for event in events_list:
        entity_id = event['entity_id']
        related_roles = event['Related_roles']

        entity_indices = entity_token_indices.get(entity_id, None)

        if entity_indices:
            role_indices = []

            for role_id in related_roles:
                role = next((role for role in role_list if role['role_id'] == role_id), None)

                if role:
                    role_start_pos = int(role['entity_strt_pos'])
                    role_end_pos = int(role['entity_end_pos'])-1
                    if role['entity_category'] in discarded_roles:
                      continue

                    role_start_token = None
                    role_end_token = None

                    for i, (start_offset, end_offset) in enumerate(token_offsets):
                        if role_start_token is None and start_offset >= role_start_pos:
                            role_start_token = i
                        if end_offset > role_end_pos:
                            role_end_token = i
                            break

                    if role_start_token is not None:
                        role_indices.append((role_start_token, role_end_token,role['entity_category']))

            if role_indices:
                role_token_indices[(entity_indices[0],entity_indices[1],entity_indices[2])] = role_indices

    return role_token_indices

# %% [markdown]
# ### Dataset Class

# %%
class ERDataset(Dataset):
  def __init__(self, data, tokenizer, max_len):
    self.data = data
    self.tokenizer = tokenizer
    self.max_len = max_len
  def __len__(self):
    return len(self.data)
  def __getitem__(self, idx):
    item=self.data[idx]
    text = item['text']
    inputs = self.tokenizer(text,max_length=max_len,truncation=True,return_offsets_mapping=True)
    tokens_len=len(inputs['input_ids'])
    offset_mapping_list=inputs['offset_mapping']
    entity_labels=GenerateLabel.generate_enity_labels(item['entity_list'],tokens_len,offset_mapping_list)
    role_labels, status_labels, method_labels=GenerateLabel.generate_role_labels(item['role_list'],tokens_len,offset_mapping_list)
    relation_labels=GenerateLabel.generate_relation_labels(offset_mapping_list,item)
    return {
      'input_ids':inputs['input_ids'],
      'attention_mask':inputs['attention_mask'],
      'entity_labels':entity_labels,
      'role_labels':role_labels,
      'status_labels':status_labels,
      'method_labels':method_labels,
      'relation_labels':relation_labels,
      'text':text,
      'file_name':item['file_name'],
      'offset_mapping':offset_mapping_list,
      'tokens':inputs.tokens()
    }

# %% [markdown]
# ### NER classifier

# %%
class EntityBertModel(nn.Module):
  def __init__(self, model_name, num_freeze_layers,num_status_labels,num_method_labels,num_role_labels,num_entity_labels, dropout=0.1):
    super(EntityBertModel, self).__init__()
    self.bertmodel = BertModel.from_pretrained(model_name)
    for layer in self.bertmodel.encoder.layer[:num_freeze_layers]:
      for param in layer.parameters():
          param.requires_grad = False
    self.dropout = nn.Dropout(dropout)
    self.status_classifier = nn.Linear(self.bertmodel.config.hidden_size, num_status_labels)
    self.method_classifier = nn.Linear(self.bertmodel.config.hidden_size, num_method_labels)
    self.role_classifier = nn.Linear(self.bertmodel.config.hidden_size, num_role_labels)
    self.entity_classifier = nn.Linear(self.bertmodel.config.hidden_size, num_entity_labels)
  def forward(self, input_ids, attention_mask):
    bert_output = self.bertmodel(input_ids=input_ids, attention_mask=attention_mask)
    sequence_output = self.dropout(bert_output[0])
    status_logits = self.status_classifier(sequence_output)
    method_logits = self.method_classifier(sequence_output)
    role_logits = self.role_classifier(sequence_output)
    entity_logits = self.entity_classifier(sequence_output)

    return status_logits, method_logits, role_logits, entity_logits

# %% [markdown]
# ## Data Loading

# %%
import json
prediction_data={}
dt_set='tst'
for label_type in ['entity','role_labels','status_labels','method_labels']:
  predpath='/content/drive/MyDrive/PHD_assessment_gmu/data/'+label_type+'_predictions_'+dt_set+'.json'
  with open(predpath, 'r', encoding='utf-8') as file:
    prediction_data[label_type]=json.load( file)

# %%
prediction_data['entity']
# Out:
# {'124_Consult-HistoryandPhy.-Consult_ERReport-OB_GYN_8': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['denies', 0, 0],
#   ['tobacco', 7, 7],
#   [',', 0, 0],
#   ['ethanol', 1, 1],
#   [',', 0, 0],
#   ['or', 0, 0],
#   ['drug', 3, 3],
#   ['use', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['currently', 0, 0],
#   ['separated', 0, 0],
#   ['from', 0, 0],
#   ['her', 0, 0],
#   ['partner', 0, 0],
#   ['who', 0, 0],
#   ['is', 0, 0],
#   ['the', 0, 0],
#   ['father', 0, 5],
#   ['of', 0, 0],
#   ['her', 0, 0],
#   ['21', 0, 0],
#   ['-', 0, 0],
#   ['month', 0, 0],
#   ['-', 0, 0],
#   ['old', 0, 5],
#   ['daughter', 5, 6],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['currently', 0, 0],
#   ['lives', 0, 0],
#   ['with', 0, 0],
#   ['her', 0, 0],
#   ['parents', 0, 0],
#   ['in', 0, 0],
#   ['green', 0, 0],
#   ['##ville', 0, 0],
#   ['.', 0, 0],
#   ['however', 0, 0],
#   [',', 0, 0],
#   ['she', 0, 0],
#   ['was', 0, 0],
#   ['visiting', 0, 0],
#   ['the', 0, 0],
#   ['est', 0, 0],
#   ['##ranged', 0, 0],
#   ['boyfriend', 0, 0],
#   ['in', 0, 0],
#   ['w', 0, 0],
#   ['##il', 0, 0],
#   ['##kes', 0, 0],
#   ['##boro', 0, 0],
#   [',', 0, 0],
#   ['this', 0, 0],
#   ['week', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '15_Consult-HistoryandPhy.-AllergyEvaluationConsult_9': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['denies', 0, 0],
#   ['tobacco', 7, 7],
#   ['or', 0, 0],
#   ['alcohol', 1, 1],
#   ['use', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '184_Consult-HistoryandPhy.-GastricBypassDiscussion-3_7': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['is', 0, 0],
#   ['a', 0, 0],
#   ['life', 0, 0],
#   ['long', 0, 0],
#   ['non', 0, 0],
#   ['##smo', 7, 7],
#   ['##ker', 8, 8],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['only', 0, 0],
#   ['drinks', 1, 1],
#   ['socially', 0, 2],
#   ['one', 0, 0],
#   ['to', 0, 0],
#   ['two', 0, 0],
#   ['drinks', 0, 2],
#   ['a', 0, 0],
#   ['month', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['employed', 0, 0],
#   ['as', 0, 0],
#   ['a', 0, 0],
#   ['manager', 0, 0],
#   ['at', 0, 0],
#   ['the', 0, 0],
#   ['new', 0, 0],
#   ['yo', 0, 0],
#   ['##rk', 0, 0],
#   ['department', 0, 0],
#   ['of', 0, 0],
#   ['taxation', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['married', 0, 0],
#   ['with', 0, 0],
#   ['four', 5, 5],
#   ['children', 6, 6],
#   ['.', 6, 0],
#   ['[SEP]', 0, 0]],
#  '233_Consult-HistoryandPhy.-GenMedConsult-52_7': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['history', 0, 0],
#   ['of', 0, 0],
#   ['alcohol', 1, 1],
#   ['use', 0, 0],
#   ['in', 0, 0],
#   ['the', 0, 0],
#   ['past', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['is', 0, 0],
#   ['basically', 0, 0],
#   ['requesting', 0, 0],
#   ['for', 0, 0],
#   ['more', 0, 0],
#   ['and', 0, 0],
#   ['more', 0, 0],
#   ['pain', 0, 0],
#   ['medications', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['states', 0, 0],
#   ['that', 0, 0],
#   ['he', 0, 0],
#   ['likes', 0, 0],
#   ['di', 0, 0],
#   ['##lau', 0, 0],
#   ['##di', 0, 0],
#   ['##d', 0, 0],
#   ['and', 0, 0],
#   ['would', 0, 0],
#   ['like', 0, 0],
#   ['to', 0, 0],
#   ['get', 0, 0],
#   ['the', 0, 0],
#   ['m', 0, 0],
#   ['##or', 0, 0],
#   ['##phine', 0, 0],
#   ['changed', 0, 0],
#   ['to', 0, 0],
#   ['di', 0, 0],
#   ['##lau', 0, 0],
#   ['##di', 0, 0],
#   ['##d', 0, 0],
#   ['.', 0, 0],
#   ['his', 0, 0],
#   ['pain', 0, 0],
#   ['is', 0, 0],
#   ['to', 0, 0],
#   ['##ler', 0, 0],
#   ['##able', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '236_Consult-HistoryandPhy.-GenMedConsult-6_7': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['a', 0, 0],
#   ['non', 0, 0],
#   ['##smo', 7, 7],
#   ['##ker', 8, 8],
#   ['and', 0, 0],
#   ['non', 0, 0],
#   ['##dr', 1, 1],
#   ['##ink', 2, 2],
#   ['##er', 2, 2],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['has', 0, 0],
#   ['been', 0, 0],
#   ['widowed', 0, 0],
#   ['for', 0, 0],
#   ['18', 0, 0],
#   ['years', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['lives', 0, 0],
#   ['alone', 0, 0],
#   ['at', 0, 0],
#   ['home', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['retired', 0, 0],
#   ['from', 0, 0],
#   ['running', 0, 0],
#   ['a', 0, 0],
#   ['restaurant', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '240_Consult-HistoryandPhy.-GenMedH&P-1_10': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['no', 0, 0],
#   ['tobacco', 7, 7],
#   [',', 0, 0],
#   ['alcohol', 1, 1],
#   [',', 0, 0],
#   ['or', 0, 0],
#   ['drug', 3, 3],
#   ['abuse', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  "270_Consult-HistoryandPhy.-Huntington'sDisease-Consult_11": [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['lives', 0, 0],
#   ['with', 0, 0],
#   ['her', 0, 0],
#   ['husband', 5, 5],
#   ['of', 0, 0],
#   ['48', 0, 0],
#   ['years', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['used', 0, 0],
#   ['to', 0, 0],
#   ['be', 0, 0],
#   ['employed', 0, 0],
#   ['as', 0, 0],
#   ['a', 0, 0],
#   ['registered', 0, 0],
#   ['nurse', 0, 0],
#   ['.', 0, 0],
#   ['her', 0, 0],
#   ['husband', 0, 5],
#   ['states', 0, 0],
#   ['that', 0, 0],
#   ['she', 0, 0],
#   ['does', 0, 0],
#   ['have', 0, 0],
#   ['a', 0, 0],
#   ['pattern', 0, 0],
#   ['of', 0, 0],
#   ['self', 0, 0],
#   ['-', 0, 0],
#   ['pre', 0, 0],
#   ['##s', 0, 0],
#   ['##cribing', 0, 0],
#   ['for', 0, 0],
#   ['minor', 0, 0],
#   ['illness', 0, 0],
#   [',', 0, 0],
#   ['but', 0, 0],
#   ['does', 0, 0],
#   ['not', 0, 0],
#   ['think', 0, 0],
#   ['that', 0, 0],
#   ['she', 0, 0],
#   ['has', 0, 0],
#   ['ever', 0, 0],
#   ['taken', 0, 0],
#   ['muscle', 0, 0],
#   ['relax', 0, 0],
#   ['##ants', 0, 0],
#   ['or', 0, 0],
#   ['se', 0, 0],
#   ['##da', 0, 0],
#   ['##tive', 0, 0],
#   ['medications', 0, 0],
#   ['without', 0, 0],
#   ['prescription', 0, 0],
#   ['##s', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['rarely', 0, 0],
#   ['drinks', 1, 1],
#   ['socially', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['denies', 0, 0],
#   ['any', 0, 0],
#   ['ill', 0, 0],
#   ['##icit', 0, 0],
#   ['substance', 3, 3],
#   ['usage', 0, 4],
#   ['.', 0, 0],
#   ['her', 0, 0],
#   ['husband', 0, 5],
#   ['reportedly', 0, 0],
#   ['gives', 0, 0],
#   ['her', 0, 0],
#   ['medication', 0, 0],
#   ['daily', 0, 0],
#   ['.', 0, 0],
#   ['has', 0, 0],
#   ['been', 0, 0],
#   ['pro', 0, 0],
#   ['##active', 0, 0],
#   ['in', 0, 0],
#   ['terms', 0, 0],
#   ['of', 0, 0],
#   ['seeking', 0, 0],
#   ['mental', 0, 0],
#   ['health', 0, 0],
#   ['care', 0, 0],
#   ['and', 0, 0],
#   ['medical', 0, 0],
#   ['care', 0, 0],
#   ['.', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['and', 0, 0],
#   ['husband', 0, 5],
#   ['report', 0, 0],
#   ['that', 0, 0],
#   ['from', 0, 0],
#   ['march', 0, 0],
#   ['2009', 0, 0],
#   [',', 0, 0],
#   ['she', 0, 0],
#   ['has', 0, 0],
#   ['been', 0, 0],
#   ['relatively', 0, 0],
#   ['independent', 0, 0],
#   [',', 0, 0],
#   ['more', 0, 0],
#   ['socially', 0, 0],
#   ['active', 0, 0],
#   ['.', 0, 0],
#   ['mental', 0, 0],
#   ['status', 0, 0],
#   ['exam', 0, 0],
#   [':', 0, 0],
#   ['this', 0, 0],
#   ['is', 0, 0],
#   ['an', 0, 0],
#   ['elderly', 0, 0],
#   ['woman', 0, 0],
#   ['appearing', 0, 0],
#   ['stated', 0, 0],
#   ['age', 0, 0],
#   ['.', 0, 0],
#   ['alert', 0, 0],
#   ['and', 0, 0],
#   ['oriented', 0, 0],
#   ['x', 0, 0],
#   ['##4', 0, 0],
#   ['with', 0, 0],
#   ['poor', 0, 0],
#   ['eye', 0, 0],
#   ['contact', 0, 0],
#   ['.', 0, 0],
#   ['appears', 0, 0],
#   ['depressed', 0, 0],
#   [',', 0, 0],
#   ['has', 0, 0],
#   ['ps', 0, 0],
#   ['##ych', 0, 0],
#   ['##omo', 0, 0],
#   ['##tor', 0, 0],
#   ['re', 0, 0],
#   ['##tar', 0, 0],
#   ['##dation', 0, 0],
#   [',', 0, 0],
#   ['and', 0, 0],
#   ['some', 0, 0],
#   ['mild', 0, 0],
#   ['in', 0, 0],
#   ['##vo', 0, 0],
#   ['##lu', 0, 0],
#   ['##ntary', 0, 0],
#   ['movements', 0, 0],
#   ['around', 0, 0],
#   ['her', 0, 0],
#   ['lips', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['cooperative', 0, 0],
#   ['.', 0, 0],
#   ['her', 0, 0],
#   ['speech', 0, 0],
#   ['is', 0, 0],
#   ['of', 0, 0],
#   ['low', 0, 0],
#   ['volume', 0, 0],
#   ['and', 0, 0],
#   ['slow', 0, 0],
#   ['rate', 0, 0],
#   ['and', 0, 0],
#   ['rhythm', 0, 0],
#   ['.', 0, 0],
#   ['her', 0, 0],
#   ['mood', 0, 0],
#   ['is', 0, 0],
#   ['sad', 0, 0],
#   ['.', 0, 0],
#   ['her', 0, 0],
#   ['affect', 0, 0],
#   ['is', 0, 0],
#   ['con', 0, 0],
#   ['##st', 0, 0],
#   ['##ricted', 0, 0],
#   ['.', 0, 0],
#   ['her', 0, 0],
#   ['thought', 0, 0],
#   ['process', 0, 0],
#   ['is', 0, 0],
#   ['logical', 0, 0],
#   ['and', 0, 0],
#   ['goal', 0, 0],
#   ['-', 0, 0],
#   ['directed', 0, 0],
#   ['.', 0, 0],
#   ['her', 0, 0],
#   ['thought', 0, 0],
#   ['content', 0, 0],
#   ['is', 0, 0],
#   ['negative', 0, 0],
#   ['for', 0, 0],
#   ['current', 0, 0],
#   ['su', 0, 0],
#   ['##icidal', 0, 0],
#   ['idea', 0, 0],
#   ['##tion', 0, 0],
#   ['.', 0, 0],
#   ['no', 0, 0],
#   ['ho', 0, 0],
#   ['##mic', 0, 0],
#   ['##idal', 0, 0],
#   ['idea', 0, 0],
#   ['##tion', 0, 0],
#   ['.', 0, 0],
#   ['no', 0, 0],
#   ['audit', 0, 0],
#   ['##ory', 0, 0],
#   ['or', 0, 0],
#   ['visual', 0, 0],
#   ['hall', 0, 0],
#   ['##uc', 0, 0],
#   ['##ination', 0, 0],
#   ['##s', 0, 0],
#   ['.', 0, 0],
#   ['no', 0, 0],
#   ['command', 0, 0],
#   ['audit', 0, 0],
#   ['##ory', 0, 0],
#   ['hall', 0, 0],
#   ['##uc', 0, 0],
#   ['##ination', 0, 0],
#   ['##s', 0, 0],
#   ['.', 0, 0],
#   ['no', 0, 0],
#   ['para', 0, 0],
#   ['##no', 0, 0],
#   ['##ia', 0, 0],
#   ['.', 0, 0],
#   ['insight', 0, 0],
#   ['and', 0, 0],
#   ['judgment', 0, 0],
#   ['are', 0, 0],
#   ['fair', 0, 0],
#   ['and', 0, 0],
#   ['intact', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '28_Consult-HistoryandPhy.-AttemptedSuicide-Consult_10': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['lives', 0, 0],
#   ['with', 0, 0],
#   ['his', 0, 0],
#   ['girlfriend', 0, 0],
#   ['on', 0, 0],
#   ['an', 0, 0],
#   ['on', 0, 0],
#   ['-', 0, 0],
#   ['and', 0, 0],
#   ['-', 0, 0],
#   ['off', 0, 0],
#   ['basis', 0, 0],
#   ['and', 0, 0],
#   ['is', 0, 0],
#   ['unclear', 0, 0],
#   ['if', 0, 0],
#   ['they', 0, 0],
#   ['will', 0, 0],
#   ['be', 0, 0],
#   ['immediately', 0, 0],
#   ['moving', 0, 0],
#   ['back', 0, 0],
#   ['in', 0, 0],
#   ['together', 0, 0],
#   ['.', 0, 0],
#   ['substance', 0, 7],
#   ['abuse', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['was', 0, 0],
#   ['actively', 0, 0],
#   ['to', 0, 0],
#   ['##x', 0, 0],
#   ['screen', 0, 0],
#   ['positive', 0, 0],
#   ['for', 0, 0],
#   ['ben', 3, 3],
#   ['##zo', 4, 4],
#   ['##dia', 4, 4],
#   ['##ze', 4, 4],
#   ['##pine', 4, 4],
#   ['##s', 4, 4],
#   [',', 0, 0],
#   ['cocaine', 3, 3],
#   [',', 0, 0],
#   ['and', 0, 0],
#   ['marijuana', 3, 3],
#   ['.', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['had', 0, 0],
#   ['an', 0, 0],
#   ['in', 0, 0],
#   ['##patient', 0, 0],
#   ['stay', 0, 0],
#   ['in', 0, 0],
#   ['2008', 0, 0],
#   ['at', 0, 0],
#   ['a', 0, 0],
#   ['##b', 0, 0],
#   ['##c', 0, 0],
#   ['lodge', 0, 0],
#   ['for', 0, 0],
#   ['drug', 0, 3],
#   ['abuse', 0, 0],
#   ['treatment', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '304_Consult-HistoryandPhy.-LumbarRadiculopathy-Consult_4': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['divorced', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['does', 0, 0],
#   ['not', 0, 0],
#   ['have', 0, 0],
#   ['support', 0, 0],
#   ['at', 0, 0],
#   ['home', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['denies', 0, 0],
#   ['tobacco', 7, 7],
#   [',', 0, 0],
#   ['alcohol', 1, 1],
#   [',', 0, 0],
#   ['and', 0, 0],
#   ['ill', 0, 0],
#   ['##icit', 0, 0],
#   ['drug', 3, 3],
#   ['use', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '407_Consult-HistoryandPhy.-PediatricRheumatologyConsult_8': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['he', 0, 0],
#   ['lives', 0, 0],
#   ['with', 0, 0],
#   ['mom', 5, 5],
#   [',', 0, 0],
#   ['dad', 5, 5],
#   [',', 0, 6],
#   ['brother', 5, 6],
#   [',', 0, 0],
#   ['sister', 5, 5],
#   [',', 6, 0],
#   ['and', 0, 0],
#   ['everybody', 0, 5],
#   ['is', 0, 0],
#   ['healthy', 0, 0],
#   ['.', 0, 0],
#   ['they', 0, 0],
#   ['live', 0, 0],
#   ['in', 0, 0],
#   ['east', 0, 0],
#   ['##on', 0, 0],
#   ['.', 0, 0],
#   ['they', 0, 0],
#   ['have', 0, 0],
#   ['4', 0, 0],
#   ['dogs', 0, 0],
#   [',', 0, 0],
#   ['3', 0, 0],
#   ['cats', 0, 0],
#   [',', 0, 0],
#   ['3', 0, 0],
#   ['m', 0, 0],
#   ['##ules', 0, 0],
#   ['and', 0, 0],
#   ['no', 0, 0],
#   ['deer', 0, 0],
#   ['.', 0, 0],
#   ['at', 0, 0],
#   ['school', 0, 0],
#   [',', 0, 0],
#   ['he', 0, 0],
#   ['is', 0, 0],
#   ['in', 0, 0],
#   ['second', 0, 0],
#   ['grade', 0, 0],
#   ['and', 0, 0],
#   ['he', 0, 0],
#   ['is', 0, 0],
#   ['doing', 0, 0],
#   ['p', 0, 0],
#   ['##e', 0, 0],
#   ['without', 0, 0],
#   ['any', 0, 0],
#   ['limitation', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '432_Consult-HistoryandPhy.-PsychConsult-Lethargy_11': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['and', 0, 0],
#   ['developmental', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['currently', 0, 0],
#   ['lives', 0, 0],
#   ['with', 0, 0],
#   ['husband', 5, 5],
#   ['of', 0, 0],
#   ['40', 0, 0],
#   ['years', 0, 0],
#   ['in', 0, 0],
#   ['league', 0, 0],
#   ['city', 0, 0],
#   [',', 0, 0],
#   ['has', 0, 0],
#   ['a', 0, 0],
#   ['masters', 0, 0],
#   ['in', 0, 0],
#   ['education', 0, 0],
#   [',', 0, 0],
#   ['is', 0, 0],
#   ['a', 0, 0],
#   ['retired', 0, 0],
#   ['reading', 0, 0],
#   ['specialist', 0, 0],
#   ['which', 0, 0],
#   ['she', 0, 0],
#   ['did', 0, 0],
#   ['it', 0, 0],
#   ['for', 0, 0],
#   ['33', 0, 0],
#   ['years', 0, 0],
#   ['.', 0, 0],
#   ['has', 0, 0],
#   ['one', 5, 0],
#   ['younger', 6, 0],
#   ['brother', 6, 6],
#   [',', 0, 0],
#   ['one', 5, 5],
#   ['daughter', 6, 5],
#   ['.', 0, 0],
#   ['denies', 0, 0],
#   ['use', 0, 0],
#   ['of', 0, 0],
#   ['tobacco', 7, 7],
#   [',', 8, 0],
#   ['alcohol', 1, 1],
#   ['and', 0, 0],
#   ['ill', 0, 0],
#   ['##icit', 0, 0],
#   ['drugs', 3, 3],
#   ['.', 0, 0],
#   ['the', 0, 0],
#   ['child', 0, 0],
#   ['as', 0, 0],
#   ['per', 0, 0],
#   ['daughter', 0, 0],
#   ['was', 0, 0],
#   ['picked', 0, 0],
#   ['on', 0, 0],
#   ['and', 0, 0],
#   ['has', 0, 0],
#   ['a', 0, 0],
#   ['strained', 0, 0],
#   ['relationship', 0, 0],
#   ['with', 0, 0],
#   ['her', 0, 0],
#   ['mother', 0, 5],
#   [',', 0, 0],
#   ['but', 0, 0],
#   ['they', 0, 0],
#   ['still', 0, 0],
#   ['are', 0, 0],
#   ['communicating', 0, 0],
#   ['.', 0, 0],
#   ['mental', 0, 0],
#   ['status', 0, 0],
#   ['examination', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['is', 0, 0],
#   ['a', 0, 0],
#   ['62', 0, 0],
#   ['-', 0, 0],
#   ['year', 0, 0],
#   ['-', 0, 0],
#   ['old', 0, 0],
#   ['white', 0, 0],
#   ['female', 0, 0],
#   [',', 0, 0],
#   ['lying', 0, 0],
#   ['in', 0, 0],
#   ['hospital', 0, 0],
#   ['bed', 0, 0],
#   [',', 0, 0],
#   ['with', 0, 0],
#   ['gown', 0, 0],
#   ['on', 0, 0],
#   [',', 0, 0],
#   ['eyes', 0, 0],
#   ['closed', 0, 0],
#   [',', 0, 0],
#   ['short', 0, 0],
#   ['s', 0, 0],
#   ['##haven', 0, 0],
#   ['hair', 0, 0],
#   [',', 0, 0],
#   ['and', 0, 0],
#   ['golf', 0, 0],
#   ['ball', 0, 0],
#   ['-', 0, 0],
#   ['sized', 0, 0],
#   ['in', 0, 0],
#   ['##dent', 0, 0],
#   ['##ation', 0, 0],
#   ['in', 0, 0],
#   ['the', 0, 0],
#   ['anterior', 0, 0],
#   ['font', 0, 0],
#   ['##ane', 0, 0],
#   ['##lle', 0, 0],
#   ['from', 0, 0],
#   ['c', 0, 0],
#   ['##rani', 0, 0],
#   ['##oto', 0, 0],
#   ['##my', 0, 0],
#   ['.', 0, 0],
#   ['ps', 0, 0],
#   ['##ych', 0, 0],
#   ['##omo', 0, 0],
#   ['##tor', 0, 0],
#   ['re', 0, 0],
#   ['##tar', 0, 0],
#   ['##dation', 0, 0],
#   [',', 0, 0],
#   ['poor', 0, 0],
#   ['eye', 0, 0],
#   ['contact', 0, 0],
#   [',', 0, 0],
#   ['speech', 0, 0],
#   ['low', 0, 0],
#   ['volume', 0, 0],
#   [',', 0, 0],
#   ['slow', 0, 0],
#   ['rate', 0, 0],
#   [',', 0, 0],
#   ['poor', 0, 0],
#   ['fl', 0, 0],
#   ['##ex', 0, 0],
#   ['##ion', 0, 0],
#   [',', 0, 0],
#   ['essentially', 0, 0],
#   ['un', 0, 0],
#   ['##res', 0, 0],
#   ['##po', 0, 0],
#   ['##ns', 0, 0],
#   ['##ive', 0, 0],
#   [',', 0, 0],
#   ['and', 0, 0],
#   ['so', 0, 0],
#   ['##m', 0, 0],
#   ['##no', 0, 0],
#   ['##lent', 0, 0],
#   ['during', 0, 0],
#   ['interview', 0, 0],
#   ['.', 0, 0],
#   ['poor', 0, 0],
#   ['concentration', 0, 0],
#   [',', 0, 0],
#   ['mood', 0, 0],
#   ['unknown', 0, 0],
#   ['(', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['did', 0, 0],
#   ['not', 0, 0],
#   ['respond', 0, 0],
#   ['to', 0, 0],
#   ['questions', 0, 0],
#   [')', 0, 0],
#   [',', 0, 0],
#   ['affect', 0, 0],
#   ['flat', 0, 0],
#   [',', 0, 0],
#   ['thought', 0, 0],
#   ['process', 0, 0],
#   ['logical', 0, 0],
#   ['and', 0, 0],
#   ['goal', 0, 0],
#   ['directed', 0, 0],
#   [',', 0, 0],
#   ['thought', 0, 0],
#   ['content', 0, 0],
#   ['unable', 0, 0],
#   ['to', 0, 0],
#   ['assess', 0, 0],
#   ['from', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['but', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ["'", 0, 0],
#   ['s', 0, 0],
#   ['daughter', 0, 0],
#   ['denied', 0, 0],
#   ['del', 0, 0],
#   ['##usions', 0, 0],
#   ['and', 0, 0],
#   ['ho', 0, 0],
#   ['##mic', 0, 0],
#   ['##idal', 0, 0],
#   ['idea', 0, 0],
#   ['##tions', 0, 0],
#   ['.', 0, 0],
#   ['positive', 0, 0],
#   ['for', 0, 0],
#   ['passive', 0, 0],
#   ['su', 0, 0],
#   ['##icidal', 0, 0],
#   ['idea', 0, 0],
#   ['##tions', 0, 0],
#   ['and', 0, 0],
#   ['perception', 0, 0],
#   ['##s', 0, 0],
#   ['.', 0, 0],
#   ['no', 0, 0],
#   ['audit', 0, 0],
#   ['##ory', 0, 0],
#   ['or', 0, 0],
#   ['visual', 0, 0],
#   ['hall', 0, 0],
#   ['##uc', 0, 0],
#   ['##ination', 0, 0],
#   ['##s', 0, 0],
#   ['.', 0, 0],
#   ['sensor', 0, 0],
#   ['##ium', 0, 0],
#   ['s', 0, 0],
#   ['##tu', 0, 0],
#   ['##por', 0, 0],
#   ['##ous', 0, 0],
#   [',', 0, 0],
#   ['did', 0, 0],
#   ['not', 0, 0],
#   ['answer', 0, 0],
#   ['orientation', 0, 0],
#   ['questions', 0, 0],
#   ['.', 0, 0],
#   ['memory', 0, 0],
#   ['information', 0, 0],
#   [',', 0, 0],
#   ['intelligence', 0, 0],
#   [',', 0, 0],
#   ['judgment', 0, 0],
#   [',', 0, 0],
#   ['and', 0, 0],
#   ['insight', 0, 0],
#   ['unknown', 0, 0],
#   ['.', 0, 0],
#   ['mini', 0, 0],
#   ['-', 0, 0],
#   ['mental', 0, 0],
#   ['status', 0, 0],
#   ['examination', 0, 0],
#   ['unable', 0, 0],
#   ['to', 0, 0],
#   ['be', 0, 0],
#   ['performed', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '454_Consult-HistoryandPhy.-RecurrentAbscesses-Consult_9': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['followed', 0, 0],
#   ['by', 0, 0],
#   ['a', 0, 0],
#   ['g', 0, 0],
#   ['##yne', 0, 0],
#   ['##cologist', 0, 0],
#   ['in', 0, 0],
#   ['bar', 0, 0],
#   ['##to', 0, 0],
#   ['##w', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['not', 0, 0],
#   ['an', 0, 0],
#   ['alcohol', 1, 1],
#   ['or', 0, 0],
#   ['tobacco', 7, 7],
#   ['user', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['not', 0, 0],
#   ['married', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['has', 0, 0],
#   ['a', 0, 0],
#   ['2', 5, 0],
#   ['-', 6, 6],
#   ['year', 6, 6],
#   ['-', 6, 0],
#   ['old', 6, 6],
#   ['child', 6, 6],
#   ['.', 6, 0],
#   ['[SEP]', 0, 0]],
#  '479_Consult-HistoryandPhy.-SupraclavicularLymphadenopathy_7': [['[CLS]',
#    0,
#    0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['she', 0, 0],
#   ['was', 0, 0],
#   ['born', 0, 0],
#   ['and', 0, 0],
#   ['raised', 0, 0],
#   ['in', 0, 0],
#   ['b', 0, 0],
#   ['##al', 0, 1],
#   ['##ti', 0, 6],
#   ['##more', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['has', 0, 0],
#   ['not', 0, 0],
#   ['performed', 0, 0],
#   ['farming', 0, 1],
#   ['or', 0, 0],
#   ['kept', 0, 5],
#   ['birds', 0, 2],
#   ['or', 0, 0],
#   ['cats', 0, 0],
#   ['.', 0, 0],
#   ['tobacco', 7, 7],
#   [':', 0, 0],
#   ['none', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  "514_Consult-HistoryandPhy.-Worker'sCompensationInjury_9": [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['is', 0, 0],
#   ['single', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['lives', 0, 0],
#   ['with', 0, 0],
#   ['her', 0, 0],
#   ['boyfriend', 0, 0],
#   ['and', 0, 0],
#   ['his', 0, 5],
#   ['father', 0, 5],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['works', 0, 0],
#   ['at', 0, 0],
#   ['nor', 0, 0],
#   ['##craft', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['wears', 0, 0],
#   ['seat', 0, 0],
#   ['##belt', 0, 0],
#   ['30', 0, 0],
#   ['%', 0, 0],
#   ['of', 0, 0],
#   ['the', 0, 0],
#   ['time', 0, 0],
#   ['.', 0, 0],
#   ['i', 0, 0],
#   ['encouraged', 0, 0],
#   ['her', 0, 0],
#   ['to', 0, 0],
#   ['use', 0, 0],
#   ['them', 0, 0],
#   ['all', 0, 0],
#   ['of', 0, 0],
#   ['the', 0, 0],
#   ['time', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['a', 0, 0],
#   ['non', 0, 0],
#   ['##smo', 7, 7],
#   ['##ker', 8, 8],
#   [',', 0, 0],
#   ['non', 0, 0],
#   ['##dr', 1, 1],
#   ['##ink', 2, 2],
#   ['##er', 2, 2],
#   ['.', 0, 0],
#   ['v', 0, 0],
#   ['##ac', 0, 0],
#   ['##cin', 0, 0],
#   ['##ations', 0, 0],
#   [':', 0, 0],
#   ['she', 0, 0],
#   ['thinks', 0, 0],
#   ['she', 0, 0],
#   ['got', 0, 0],
#   ['a', 0, 0],
#   ['te', 0, 0],
#   ['##tan', 0, 0],
#   ['##us', 0, 0],
#   ['vaccine', 0, 0],
#   ['in', 0, 0],
#   ['childhood', 0, 0],
#   [',', 0, 0],
#   ['but', 0, 0],
#   ['does', 0, 0],
#   ['not', 0, 0],
#   ['know', 0, 0],
#   ['for', 0, 0],
#   ['sure', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['does', 0, 0],
#   ['not', 0, 0],
#   ['think', 0, 0],
#   ['she', 0, 0],
#   ['has', 0, 0],
#   ['had', 0, 0],
#   ['a', 0, 0],
#   ['te', 0, 0],
#   ['##tan', 0, 0],
#   ['##us', 0, 0],
#   ['boost', 0, 0],
#   ['##er', 0, 0],
#   ['recently', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '19_Consult-HistoryandPhy.-AnkleSprain-H&P_9': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['lives', 0, 0],
#   ['here', 0, 0],
#   ['locally', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['does', 0, 0],
#   ['not', 0, 0],
#   ['report', 0, 7],
#   ['any', 0, 0],
#   ['significant', 0, 0],
#   ['alcohol', 1, 1],
#   ['or', 0, 0],
#   ['ill', 0, 0],
#   ['##icit', 0, 0],
#   ['drug', 3, 3],
#   ['use', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['works', 0, 0],
#   ['full', 0, 0],
#   ['time', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '399_Consult-HistoryandPhy.-OrthopedicConsult-3_9': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['married', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['lives', 0, 0],
#   ['with', 0, 0],
#   ['her', 0, 0],
#   ['spouse', 5, 5],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '402_Consult-HistoryandPhy.-OtitisMedia-H&P_7': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['parent', 0, 0],
#   ['admits', 0, 0],
#   ['child', 5, 6],
#   ['is', 0, 0],
#   ['in', 0, 0],
#   ['a', 0, 0],
#   ['large', 0, 0],
#   ['day', 0, 0],
#   ['##care', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '427_Consult-HistoryandPhy.-PsychConsult-AssaultiveBehavior_10': [['[CLS]',
#    0,
#    0],
#   ['social', 0, 0],
#   ['and', 0, 0],
#   ['developmental', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['is', 0, 0],
#   ['employed', 0, 0],
#   ['as', 0, 0],
#   ['a', 0, 0],
#   ['tree', 0, 0],
#   ['cutter', 0, 0],
#   [',', 0, 0],
#   ['currently', 0, 0],
#   ['on', 0, 0],
#   ['medical', 0, 0],
#   ['leave', 0, 0],
#   ['for', 0, 0],
#   ['the', 0, 0],
#   ['last', 0, 0],
#   ['2', 0, 0],
#   ['months', 0, 0],
#   ['following', 0, 0],
#   ['a', 0, 0],
#   ['back', 0, 0],
#   ['injury', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['lives', 0, 0],
#   ['with', 0, 0],
#   ['his', 0, 0],
#   ['wife', 5, 5],
#   ['and', 0, 0],
#   ['children', 5, 5],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['has', 0, 0],
#   ['a', 0, 0],
#   ['history', 0, 0],
#   ['of', 0, 0],
#   ['domestic', 0, 0],
#   ['violence', 0, 0],
#   [',', 0, 0],
#   ['but', 0, 0],
#   ['not', 0, 0],
#   ['recently', 0, 0],
#   ['.', 0, 0],
#   ['other', 0, 0],
#   ['details', 0, 0],
#   ['of', 0, 0],
#   ['occupational', 0, 0],
#   [',', 0, 0],
#   ['educational', 0, 0],
#   ['history', 0, 0],
#   ['not', 0, 0],
#   ['currently', 0, 0],
#   ['known', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '450_Consult-HistoryandPhy.-RecordsReview-Epicondylitis_9': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['injured', 0, 0],
#   ['worker', 0, 0],
#   ['denies', 0, 0],
#   ['tobacco', 7, 7],
#   ['or', 0, 0],
#   ['alcohol', 1, 1],
#   ['consumption', 0, 2],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '98_Consult-HistoryandPhy.-Consult-EnlargedTonsils_9': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['is', 0, 0],
#   ['single', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['a', 0, 0],
#   ['student', 0, 0],
#   ['.', 0, 0],
#   ['denies', 0, 0],
#   ['tobacco', 7, 7],
#   ['or', 0, 0],
#   ['alcohol', 1, 1],
#   ['use', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '18_Consult-HistoryandPhy.-AnklePain-Consult_10': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['mother', 5, 0],
#   ['appears', 0, 0],
#   ['loving', 0, 0],
#   ['and', 0, 0],
#   ['caring', 0, 0],
#   ['.', 0, 0],
#   ['there', 0, 0],
#   ['is', 0, 0],
#   ['no', 0, 0],
#   ['evidence', 0, 0],
#   ['of', 0, 0],
#   ['abuse', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '273_Consult-HistoryandPhy.-HypersensitivitytoCoumadin_5': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['is', 0, 0],
#   ['originally', 0, 0],
#   ['from', 0, 0],
#   ['main', 0, 0],
#   ['##e', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['has', 0, 0],
#   ['lived', 0, 0],
#   ['in', 0, 0],
#   ['a', 0, 0],
#   ['##riz', 0, 0],
#   ['##ona', 0, 0],
#   ['for', 0, 0],
#   ['4', 0, 0],
#   ['years', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['has', 0, 0],
#   ['had', 0, 0],
#   ['2', 5, 5],
#   ['children', 6, 6],
#   [';', 0, 0],
#   ['however', 0, 0],
#   [',', 0, 0],
#   ['only', 0, 0],
#   ['one', 0, 0],
#   ['is', 0, 0],
#   ['living', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['had', 0, 0],
#   ['one', 5, 5],
#   ['child', 6, 5],
#   ['died', 0, 0],
#   ['from', 0, 0],
#   ['complications', 0, 0],
#   ['of', 0, 0],
#   ['ul', 0, 0],
#   ['##cer', 0, 0],
#   ['##ative', 0, 0],
#   ['co', 0, 0],
#   ['##lit', 0, 0],
#   ['##is', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['has', 0, 0],
#   ['been', 0, 0],
#   ['predominantly', 0, 0],
#   ['a', 0, 0],
#   ['home', 0, 0],
#   ['##maker', 0, 0],
#   ['during', 0, 0],
#   ['her', 0, 0],
#   ['life', 0, 0],
#   [',', 0, 0],
#   ['but', 0, 0],
#   ['has', 0, 0],
#   ['done', 0, 0],
#   ['some', 0, 0],
#   ['domestic', 0, 0],
#   ['cleaning', 0, 0],
#   ['work', 0, 0],
#   ['in', 0, 0],
#   ['the', 0, 0],
#   ['past', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '321_Consult-HistoryandPhy.-MigrainewithoutAura-Consult_4': [['[CLS]', 0, 0],
#   ['headache', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['describes', 0, 0],
#   ['the', 0, 0],
#   ['gradual', 0, 0],
#   ['onset', 0, 0],
#   ['of', 0, 0],
#   ['a', 0, 0],
#   ['headache', 0, 0],
#   ['problem', 0, 0],
#   ['.', 0, 0],
#   ['the', 0, 0],
#   ['headache', 0, 0],
#   ['first', 0, 5],
#   ['began', 0, 5],
#   ['2', 0, 0],
#   ['months', 0, 0],
#   ['ago', 0, 0],
#   ['.', 0, 0],
#   ['the', 0, 0],
#   ['headache', 0, 0],
#   ['##s', 0, 0],
#   ['are', 0, 0],
#   ['located', 0, 0],
#   ['behind', 0, 0],
#   ['both', 0, 0],
#   ['eyes', 0, 0],
#   ['.', 0, 0],
#   ['the', 0, 0],
#   ['pain', 0, 0],
#   ['is', 0, 0],
#   ['characterized', 0, 0],
#   ['as', 0, 0],
#   ['a', 0, 0],
#   ['sensation', 0, 0],
#   ['of', 0, 0],
#   ['pressure', 0, 0],
#   ['.', 0, 0],
#   ['the', 0, 0],
#   ['intensity', 0, 0],
#   ['is', 0, 0],
#   ['moderately', 0, 0],
#   ['severe', 0, 0],
#   [',', 0, 0],
#   ['making', 0, 0],
#   ['normal', 0, 0],
#   ['activities', 0, 0],
#   ['difficult', 0, 0],
#   ['.', 0, 0],
#   ['associated', 0, 0],
#   ['symptoms', 0, 0],
#   ['include', 0, 0],
#   ['sin', 0, 0],
#   ['##us', 0, 0],
#   ['congestion', 0, 0],
#   ['and', 0, 0],
#   ['photo', 0, 0],
#   ['##ph', 0, 0],
#   ['##obia', 0, 4],
#   ['.', 0, 0],
#   ['the', 0, 0],
#   ['headache', 0, 0],
#   ['may', 0, 0],
#   ['be', 0, 0],
#   ['brought', 0, 0],
#   ['on', 0, 0],
#   ['by', 0, 0],
#   ['stress', 0, 0],
#   [',', 0, 0],
#   ['lack', 0, 0],
#   ['of', 0, 0],
#   ['sleep', 0, 0],
#   ['and', 0, 0],
#   ['alcohol', 1, 1],
#   ['.', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['denies', 0, 0],
#   ['vomit', 0, 0],
#   ['##ing', 0, 0],
#   ['and', 0, 0],
#   ['jaw', 0, 0],
#   ['pain', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '347_Consult-HistoryandPhy.-NeuropsychologicalEvaluation-3_11': [['[CLS]',
#    0,
#    0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['obtained', 0, 0],
#   ['a', 0, 0],
#   ['law', 0, 0],
#   ['degree', 0, 0],
#   ['from', 0, 0],
#   ['the', 0, 0],
#   ['university', 0, 0],
#   ['of', 0, 0],
#   ['b', 0, 0],
#   ['##al', 0, 0],
#   ['##ti', 0, 0],
#   ['##more', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['did', 0, 0],
#   ['not', 0, 0],
#   ['complete', 0, 0],
#   ['his', 0, 0],
#   ['undergraduate', 0, 0],
#   ['degree', 0, 0],
#   ['from', 0, 0],
#   ['the', 0, 0],
#   ['university', 0, 0],
#   ['of', 0, 0],
#   ['ma', 0, 0],
#   ['##ryl', 0, 0],
#   ['##and', 0, 0],
#   ['because', 0, 0],
#   ['he', 0, 0],
#   ['was', 0, 0],
#   ['able', 0, 0],
#   ['to', 0, 0],
#   ['transfer', 0, 0],
#   ['his', 0, 0],
#   ['credits', 0, 0],
#   ['in', 0, 0],
#   ['order', 0, 0],
#   ['to', 0, 0],
#   ['attend', 0, 0],
#   ['law', 0, 0],
#   ['school', 0, 0],
#   ['at', 0, 0],
#   ['that', 0, 0],
#   ['time', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['reported', 0, 0],
#   ['that', 0, 0],
#   ['he', 0, 0],
#   ['did', 0, 0],
#   ['not', 0, 0],
#   ['obtain', 0, 0],
#   ['very', 0, 0],
#   ['good', 0, 0],
#   ['grades', 0, 0],
#   ['until', 0, 0],
#   ['he', 0, 0],
#   ['reached', 0, 0],
#   ['law', 0, 0],
#   ['school', 0, 0],
#   [',', 0, 0],
#   ['at', 0, 0],
#   ['which', 0, 0],
#   ['point', 0, 0],
#   ['he', 0, 0],
#   ['graduated', 0, 0],
#   ['in', 0, 0],
#   ['the', 0, 0],
#   ['top', 0, 0],
#   ['10', 0, 0],
#   ['of', 0, 0],
#   ['his', 0, 0],
#   ['class', 0, 0],
#   ['and', 0, 0],
#   ['had', 0, 0],
#   ['no', 0, 0],
#   ['problem', 0, 0],
#   ['passing', 0, 0],
#   ['the', 0, 0],
#   ['bar', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['thought', 0, 0],
#   ['that', 0, 0],
#   ['effort', 0, 0],
#   ['and', 0, 0],
#   ['motivation', 0, 0],
#   ['were', 0, 0],
#   ['important', 0, 0],
#   ['to', 0, 0],
#   ['his', 0, 0],
#   ['success', 0, 0],
#   ['in', 0, 0],
#   ['his', 0, 0],
#   ['school', 0, 0],
#   ['and', 0, 0],
#   ['he', 0, 0],
#   ['had', 0, 0],
#   ['not', 0, 0],
#   ['felt', 0, 0],
#   ['very', 0, 0],
#   ['motivated', 0, 0],
#   ['previously', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['reported', 0, 0],
#   ['that', 0, 0],
#   ['he', 0, 0],
#   ['repeated', 0, 0],
#   ['math', 0, 0],
#   ['classes', 0, 0],
#   ['"', 0, 0],
#   ['every', 0, 0],
#   ['year', 0, 0],
#   ['of', 0, 0],
#   ['school', 0, 0],
#   ['"', 0, 0],
#   ['and', 0, 0],
#   ['attended', 0, 0],
#   ['summer', 0, 0],
#   ['school', 0, 0],
#   ['every', 0, 0],
#   ['year', 0, 0],
#   ['due', 0, 0],
#   ['to', 0, 0],
#   ['that', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['has', 0, 0],
#   ['worked', 0, 0],
#   ['as', 0, 0],
#   ['a', 0, 0],
#   ['tax', 0, 0],
#   ['attorney', 0, 0],
#   ['for', 0, 0],
#   ['the', 0, 0],
#   ['past', 0, 0],
#   ['48', 0, 0],
#   ['years', 0, 0],
#   ['and', 0, 0],
#   ['reported', 0, 0],
#   ['having', 0, 0],
#   ['a', 0, 0],
#   ['thriving', 0, 0],
#   ['practice', 0, 0],
#   ['with', 0, 0],
#   ['clients', 0, 0],
#   ['all', 0, 0],
#   ['across', 0, 0],
#   ['the', 0, 0],
#   ['country', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['served', 0, 0],
#   ['also', 0, 0],
#   ['in', 0, 0],
#   ['the', 0, 0],
#   ['u', 0, 0],
#   ['.', 0, 0],
#   ['s', 0, 0],
#   ['.', 0, 0],
#   ['coast', 0, 0],
#   ['guard', 0, 0],
#   ['between', 0, 0],
#   ['1951', 0, 0],
#   ['and', 0, 0],
#   ['1953', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['has', 0, 0],
#   ['been', 0, 0],
#   ['married', 0, 0],
#   ['for', 0, 0],
#   ['the', 0, 0],
#   ['past', 0, 0],
#   ['36', 0, 0],
#   ['years', 0, 0],
#   ['to', 0, 0],
#   ['his', 0, 0],
#   ['wife', 5, 5],
#   [',', 0, 0],
#   ['l', 0, 0],
#   ['##inda', 0, 0],
#   [',', 0, 0],
#   ['who', 0, 0],
#   ['is', 0, 0],
#   ['a', 0, 0],
#   ['home', 0, 0],
#   ['##maker', 0, 0],
#   ['.', 0, 0],
#   ['they', 0, 0],
#   ['have', 0, 0],
#   ['four', 5, 0],
#   ['children', 6, 0],
#   ['and', 0, 0],
#   ['he', 0, 0],
#   ['reported', 0, 0],
#   ['having', 0, 0],
#   ['good', 0, 0],
#   ['relationship', 0, 0],
#   ['with', 0, 0],
#   ['them', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['described', 0, 0],
#   ['being', 0, 0],
#   ['very', 0, 0],
#   ['active', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['goes', 0, 0],
#   ['for', 0, 0],
#   ['dancing', 0, 0],
#   ['four', 0, 0],
#   ['to', 0, 0],
#   ['five', 0, 0],
#   ['times', 0, 0],
#   ['a', 0, 0],
#   ['week', 0, 0],
#   [',', 0, 0],
#   ['swim', 0, 0],
#   ['##s', 0, 0],
#   ['daily', 0, 0],
#   [',', 0, 0],
#   ['plays', 0, 0],
#   ['golf', 0, 0],
#   ['regularly', 0, 0],
#   ['and', 0, 0],
#   ['spends', 0, 0],
#   ['significant', 0, 0],
#   ['amounts', 0, 0],
#   ['of', 0, 0],
#   ['time', 0, 0],
#   ['social', 0, 0],
#   ['##izing', 0, 0],
#   ['with', 0, 0],
#   ['friends', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '43_Consult-HistoryandPhy.-BloodInToilet_7': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['no', 0, 0],
#   ['tobacco', 7, 7],
#   ['or', 0, 0],
#   ['alcohol', 1, 1],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '266_Consult-HistoryandPhy.-HipFracture-ERConsult_8': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['denies', 0, 0],
#   ['any', 0, 0],
#   ['tobacco', 7, 7],
#   ['or', 0, 0],
#   ['alcohol', 1, 1],
#   ['use', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['divorced', 0, 0],
#   ['with', 0, 0],
#   ['2', 5, 5],
#   ['children', 6, 6],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['lives', 0, 0],
#   ['with', 0, 0],
#   ['her', 0, 0],
#   ['son', 5, 5],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '286_Consult-HistoryandPhy.-ItchyRash-ERVisit_7': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['is', 0, 0],
#   ['accompanied', 0, 0],
#   ['with', 0, 0],
#   ['his', 0, 0],
#   ['wife', 5, 5],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '120_Consult-HistoryandPhy.-Consult-Vomiting&Nausea_7': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['is', 0, 0],
#   ['divorced', 0, 0],
#   ['and', 0, 0],
#   ['is', 0, 0],
#   ['a', 0, 0],
#   ['home', 0, 0],
#   ['##maker', 0, 0],
#   ['.', 0, 0],
#   ['no', 0, 0],
#   ['smoking', 7, 7],
#   ['or', 0, 0],
#   ['alcohol', 1, 1],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '178_Consult-HistoryandPhy.-ForeignBody-Fingernail_6': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['patient', 0, 0],
#   ['is', 0, 0],
#   ['married', 0, 0],
#   ['and', 0, 0],
#   ['is', 0, 0],
#   ['a', 0, 0],
#   ['non', 0, 7],
#   ['##smo', 7, 8],
#   ['##ker', 8, 8],
#   ['and', 0, 0],
#   ['lives', 0, 0],
#   ['with', 0, 0],
#   ['his', 0, 0],
#   ['wife', 5, 5],
#   ['.', 0, 0],
#   ['nursing', 0, 0],
#   ['notes', 0, 0],
#   ['were', 0, 0],
#   ['reviewed', 0, 0],
#   ['with', 0, 0],
#   ['which', 0, 0],
#   ['i', 0, 0],
#   ['agree', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '204_Consult-HistoryandPhy.-GenMedConsult-26_9': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['no', 0, 0],
#   ['tobacco', 7, 7],
#   [',', 0, 0],
#   ['alcohol', 1, 1],
#   ['or', 0, 0],
#   ['ill', 0, 0],
#   ['##icit', 0, 0],
#   ['drug', 3, 3],
#   ['use', 0, 0],
#   ['.', 0, 0],
#   ['patient', 0, 0],
#   ['is', 0, 0],
#   ['born', 0, 0],
#   ['and', 0, 0],
#   ['raised', 0, 0],
#   ['in', 0, 0],
#   ['ok', 0, 0],
#   ['##lah', 0, 0],
#   ['##oma', 0, 0],
#   ['.', 0, 0],
#   ['no', 0, 0],
#   ['known', 0, 0],
#   ['exposure', 0, 0],
#   ['##s', 0, 0],
#   ['.', 0, 0],
#   ['married', 0, 0],
#   ['with', 0, 0],
#   ['2', 5, 5],
#   ['children', 6, 6],
#   ['.', 0, 0],
#   ['medication', 0, 0],
#   [':', 0, 0],
#   ['none', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '258_Consult-HistoryandPhy.-HandPain-Consult_6': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['is', 0, 0],
#   ['a', 0, 0],
#   ['non', 0, 0],
#   ['##smo', 7, 7],
#   ['##ker', 8, 8],
#   ['and', 0, 0],
#   ['does', 0, 0],
#   ['not', 0, 0],
#   ['use', 0, 0],
#   ['illegal', 0, 0],
#   ['drugs', 3, 3],
#   ['.', 0, 0],
#   ['occasionally', 0, 1],
#   ['drinks', 1, 2],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '301_Consult-HistoryandPhy.-LowBackPain-Consult_5': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['he', 0, 0],
#   ['is', 0, 0],
#   ['married', 0, 0],
#   ['and', 0, 0],
#   ['has', 0, 0],
#   ['support', 0, 0],
#   ['at', 0, 0],
#   ['home', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['denies', 0, 0],
#   ['tobacco', 7, 7],
#   ['and', 0, 0],
#   ['ill', 0, 0],
#   ['##icit', 0, 0],
#   ['drug', 3, 3],
#   ['use', 0, 4],
#   ['and', 0, 0],
#   ['drinks', 1, 1],
#   ['two', 0, 2],
#   ['to', 0, 0],
#   ['three', 0, 0],
#   ['alcoholic', 0, 1],
#   ['beverages', 0, 2],
#   ['a', 0, 0],
#   ['day', 0, 0],
#   ['and', 0, 0],
#   ['up', 0, 0],
#   ['to', 0, 0],
#   ['four', 0, 0],
#   ['to', 0, 0],
#   ['nine', 0, 0],
#   ['per', 0, 0],
#   ['week', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '321_Consult-HistoryandPhy.-MigrainewithoutAura-Consult_10': [['[CLS]', 0, 0],
#   ['personal', 0, 0],
#   ['/', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['marital', 0, 0],
#   ['status', 0, 0],
#   [':', 0, 0],
#   ['married', 0, 0],
#   ['.', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['smoke', 7, 7],
#   ['##s', 8, 8],
#   ['1', 0, 0],
#   ['pack', 0, 0],
#   ['of', 0, 0],
#   ['cigarettes', 0, 0],
#   ['per', 0, 0],
#   ['day', 0, 0],
#   ['.', 0, 0],
#   ['denies', 0, 0],
#   ['use', 0, 0],
#   ['of', 0, 0],
#   ['alcohol', 1, 1],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '406_Consult-HistoryandPhy.-ParoxysmalAtrialFibrillation_10': [['[CLS]',
#    0,
#    0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['is', 0, 0],
#   ['married', 0, 0],
#   ['.', 0, 0],
#   ['has', 0, 0],
#   ['four', 0, 0],
#   ['adult', 5, 1],
#   ['children', 6, 6],
#   ['.', 0, 0],
#   ['good', 0, 0],
#   ['health', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['a', 0, 0],
#   ['lifetime', 0, 0],
#   ['non', 0, 0],
#   ['##smo', 7, 7],
#   ['##ker', 8, 8],
#   [',', 0, 0],
#   ['social', 0, 0],
#   ['alcohol', 1, 1],
#   ['drink', 2, 2],
#   ['##er', 2, 2],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '408_Consult-HistoryandPhy.-PenileCellulitis_7': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['lives', 0, 0],
#   ['with', 0, 0],
#   ['both', 5, 0],
#   ['parents', 6, 5],
#   ['and', 0, 0],
#   ['no', 0, 0],
#   ['siblings', 0, 5],
#   ['.', 0, 0],
#   ['there', 0, 0],
#   ['are', 0, 0],
#   ['smoke', 0, 7],
#   ['##rs', 0, 0],
#   ['at', 0, 0],
#   ['home', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '421_Consult-HistoryandPhy.-ProstateAdenocarcinoma-H&P_7': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['he', 0, 0],
#   ['is', 0, 0],
#   ['not', 0, 0],
#   ['a', 0, 0],
#   ['smoke', 7, 7],
#   ['##r', 8, 8],
#   ['.', 8, 0],
#   ['he', 0, 0],
#   ['does', 0, 0],
#   ['drink', 1, 1],
#   ['six', 0, 2],
#   ['beers', 0, 2],
#   ['a', 0, 2],
#   ['day', 0, 2],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '446_Consult-HistoryandPhy.-PulmonaryConsultation-2_8': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['is', 0, 0],
#   ['a', 0, 0],
#   ['non', 0, 0],
#   ['-', 0, 0],
#   ['smoke', 7, 7],
#   ['##r', 8, 8],
#   ['.', 0, 0],
#   ['no', 0, 0],
#   ['alcohol', 1, 1],
#   ['abuse', 0, 0],
#   ['.', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['is', 0, 0],
#   ['married', 0, 0],
#   ['with', 0, 0],
#   ['no', 0, 5],
#   ['children', 0, 6],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '451_Consult-HistoryandPhy.-RecordsReview-Orthopedic_8': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['he', 0, 0],
#   ['does', 0, 0],
#   ['admit', 0, 0],
#   ['to', 0, 0],
#   ['one', 7, 0],
#   ['half', 8, 0],
#   ['pack', 8, 0],
#   ['of', 8, 0],
#   ['cigarette', 8, 0],
#   ['consumption', 8, 3],
#   ['per', 8, 0],
#   ['day', 8, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['denies', 0, 0],
#   ['any', 0, 0],
#   ['alcohol', 1, 1],
#   ['consumption', 2, 2],
#   ['.', 2, 0],
#   ['[SEP]', 0, 0]],
#  '468_Consult-HistoryandPhy.-SickSinusSyndrome_6': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['resides', 0, 0],
#   ['full', 0, 0],
#   ['time', 0, 0],
#   ['at', 0, 0],
#   ['a', 0, 0],
#   ['##b', 0, 0],
#   ['##c', 0, 0],
#   ['supervised', 0, 0],
#   ['living', 0, 0],
#   ['facility', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['is', 0, 0],
#   ['non', 0, 0],
#   ['##smo', 7, 7],
#   ['##ker', 8, 8],
#   [',', 8, 0],
#   ['non', 0, 0],
#   ['##dr', 1, 1],
#   ['##ink', 2, 2],
#   ['##er', 2, 2],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['uses', 0, 0],
#   ['wheelchair', 0, 0],
#   ['and', 0, 0],
#   ['moves', 0, 5],
#   ['himself', 0, 6],
#   ['about', 0, 0],
#   ['with', 0, 0],
#   ['his', 0, 0],
#   ['feet', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['is', 0, 0],
#   ['independent', 0, 0],
#   ['of', 0, 0],
#   ['activities', 0, 0],
#   ['of', 0, 0],
#   ['daily', 0, 0],
#   ['living', 0, 0],
#   ['and', 0, 0],
#   ['dependent', 0, 0],
#   ['on', 0, 0],
#   ['independent', 0, 0],
#   ['activities', 0, 0],
#   ['of', 0, 0],
#   ['daily', 0, 0],
#   ['living', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '510_Consult-HistoryandPhy.-Well-ChildCheck-5_6': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['lives', 0, 0],
#   ['at', 0, 0],
#   ['home', 0, 0],
#   ['with', 0, 0],
#   ['23', 0, 0],
#   ['-', 0, 0],
#   ['year', 0, 0],
#   ['-', 0, 0],
#   ['old', 0, 0],
#   ['mother', 5, 5],
#   [',', 0, 0],
#   ['who', 0, 0],
#   ['is', 0, 0],
#   ['a', 0, 0],
#   ['home', 0, 0],
#   ['##maker', 0, 0],
#   ['and', 0, 0],
#   ['24', 0, 5],
#   ['-', 0, 0],
#   ['year', 0, 0],
#   ['-', 0, 6],
#   ['old', 0, 6],
#   ['father', 5, 6],
#   [',', 0, 0],
#   ['j', 0, 6],
#   ['##oh', 0, 0],
#   ['##n', 0, 0],
#   [',', 0, 0],
#   ['who', 0, 0],
#   ['is', 0, 0],
#   ['a', 0, 0],
#   ['supervisor', 0, 0],
#   ['at', 0, 0],
#   ['ex', 0, 0],
#   ['##cel', 0, 0],
#   ['.', 0, 0],
#   ['the', 0, 0],
#   ['family', 0, 0],
#   ['lives', 0, 0],
#   ['in', 0, 0],
#   ['bent', 0, 0],
#   ['##ley', 0, 0],
#   [',', 0, 0],
#   ['ka', 0, 0],
#   ['##ns', 0, 0],
#   ['##as', 0, 0],
#   ['.', 0, 0],
#   ['no', 0, 0],
#   ['smoking', 0, 0],
#   ['in', 0, 0],
#   ['the', 0, 0],
#   ['home', 0, 0],
#   ['.', 0, 0],
#   ['family', 0, 0],
#   ['does', 0, 0],
#   ['have', 0, 0],
#   ['one', 0, 0],
#   ['pet', 0, 0],
#   ['cat', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '112_Consult-HistoryandPhy.-Consult-RectalBleeding_8': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['is', 0, 0],
#   ['retired', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['is', 0, 0],
#   ['married', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['had', 0, 0],
#   ['4', 5, 5],
#   ['children', 6, 6],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['quite', 7, 0],
#   ['smoking', 8, 7],
#   ['25', 0, 0],
#   ['years', 0, 0],
#   ['ago', 0, 0],
#   ['after', 0, 0],
#   ['a', 0, 0],
#   ['35', 0, 0],
#   ['-', 0, 0],
#   ['year', 0, 0],
#   ['history', 0, 0],
#   ['of', 0, 0],
#   ['smoking', 0, 7],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['does', 0, 0],
#   ['not', 0, 0],
#   ['drink', 1, 1],
#   ['alcohol', 2, 2],
#   ['.', 0, 2],
#   ['[SEP]', 0, 0]],
#  '116_Consult-HistoryandPhy.-Consult-Sepsis_6': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['is', 0, 0],
#   ['a', 0, 0],
#   ['former', 0, 0],
#   ['smoke', 7, 7],
#   ['##r', 8, 8],
#   [',', 0, 0],
#   ['reportedly', 0, 0],
#   ['quit', 0, 0],
#   ['in', 0, 0],
#   ['2007', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['used', 0, 0],
#   ['cocaine', 3, 3],
#   ['in', 0, 0],
#   ['the', 0, 0],
#   ['past', 0, 0],
#   [',', 0, 0],
#   ['reportedly', 0, 0],
#   ['quit', 0, 0],
#   ['in', 0, 0],
#   ['2005', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['also', 0, 0],
#   ['has', 0, 0],
#   ['a', 0, 0],
#   ['history', 0, 0],
#   ['of', 0, 0],
#   ['alcohol', 1, 1],
#   ['abuse', 0, 0],
#   [',', 0, 0],
#   ['but', 0, 0],
#   ['apparently', 0, 0],
#   ['quit', 0, 0],
#   ['more', 0, 0],
#   ['than', 0, 0],
#   ['10', 0, 0],
#   ['years', 0, 0],
#   ['ago', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '118_Consult-HistoryandPhy.-Consult-StasisUlcer_7': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['admits', 0, 0],
#   ['to', 0, 0],
#   ['heavy', 0, 0],
#   ['alcohol', 1, 1],
#   ['drinking', 0, 2],
#   ['in', 0, 0],
#   ['the', 0, 0],
#   ['past', 0, 0],
#   [',', 0, 0],
#   ['quit', 0, 0],
#   ['several', 0, 0],
#   ['years', 0, 0],
#   ['ago', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['is', 0, 0],
#   ['also', 0, 0],
#   ['a', 0, 0],
#   ['former', 0, 0],
#   ['cigarette', 0, 0],
#   ['smoke', 7, 7],
#   ['##r', 8, 8],
#   [',', 0, 0],
#   ['quit', 0, 0],
#   ['several', 0, 0],
#   ['years', 0, 0],
#   ['ago', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '162_Consult-HistoryandPhy.-ENTConsult_14': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['is', 0, 0],
#   ['single', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['unemployed', 0, 0],
#   ['at', 0, 0],
#   ['this', 0, 0],
#   ['time', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['a', 0, 0],
#   ['smoke', 7, 7],
#   ['##r', 8, 8],
#   ['about', 0, 0],
#   ['a', 0, 0],
#   ['pack', 0, 0],
#   ['and', 0, 0],
#   ['a', 0, 0],
#   ['half', 0, 0],
#   ['for', 0, 0],
#   ['38', 0, 0],
#   ['years', 0, 0],
#   ['and', 0, 0],
#   ['notes', 0, 0],
#   ['rare', 0, 0],
#   ['alcohol', 1, 1],
#   ['use', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '190_Consult-HistoryandPhy.-GenMedConsult-13_8': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['married', 0, 0],
#   ['.', 0, 0],
#   ['a', 0, 0],
#   ['76', 0, 0],
#   ['-', 0, 0],
#   ['year', 0, 0],
#   ['-', 0, 0],
#   ['old', 0, 0],
#   ['who', 0, 0],
#   ['used', 0, 0],
#   ['to', 0, 0],
#   ['smoke', 7, 7],
#   ['a', 0, 0],
#   ['pack', 0, 0],
#   ['a', 0, 0],
#   ['day', 0, 0],
#   ['and', 0, 0],
#   ['quit', 0, 0],
#   ['in', 0, 0],
#   ['1985', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['retired', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '226_Consult-HistoryandPhy.-GenMedConsult-46_10': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['he', 0, 0],
#   ['does', 0, 0],
#   ['smoke', 7, 7],
#   ['two', 0, 8],
#   ['packs', 0, 0],
#   ['of', 0, 0],
#   ['cigarettes', 0, 0],
#   ['per', 0, 0],
#   ['day', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['has', 0, 0],
#   ['no', 0, 0],
#   ['alcohol', 1, 1],
#   ['or', 0, 0],
#   ['drug', 3, 3],
#   ['use', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['is', 0, 0],
#   ['a', 0, 0],
#   ['painter', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '259_Consult-HistoryandPhy.-Head&NeckCancerConsult_9': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['is', 0, 0],
#   ['married', 0, 0],
#   ['but', 0, 0],
#   ['has', 0, 0],
#   ['been', 0, 0],
#   ['separated', 0, 0],
#   ['from', 0, 0],
#   ['his', 0, 0],
#   ['wife', 0, 5],
#   ['for', 0, 0],
#   ['many', 0, 0],
#   ['years', 0, 0],
#   [',', 0, 0],
#   ['they', 0, 0],
#   ['remain', 0, 0],
#   ['close', 0, 0],
#   [',', 0, 0],
#   ['and', 0, 0],
#   ['they', 0, 0],
#   ['have', 0, 0],
#   ['two', 5, 0],
#   ['adult', 6, 0],
#   ['sons', 6, 6],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['is', 0, 0],
#   ['retired', 0, 0],
#   ['from', 0, 0],
#   ['the', 0, 0],
#   ['air', 0, 0],
#   ['force', 0, 0],
#   [',', 0, 0],
#   ['currently', 0, 0],
#   ['works', 0, 0],
#   ['for', 0, 0],
#   ['lock', 0, 0],
#   ['##hee', 0, 0],
#   ['##d', 0, 0],
#   ['ma', 0, 0],
#   ['##rt', 0, 0],
#   ['##in', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['was', 0, 0],
#   ['born', 0, 0],
#   ['and', 0, 0],
#   ['raised', 0, 0],
#   ['in', 0, 0],
#   ['new', 0, 0],
#   ['yo', 0, 0],
#   ['##rk', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['does', 0, 0],
#   ['have', 0, 0],
#   ['a', 0, 0],
#   ['smoking', 7, 7],
#   ['history', 0, 0],
#   [',', 0, 0],
#   ['about', 0, 0],
#   ['a', 0, 0],
#   ['20', 0, 0],
#   ['pack', 0, 0],
#   ['-', 0, 0],
#   ['year', 0, 0],
#   ['history', 0, 0],
#   ['and', 0, 0],
#   ['he', 0, 0],
#   ['reports', 0, 0],
#   ['quit', 0, 0],
#   ['##ting', 0, 0],
#   ['on', 0, 0],
#   ['j', 0, 0],
#   ['##ul', 0, 0],
#   ['##y', 0, 0],
#   ['27', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['does', 1, 0],
#   ['drink', 2, 1],
#   ['alcohol', 2, 2],
#   ['socially', 0, 0],
#   ['.', 0, 0],
#   ['no', 0, 0],
#   ['use', 0, 0],
#   ['of', 0, 0],
#   ['ill', 0, 3],
#   ['##icit', 0, 4],
#   ['drugs', 3, 3],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '264_Consult-HistoryandPhy.-Hematuria-ERVisit_7': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['lives', 0, 0],
#   ['at', 0, 0],
#   ['home', 0, 0],
#   ['with', 0, 0],
#   ['his', 0, 0],
#   ['daughter', 5, 5],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['does', 0, 0],
#   ['not', 0, 0],
#   ['smoke', 7, 7],
#   [',', 0, 0],
#   ['occasionally', 0, 0],
#   ['drinks', 1, 1],
#   ['alcohol', 2, 2],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['is', 0, 0],
#   ['independent', 0, 0],
#   ['with', 0, 0],
#   ['his', 0, 0],
#   ['activities', 0, 0],
#   ['of', 0, 0],
#   ['daily', 0, 0],
#   ['living', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '285_Consult-HistoryandPhy.-IschemicCecum-Consult_8': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['had', 0, 0],
#   ['a', 0, 0],
# ...
#   ['-', 0, 0],
#   ['7', 0, 0],
#   ['cigarettes', 0, 0],
#   ['per', 0, 0],
#   ['day', 0, 0],
#   ['and', 0, 0],
#   ['has', 0, 0],
#   ['done', 0, 0],
#   ['so', 0, 0],
#   ['for', 0, 0],
#   ['more', 0, 0],
#   ['than', 0, 0],
#   ['50', 0, 0],
#   ['years', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['quit', 0, 0],
#   ['smoking', 7, 7],
#   ['about', 0, 0],
#   ['6', 0, 0],
#   ['weeks', 0, 0],
#   ['ago', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['occasionally', 0, 0],
#   ['has', 0, 0],
#   ['alcohol', 1, 1],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['married', 0, 0],
#   ['and', 0, 0],
#   ['has', 0, 0],
#   ['3', 5, 5],
#   ['children', 6, 6],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['lives', 0, 0],
#   ['at', 0, 0],
#   ['home', 0, 0],
#   ['with', 0, 0],
#   ['her', 0, 0],
#   ['husband', 5, 5],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['used', 0, 0],
#   ['to', 0, 0],
#   ['work', 0, 0],
#   ['as', 0, 0],
#   ['a', 0, 0],
#   ['unit', 0, 0],
#   ['clerk', 0, 0],
#   ['at', 0, 0],
#   ['x', 0, 0],
#   ['##y', 0, 0],
#   ['##z', 0, 0],
#   ['medical', 0, 0],
#   ['center', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '324_Consult-HistoryandPhy.-MultipleNeurologicalSymptoms_8': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['he', 0, 0],
#   ['previously', 0, 0],
#   ['worked', 0, 0],
#   ['with', 0, 0],
#   ['pipeline', 0, 0],
#   ['work', 0, 0],
#   [',', 0, 0],
#   ['but', 0, 0],
#   ['has', 0, 0],
#   ['been', 0, 0],
#   ['on', 0, 0],
#   ['disability', 0, 0],
#   ['for', 0, 0],
#   ['five', 0, 0],
#   ['years', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['is', 0, 0],
#   ['unsure', 0, 0],
#   ['which', 0, 0],
#   ['symptoms', 0, 5],
#   ['led', 0, 6],
#   ['him', 0, 0],
#   ['to', 0, 0],
#   ['go', 0, 0],
#   ['on', 0, 0],
#   ['disability', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['has', 0, 0],
#   ['previously', 0, 0],
#   ['smoked', 7, 7],
#   ['about', 0, 0],
#   ['two', 0, 0],
#   ['packs', 0, 0],
#   ['of', 0, 0],
#   ['cigarettes', 0, 0],
#   ['daily', 0, 0],
#   ['for', 0, 0],
#   ['20', 0, 0],
#   ['years', 0, 0],
#   [',', 0, 0],
#   ['but', 0, 0],
#   ['quit', 0, 0],
#   ['about', 0, 0],
#   ['20', 0, 0],
#   ['years', 0, 0],
#   ['ago', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['denies', 0, 0],
#   ['alcohol', 1, 1],
#   ['or', 0, 0],
#   ['ill', 0, 0],
#   ['##icit', 0, 0],
#   ['drug', 3, 3],
#   ['use', 0, 4],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['lives', 0, 0],
#   ['with', 0, 0],
#   ['his', 0, 0],
#   ['wife', 0, 5],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['does', 0, 0],
#   ['not', 0, 0],
#   ['really', 0, 0],
#   ['have', 0, 0],
#   ['any', 0, 0],
#   ['ho', 0, 0],
#   ['##bb', 0, 0],
#   ['##ies', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '325_Consult-HistoryandPhy.-Murmur&Bacteremia._9': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['denies', 0, 0],
#   ['ever', 0, 5],
#   ['having', 0, 0],
#   ['smoked', 7, 7],
#   [',', 0, 0],
#   ['denies', 0, 0],
#   ['any', 0, 0],
#   ['significant', 0, 0],
#   ['alcohol', 1, 1],
#   ['use', 0, 0],
#   [',', 0, 0],
#   ['and', 0, 0],
#   ['lives', 0, 0],
#   ['with', 0, 0],
#   ['her', 0, 0],
#   ['daughter', 5, 0],
#   ['in', 0, 0],
#   ['p', 0, 0],
#   ['##asa', 0, 0],
#   ['##den', 0, 0],
#   ['##a', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '326_Consult-HistoryandPhy.-Neck&BackPain_12': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['is', 0, 0],
#   ['retired', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['married', 0, 0],
#   ['with', 0, 0],
#   ['three', 5, 5],
#   ['grown', 6, 6],
#   ['children', 6, 6],
#   ['.', 0, 0],
#   ['has', 0, 0],
#   ['a', 0, 0],
#   ['high', 0, 0],
#   ['school', 0, 0],
#   ['level', 0, 0],
#   ['education', 0, 0],
#   ['.', 0, 0],
#   ['does', 0, 0],
#   ['not', 0, 0],
#   ['smoke', 7, 7],
#   [',', 0, 0],
#   ['drink', 1, 1],
#   [',', 0, 0],
#   ['or', 0, 0],
#   ['utilize', 0, 0],
#   ['any', 0, 0],
#   ['ill', 3, 0],
#   ['##icit', 4, 4],
#   ['substances', 4, 4],
#   ['.', 0, 0],
#   ['o', 0, 0],
#   ['##s', 0, 0],
#   ['##wes', 0, 0],
#   ['##try', 0, 0],
#   ['pain', 0, 0],
#   ['inventory', 0, 0],
#   [':', 0, 0],
#   ['significant', 0, 0],
#   ['impact', 0, 0],
#   ['on', 0, 0],
#   ['every', 0, 0],
#   ['aspect', 0, 0],
#   ['of', 0, 0],
#   ['her', 0, 0],
#   ['quality', 0, 0],
#   ['of', 0, 0],
#   ['life', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['would', 0, 0],
#   ['like', 0, 0],
#   ['to', 0, 0],
#   ['become', 0, 0],
#   ['more', 0, 0],
#   ['functional', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '38_Consult-HistoryandPhy.-BilateralHipPain_8': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['is', 0, 0],
#   ['married', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['employed', 0, 0],
#   ['as', 0, 0],
#   ['an', 0, 0],
#   ['office', 0, 0],
#   ['manager', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['does', 0, 0],
#   ['smoke', 7, 7],
#   ['cigarettes', 0, 8],
#   [',', 0, 0],
#   ['one', 0, 0],
#   ['pack', 0, 0],
#   ['per', 0, 0],
#   ['day', 0, 0],
#   ['for', 0, 0],
#   ['the', 0, 0],
#   ['last', 0, 0],
#   ['20', 0, 0],
#   ['years', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['consume', 1, 0],
#   ['##s', 2, 0],
#   ['alcohol', 2, 1],
#   ['3', 0, 0],
#   ['to', 0, 0],
#   ['5', 0, 0],
#   ['drinks', 0, 1],
#   ['daily', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['uses', 0, 0],
#   ['no', 0, 0],
#   ['ill', 0, 0],
#   ['##icit', 0, 0],
#   ['drugs', 3, 3],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['exercises', 0, 0],
#   ['monthly', 0, 0],
#   ['mainly', 0, 0],
#   ['walking', 0, 0],
#   ['and', 0, 0],
#   ['low', 0, 0],
#   ['impact', 0, 0],
#   ['a', 0, 0],
#   ['##ero', 0, 0],
#   ['##bic', 0, 0],
#   ['##s', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['also', 0, 0],
#   ['likes', 0, 0],
#   ['to', 0, 0],
#   ['play', 0, 0],
#   ['softball', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '405_Consult-HistoryandPhy.-PainManagementConsult-2_7': [['[CLS]', 0, 0],
#   ['personal', 0, 0],
#   ['and', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['marital', 0, 0],
#   ['status', 0, 0],
#   [':', 0, 0],
#   ['married', 0, 0],
#   ['.', 0, 0],
#   ['smoking', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['smoked', 7, 7],
#   ['1', 0, 0],
#   ['pp', 0, 0],
#   ['##d', 0, 0],
#   [',', 0, 0],
#   ['quit', 0, 0],
#   ['5', 0, 0],
#   ['years', 0, 0],
#   ['ago', 0, 0],
#   ['and', 0, 0],
#   ['after', 0, 0],
#   ['smoking', 0, 0],
#   ['for', 0, 0],
#   ['15', 0, 0],
#   ['years', 0, 0],
#   ['.', 0, 0],
#   ['alcohol', 1, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['drinks', 0, 1],
#   ['socially', 0, 0],
#   ['.', 0, 0],
#   ['denies', 0, 0],
#   ['any', 0, 0],
#   ['history', 0, 0],
#   ['of', 0, 0],
#   ['drug', 3, 3],
#   ['abuse', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '412_Consult-HistoryandPhy.-PeripheralEffusion-Consult_9': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['still', 0, 0],
#   ['smoke', 7, 7],
#   ['##s', 8, 8],
#   [',', 0, 0],
#   ['but', 0, 0],
#   ['less', 0, 0],
#   ['than', 0, 0],
#   ['before', 0, 0],
#   ['.', 0, 0],
#   ['drinks', 1, 1],
#   ['socially', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '419_Consult-HistoryandPhy.-PreopCardiacConsult_9': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['she', 0, 0],
#   ['used', 0, 0],
#   ['to', 0, 0],
#   ['smoke', 0, 7],
#   ['cigarettes', 0, 8],
#   ['and', 0, 0],
#   ['smoked', 7, 7],
#   ['from', 0, 0],
#   ['the', 0, 0],
#   ['age', 0, 0],
#   ['of', 0, 0],
#   ['14', 0, 0],
#   ['to', 0, 0],
#   ['43', 0, 0],
#   ['and', 0, 0],
#   ['quit', 0, 0],
#   ['at', 0, 0],
#   ['the', 0, 0],
#   ['time', 0, 0],
#   ['of', 0, 0],
#   ['her', 0, 0],
#   ['bypass', 0, 0],
#   ['surgery', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['does', 0, 0],
#   ['not', 0, 0],
#   ['drink', 1, 1],
#   ['alcohol', 2, 2],
#   ['nor', 0, 0],
#   ['use', 0, 0],
#   ['ill', 0, 0],
#   ['##icit', 0, 0],
#   ['drugs', 3, 3],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['lives', 0, 0],
#   ['alone', 0, 0],
#   ['and', 0, 0],
#   ['is', 0, 0],
#   ['widowed', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['a', 0, 0],
#   ['retired', 0, 0],
#   ['cu', 0, 0],
#   ['##sto', 0, 0],
#   ['##dian', 0, 0],
#   ['at', 0, 0],
#   ['university', 0, 0],
#   ['.', 0, 0],
#   ['of', 0, 0],
#   ['note', 0, 0],
#   [',', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['accompanied', 0, 0],
#   ['with', 0, 0],
#   ['her', 0, 0],
#   ['verbal', 0, 0],
#   ['consent', 0, 0],
#   ['by', 0, 0],
#   ['her', 0, 0],
#   ['daughter', 0, 5],
#   ['and', 0, 0],
#   ['grandson', 0, 0],
#   ['at', 0, 0],
#   ['the', 0, 0],
#   ['bedside', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '430_Consult-HistoryandPhy.-PsychConsult-Depression-1_9': [['[CLS]', 0, 0],
#   ['substance', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 1, 0],
#   ['has', 0, 0],
#   ['been', 0, 0],
#   ['sober', 0, 0],
#   ['for', 0, 0],
#   ['five', 0, 0],
#   ['years', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['drank', 1, 0],
#   ['one', 0, 0],
#   ['bottle', 0, 0],
#   ['of', 0, 0],
#   ['wine', 0, 0],
#   ['per', 0, 0],
#   ['day', 0, 0],
#   ['as', 0, 0],
#   ['per', 0, 0],
#   ['hp', 0, 0],
#   ['##i', 0, 0],
#   ['.', 0, 0],
#   ['history', 0, 0],
#   ['of', 0, 0],
#   ['drinking', 1, 1],
#   ['for', 0, 0],
#   ['approximately', 0, 0],
#   ['25', 0, 0],
#   ['years', 0, 0],
#   ['.', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['does', 0, 0],
#   ['not', 0, 0],
#   ['currently', 0, 0],
#   ['have', 0, 0],
#   ['a', 0, 0],
#   ['sponsor', 0, 0],
#   ['.', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['experimented', 0, 0],
#   ['with', 0, 0],
#   ['am', 3, 0],
#   ['##phe', 4, 0],
#   ['##tamine', 4, 0],
#   ['##s', 4, 4],
#   [',', 0, 0],
#   ['cocaine', 3, 3],
#   [',', 0, 0],
#   ['marijuana', 3, 3],
#   ['approximately', 0, 0],
#   ['16', 0, 0],
#   ['years', 0, 0],
#   ['ago', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '457_Consult-HistoryandPhy.-RenalFailureEvaluation_8': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['he', 0, 0],
#   ['is', 0, 0],
#   ['married', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['does', 0, 0],
#   ['smoke', 7, 7],
#   ['despite', 0, 0],
#   ['understanding', 0, 0],
#   ['the', 0, 0],
#   ['risks', 0, 0],
#   ['associated', 0, 0],
#   ['with', 0, 0],
#   ['smoking', 0, 7],
#   ['a', 0, 0],
#   ['pack', 0, 0],
#   ['every', 0, 0],
#   ['6', 0, 0],
#   ['days', 0, 0],
#   ['.', 0, 0],
#   ['does', 0, 0],
#   ['not', 0, 0],
#   ['drink', 1, 1],
#   ['alcohol', 2, 2],
#   ['or', 0, 0],
#   ['use', 0, 0],
#   ['any', 0, 0],
#   ['recreational', 0, 0],
#   ['drug', 3, 3],
#   ['use', 4, 4],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['was', 0, 0],
#   ['on', 0, 0],
#   ['no', 0, 0],
#   ['prescribed', 0, 0],
#   ['medications', 0, 0],
#   ['.', 0, 0],
#   ['he', 0, 0],
#   ['did', 0, 0],
#   ['have', 0, 0],
#   ['a', 0, 0],
#   ['fairly', 0, 0],
#   ['normal', 0, 0],
#   ['ps', 0, 0],
#   ['##a', 0, 0],
#   ['of', 0, 0],
#   ['about', 0, 0],
#   ['119', 0, 0],
#   ['and', 0, 0],
#   ['i', 0, 0],
#   ['had', 0, 0],
#   ['ordered', 0, 0],
#   ['a', 0, 0],
#   ['re', 0, 0],
#   ['##nal', 0, 0],
#   ['ultra', 0, 0],
#   ['##sound', 0, 0],
#   ['which', 0, 0],
#   ['showed', 0, 0],
#   ['fairly', 0, 0],
#   ['normal', 0, 0],
#   ['-', 0, 0],
#   ['sized', 0, 0],
#   ['kidney', 0, 0],
#   ['##s', 0, 0],
#   ['and', 0, 0],
#   ['no', 0, 0],
#   ['evidence', 0, 0],
#   ['of', 0, 0],
#   ['h', 0, 0],
#   ['##ydro', 0, 0],
#   ['##ne', 0, 0],
#   ['##ph', 0, 0],
#   ['##rosis', 0, 0],
#   ['or', 0, 0],
#   ['mass', 0, 0],
#   [',', 0, 0],
#   ['but', 0, 0],
#   ['it', 0, 0],
#   ['was', 0, 0],
#   ['consistent', 0, 0],
#   ['with', 0, 0],
#   ['increased', 0, 0],
#   ['echo', 0, 0],
#   ['##genic', 0, 0],
#   ['##ity', 0, 0],
#   ['in', 0, 0],
#   ['the', 0, 0],
#   ['cortex', 0, 0],
#   [',', 0, 0],
#   ['findings', 0, 0],
#   ['representative', 0, 0],
#   ['of', 0, 0],
#   ['medical', 0, 0],
#   ['re', 0, 0],
#   ['##nal', 0, 0],
#   ['disease', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '79_Consult-HistoryandPhy.-ColonPolyps-GeneticCounseling_8': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['is', 0, 0],
#   ['married', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['was', 0, 0],
#   ['born', 0, 0],
#   ['and', 0, 0],
#   ['raised', 0, 0],
#   ['in', 0, 0],
#   ['south', 0, 0],
#   ['da', 0, 0],
#   ['##kot', 0, 0],
#   ['##a', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['moved', 0, 0],
#   ['to', 0, 0],
#   ['color', 0, 0],
#   ['##ado', 0, 0],
#   ['37', 0, 0],
#   ['years', 0, 0],
#   ['ago', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['attended', 0, 0],
#   ['co', 0, 0],
#   ['##lla', 0, 0],
#   ['##ge', 0, 0],
#   ['at', 0, 0],
#   ['the', 0, 0],
#   ['color', 0, 0],
#   ['##ado', 0, 0],
#   ['university', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['certified', 0, 0],
#   ['public', 0, 0],
#   ['account', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['does', 0, 0],
#   ['not', 0, 0],
#   ['smoke', 7, 7],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['drinks', 1, 1],
#   ['socially', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '8_Consult-HistoryandPhy.-AcuteInferiorMyocardialInfarction_7': [['[CLS]',
#    0,
#    0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['denies', 0, 0],
#   ['alcohol', 1, 1],
#   ['or', 0, 0],
#   ['drugs', 3, 3],
#   ['.', 0, 0],
#   ['smoke', 7, 7],
#   ['##s', 8, 8],
#   ['2', 0, 0],
#   ['packs', 0, 0],
#   ['of', 0, 0],
#   ['cigarettes', 0, 0],
#   ['per', 0, 0],
#   ['day', 0, 0],
#   ['.', 0, 0],
#   ['works', 0, 0],
#   ['as', 0, 0],
#   ['a', 0, 0],
#   ['banker', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '185_Consult-HistoryandPhy.-GastrointestinalBleed-ERVisit_10': [['[CLS]',
#    0,
#    0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['a', 0, 0],
#   ['non', 0, 0],
#   ['##smo', 7, 7],
#   ['##ker', 8, 8],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['occasionally', 0, 0],
#   ['has', 0, 0],
#   ['a', 1, 0],
#   ['drink', 2, 1],
#   ['every', 0, 2],
#   ['few', 0, 0],
#   ['weeks', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['divorced', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['has', 0, 0],
#   ['2', 5, 5],
#   ['sons', 6, 6],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['house', 0, 0],
#   ['##par', 0, 0],
#   ['##ent', 0, 0],
#   ['at', 0, 0],
#   ['southern', 0, 0],
#   ['university', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '448_Consult-HistoryandPhy.-PulmonaryEmbolism_9': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['she', 0, 0],
#   ['used', 0, 0],
#   ['to', 0, 0],
#   ['be', 0, 0],
#   ['a', 0, 0],
#   ['smoke', 7, 7],
#   ['##r', 8, 8],
#   [',', 0, 0],
#   ['not', 0, 0],
#   ['anymore', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['drinks', 1, 1],
#   ['2', 0, 2],
#   ['to', 0, 0],
#   ['3', 0, 0],
#   ['glasses', 0, 0],
#   ['of', 0, 0],
#   ['wine', 0, 0],
#   ['per', 0, 0],
#   ['week', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['is', 0, 0],
#   ['retired', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '524_Consult-HistoryandPhy.-AcuteInferiorMyocardialInfarction_7': [['[CLS]',
#    0,
#    0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['denies', 0, 0],
#   ['alcohol', 1, 1],
#   ['or', 0, 0],
#   ['drugs', 3, 3],
#   ['.', 0, 0],
#   ['smoke', 7, 7],
#   ['##s', 8, 8],
#   ['2', 0, 0],
#   ['packs', 0, 0],
#   ['of', 0, 0],
#   ['cigarettes', 0, 0],
#   ['per', 0, 0],
#   ['day', 0, 0],
#   ['.', 0, 0],
#   ['works', 0, 0],
#   ['as', 0, 0],
#   ['a', 0, 0],
#   ['banker', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '256_Consult-HistoryandPhy.-H&P-Nausea&Vomiting_8': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['she', 0, 0],
#   ['has', 0, 0],
#   ['a', 0, 0],
#   ['27', 0, 0],
#   ['pack', 0, 0],
#   ['year', 0, 0],
#   ['smoking', 7, 7],
#   ['history', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['denies', 0, 0],
#   ['any', 0, 0],
#   ['alcohol', 1, 1],
#   ['use', 0, 0],
#   ['.', 0, 0],
#   ['she', 0, 0],
#   ['does', 0, 0],
#   ['have', 0, 0],
#   ['a', 0, 0],
#   ['history', 0, 0],
#   ['of', 0, 0],
#   ['chronic', 0, 0],
#   ['marijuana', 3, 3],
#   ['use', 0, 0],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]],
#  '132_Consult-HistoryandPhy.-DetoxfromHeroin_7': [['[CLS]', 0, 0],
#   ['social', 0, 0],
#   ['history', 0, 0],
#   [':', 0, 0],
#   ['the', 0, 0],
#   ['patient', 0, 0],
#   ['is', 0, 0],
#   ['a', 0, 0],
#   ['smoke', 7, 7],
#   ['##r', 8, 8],
#   ['.', 0, 0],
#   ['admits', 0, 0],
#   ['to', 0, 0],
#   ['heroin', 3, 0],
#   ['use', 0, 0],
#   [',', 0, 0],
#   ['alcohol', 1, 1],
#   ['abuse', 0, 0],
#   ['as', 0, 0],
#   ['well', 0, 0],
#   ['.', 0, 0],
#   ['also', 0, 0],
#   ['admits', 0, 0],
#   ['today', 0, 0],
#   ['using', 0, 0],
#   ['cocaine', 3, 3],
#   ['.', 0, 0],
#   ['[SEP]', 0, 0]]}

# %%
import json
prediction_file_path='/content/drive/MyDrive/PHD_assessment_gmu/data/tst_Flt_ent_role_model_2.json'

# %%
with open(prediction_file_path, 'r', encoding='utf-8') as file:
  prediction_data=json.load( file)

# %%
entity_dict = prediction_data['entity']
role_dict=prediction_data['role']
method_dict=prediction_data['method']
status_dict=prediction_data['status']

# %%
entity_dict['430_Consult-HistoryandPhy.-PsychConsult-Depression-1_9']
# Out:
# [['[CLS]', 0, 0],
#  ['substance', 0, 0],
#  ['history', 0, 0],
#  [':', 0, 0],
#  ['the', 0, 0],
#  ['patient', 1, 0],
#  ['has', 0, 0],
#  ['been', 0, 0],
#  ['sober', 0, 0],
#  ['for', 0, 0],
#  ['five', 0, 0],
#  ['years', 0, 0],
#  ['.', 0, 0],
#  ['she', 0, 0],
#  ['drank', 1, 0],
#  ['one', 0, 0],
#  ['bottle', 0, 0],
#  ['of', 0, 0],
#  ['wine', 0, 0],
#  ['per', 0, 0],
#  ['day', 0, 0],
#  ['as', 0, 0],
#  ['per', 0, 0],
#  ['hp', 0, 0],
#  ['##i', 0, 0],
#  ['.', 0, 0],
#  ['history', 0, 0],
#  ['of', 0, 0],
#  ['drinking', 1, 1],
#  ['for', 0, 0],
#  ['approximately', 0, 0],
#  ['25', 0, 0],
#  ['years', 0, 0],
#  ['.', 0, 0],
#  ['the', 0, 0],
#  ['patient', 0, 0],
#  ['does', 0, 0],
#  ['not', 0, 0],
#  ['currently', 0, 0],
#  ['have', 0, 0],
#  ['a', 0, 0],
#  ['sponsor', 0, 0],
#  ['.', 0, 0],
#  ['the', 0, 0],
#  ['patient', 0, 0],
#  ['experimented', 0, 0],
#  ['with', 0, 0],
#  ['am', 3, 3],
#  ['##phe', 4, 4],
#  ['##tamine', 4, 4],
#  ['##s', 4, 4],
#  [',', 0, 0],
#  ['cocaine', 3, 3],
#  [',', 0, 0],
#  ['marijuana', 3, 3],
#  ['approximately', 0, 0],
#  ['16', 0, 0],
#  ['years', 0, 0],
#  ['ago', 0, 0],
#  ['.', 0, 0],
#  ['[SEP]', 0, 0]]

# %%
train_dataset=torch.load(train_dataset_path)
test_dataset=torch.load(test_dataset_path)

# %%
def extract_spans_from_labels(labels):
    spans = []
    current_span = []
    current_label = None
    last_valid_index = -1  # Tracks the last index of a non-'O' label

    for i, label in enumerate(labels):
        # Ignore BIO scheme and consider only the entity type
        simplified_label = label[2:] if label.startswith(('B-', 'I-')) else label

        # Start a new span or continue the current one
        if simplified_label != 'O':
            # If starting a new span or within allowable break from last non-'O'
            if current_label is None or simplified_label != current_label or i - last_valid_index > 3:
                # Save the current span before starting a new one and reset the current span
                if current_span:
                    spans.append((current_label, current_span))
                    current_span = []
                current_label = simplified_label
            current_span.append(i)
            last_valid_index = i
        elif current_span and i - last_valid_index > 3:
            # End the current span if the break is too long
            spans.append((current_label, current_span))
            current_span = []
            current_label = None

    # Add the last span if exists
    if current_span:
        spans.append((current_label, current_span))

    return spans

# %%
def correct_span_positions(span_pos):
  updated_span_pos=[]
  for ele in span_pos:
    if len(ele[1])==1:
      updated_span_pos.append((ele[0],(ele[1][0],ele[1][0])))
    elif len(ele[1])>=2:
      strt_pos=ele[1][0]
      end_pos=ele[1][-1]
      updated_span_pos.append((ele[0],(ele[1][0],ele[1][-1])))
  return updated_span_pos
def convert_id_label(prediction_data,id_label):
  prediction_data=[id_label[ele[2]] for ele in prediction_data]
  return prediction_data
def generate_prediction_spans(prediction_data_ent,prediction_data_role,prediction_data_status,prediction_data_method,id_label_ent,id_label_method,id_label_role,id_label_status):
  prediction_data_ent=convert_id_label(prediction_data_ent,id_label_ent)
  prediction_data_role=convert_id_label(prediction_data_role,id_label_role)
  prediction_data_method=convert_id_label(prediction_data_method,id_label_method)
  prediction_data_status=convert_id_label(prediction_data_status,id_label_status)
  pred_spans_ent=extract_spans_from_labels(prediction_data_ent)
  pred_spans_roles=extract_spans_from_labels(prediction_data_role)
  pred_spans_status=extract_spans_from_labels(prediction_data_status)
  pred_spans_method=extract_spans_from_labels(prediction_data_method)
  pred_spans_ent=correct_span_positions(pred_spans_ent)
  pred_spans_roles=correct_span_positions(pred_spans_roles)
  pred_spans_status=correct_span_positions(pred_spans_status)
  pred_spans_method=correct_span_positions(pred_spans_method)
  relation_pairs=list(itertools.product(pred_spans_ent, pred_spans_roles))
  relation_pairs.extend(list(itertools.product(pred_spans_ent, pred_spans_status)))
  relation_pairs.extend(list(itertools.product(pred_spans_ent, pred_spans_method)))
  relation_pair_labels_dict = {key: 'No Relation' for key in relation_pairs}
  return pred_spans_ent,pred_spans_roles,pred_spans_status,pred_spans_method,relation_pair_labels_dict
def insert_span_markers(text, spans):
    # Create a list to store the markers that need to be inserted at each index
    insertions = {i: [] for i in range(len(text) + 1)}

    # Populate the insertions dictionary with the correct markers for each span
    sp_cnt=0
    for span in spans:
        sp_cnt=sp_cnt+1
        start, end, category = span
        start=int(start)
        end=int(end)
        insertions[start].append('[SPAN'+str(sp_cnt)+'_START]')
        insertions[end].append('[SPAN'+str(sp_cnt)+'_END]')
        '''
        if category == 'entity':
            insertions[start].append('[SPAN1_START]')
            insertions[end].append('[SPAN1_END]')
        elif category == 'role':
            insertions[start].append('[SPAN2_START]')
            insertions[end].append('[SPAN2_END]')
        '''
    # Construct the new text with markers
    new_text_pieces = []
    for i, char in enumerate(text):
        # Add markers before the current character
        if insertions[i]:
            new_text_pieces.append(' '+' '.join(insertions[i]) + ' ')
        new_text_pieces.append(char)
    # Add any markers that should be inserted after the last character
    if insertions[len(text)]:
        new_text_pieces.append(' ' + ' '.join(insertions[len(text)]))

    # Join all pieces of the new text
    return ''.join(new_text_pieces)

# %%
def generate_relation_prediction_data(sentence,file_name,tokenizer_outputs,relation_pair_labels_dict):
  data_input_list=[]
  offset_mapping_list=tokenizer_outputs['offset_mapping']
  for pair,pair_label in relation_pair_labels_dict.items():
    entity_pos=[]
    entity_pos.append(offset_mapping_list[pair[0][1][0]][0])
    entity_pos.append(offset_mapping_list[pair[0][1][1]][1])
    entity_pos.append('entity')
    role_pos=[]
    role_pos.append(offset_mapping_list[pair[1][1][0]][0])
    role_pos.append(offset_mapping_list[pair[1][1][1]][1])
    role_pos.append('role')
    marked_sentence = insert_span_markers(sentence,[entity_pos,role_pos])
    data_input_list.append({'file_name':file_name,'text':marked_sentence,'Entity':pair[0][0],'Role':pair[1][0],'label':pair_label})
  return data_input_list

# %%
def preparing_relation_labels(relation_labels,pred_spans_ent,pred_spans_roles,pred_spans_status,pred_spans_method,relation_pair_labels_dict):
  identified_relations_cnt=0
  print(len(relation_pair_labels_dict))
  print(pred_spans_ent)
  for span in pred_spans_ent:
    start_token_index=span[1][0]
    end_token_index=span[1][1]
    print('pes:',span)
    for keys,values in relation_labels.items():
      rel_start_token_ind=keys[0]
      rel_end_token_ind=keys[1]
      print('--------------------------------------------------')
      print('Entity')
      print('rlb:',rel_start_token_ind)
      print('rlb:',rel_end_token_ind)
      if (start_token_index>=rel_start_token_ind-2 and end_token_index<=rel_end_token_ind+2) or (rel_start_token_ind>=start_token_index-2 and rel_end_token_ind<=end_token_index):
        print('Entity Match')
        for ele in values:
          print('################')
          print('Role')
          print('rle:',ele)
          print('ppppppppp')
          if ele[2]=='Status':
            print('preictionspans_list:',pred_spans_status)
            for status_span in pred_spans_status:
              print('prs:',status_span)
              if (status_span[1][0]>=ele[0]-2 and status_span[1][1]<=ele[1]+2) or ((ele[0]>=status_span[1][0]-2 and ele[1]+2<=status_span[1][1])):
                pair_key=((span[0], (start_token_index, end_token_index)), (status_span[0], (status_span[1][0], status_span[1][1])))

                relation_pair_labels_dict[pair_key]='Relation'

                print('Match')
                identified_relations_cnt += 1
                #break
          elif ele[2]=='Method':
            for method_span in pred_spans_method:
              print('prs:',method_span)
              if (method_span[1][0]>=ele[0]-2 and method_span[1][1]<=ele[1]+2) or ((ele[0]>=method_span[1][0]-2 and ele[1]+2<=method_span[1][1])):
                pair_key=((span[0], (start_token_index, end_token_index)), (method_span[0], (method_span[1][0], method_span[1][1])))

                relation_pair_labels_dict[pair_key]='Relation'
                print('Match')
                identified_relations_cnt += 1
                #break
          else:

            print(pred_spans_roles)
            for role_span in pred_spans_roles:
              print('prs:',role_span)
              if (role_span[1][0]>=ele[0]-2 and role_span[1][1]<=ele[1]+2) or ((ele[0]>=role_span[1][0]-2 and ele[1]+2<=role_span[1][1])):
                pair_key=((span[0], (start_token_index, end_token_index)), (role_span[0], (role_span[1][0], role_span[1][1])))

                relation_pair_labels_dict[pair_key]='Relation'

                print('Match')
                identified_relations_cnt += 1
                #break
        break

  print(relation_pair_labels_dict)
  return relation_pair_labels_dict, identified_relations_cnt



def generate_relation_data(text,file_name,prediction_data_ent,prediction_data_role,prediction_data_status,prediction_data_method,id_label_ent,id_label_method,id_label_role,id_label_status,relation_labels=None):
  inputs = tokenizer(text,max_length=max_len,truncation=True,return_offsets_mapping=True)

  tokens_len=len(inputs['input_ids'])
  if tokens_len==len(prediction_data_ent):
    pred_spans_ent,pred_spans_roles,pred_spans_status,pred_spans_method,relation_pair_labels_dict=generate_prediction_spans(prediction_data_ent,prediction_data_role,prediction_data_status,prediction_data_method,id_label_ent,id_label_method,id_label_role,id_label_status)
    if relation_labels:
      present_relation_label_cnt=0
      for e,r in relation_labels.items():
        present_relation_label_cnt += len(r)
      relation_pair_labels_dict,identified_relations_cnt=preparing_relation_labels(relation_labels,pred_spans_ent,pred_spans_roles,pred_spans_status,pred_spans_method,relation_pair_labels_dict)
      relation_data=generate_relation_prediction_data(text,file_name,inputs,relation_pair_labels_dict)
      return relation_data,present_relation_label_cnt,identified_relations_cnt,present_relation_label_cnt-identified_relations_cnt
    else:
      relation_data=generate_relation_prediction_data(text,file_name,inputs,relation_pair_labels_dict)
      return relation_data
  else:
    return None,None

# %%
flnm='259_Consult-HistoryandPhy.-Head&NeckCancerConsult_9'
rlb=''
t=''
for tst_doc in test_dataset:
  if tst_doc['file_name']==flnm:
    rlb=tst_doc['relation_labels']
    t=tst_doc['text']

# %%
t
# Out:
# 'SOCIAL HISTORY:  The patient is married but has been separated from his wife for many years, they remain close, and they have two adult sons. He is retired from the Air Force, currently works for Lockheed Martin. He was born and raised in New York. He does have a smoking history, about a 20 pack-year history and he reports quitting on July 27. He does drink alcohol socially. No use of illicit drugs.\n\n'

# %%
rlb
# Out:
# {(26, 28, 'Family'): [(27, 28, 'Type'), (26, 26, 'Amount')],
#  (84, 86, 'Alcohol'): [(84, 85, 'Status'), (87, 87, 'Amount')],
#  (94, 94, 'Drug'): [(92, 93, 'Type'), (89, 90, 'Status')],
#  (62, 62, 'Tobacco'): [(67, 70, 'Amount'),
#   (74, 81, 'Status'),
#   (78, 81, 'QuitHistory')]}

# %%
rel_dt_lst1,rel_present1,identified_rel1,missed_rel_perc1=generate_relation_data(t,flnm,entity_dict[flnm],role_dict[flnm],status_dict[flnm],method_dict[flnm],id_label_ent,id_label_method,id_label_role,id_label_status,relation_labels=rlb)
# Out:
# 120
# [('Family', (14, 14)), ('Family', (26, 28)), ('Tobacco', (62, 62)), ('Alcohol', (86, 86)), ('Drug', (94, 94))]
# pes: ('Family', (14, 14))
# --------------------------------------------------
# Entity
# rlb: 26
# rlb: 28
# --------------------------------------------------
# Entity
# rlb: 84
# rlb: 86
# --------------------------------------------------
# Entity
# rlb: 94
# rlb: 94
# --------------------------------------------------
# Entity
# rlb: 62
# rlb: 62
# pes: ('Family', (26, 28))
# --------------------------------------------------
# Entity
# rlb: 26
# rlb: 28
# Entity Match
# ################
# Role
# rle: (27, 28, 'Type')
# ppppppppp
# [('Type', (7, 7)), ('Type', (14, 14)), ('Temporal', (15, 17)), ('Amount', (26, 26)), ('Type', (27, 28)), ('Location', (35, 36)), ('Location', (41, 46)), ('Location', (54, 56)), ('Amount', (67, 70)), ('Location', (80, 80)), ('Amount', (87, 87)), ('Type', (92, 93))]
# prs: ('Type', (7, 7))
# prs: ('Type', (14, 14))
# prs: ('Temporal', (15, 17))
# prs: ('Amount', (26, 26))
# Match
# prs: ('Type', (27, 28))
# Match
# prs: ('Location', (35, 36))
# prs: ('Location', (41, 46))
# prs: ('Location', (54, 56))
# prs: ('Amount', (67, 70))
# prs: ('Location', (80, 80))
# prs: ('Amount', (87, 87))
# prs: ('Type', (92, 93))
# ################
# Role
# rle: (26, 26, 'Amount')
# ppppppppp
# [('Type', (7, 7)), ('Type', (14, 14)), ('Temporal', (15, 17)), ('Amount', (26, 26)), ('Type', (27, 28)), ('Location', (35, 36)), ('Location', (41, 46)), ('Location', (54, 56)), ('Amount', (67, 70)), ('Location', (80, 80)), ('Amount', (87, 87)), ('Type', (92, 93))]
# prs: ('Type', (7, 7))
# prs: ('Type', (14, 14))
# prs: ('Temporal', (15, 17))
# prs: ('Amount', (26, 26))
# Match
# prs: ('Type', (27, 28))
# Match
# prs: ('Location', (35, 36))
# prs: ('Location', (41, 46))
# prs: ('Location', (54, 56))
# prs: ('Amount', (67, 70))
# prs: ('Location', (80, 80))
# prs: ('Amount', (87, 87))
# prs: ('Type', (92, 93))
# pes: ('Tobacco', (62, 62))
# --------------------------------------------------
# Entity
# rlb: 26
# rlb: 28
# --------------------------------------------------
# Entity
# rlb: 84
# rlb: 86
# --------------------------------------------------
# Entity
# rlb: 94
# rlb: 94
# --------------------------------------------------
# Entity
# rlb: 62
# rlb: 62
# Entity Match
# ################
# Role
# rle: (67, 70, 'Amount')
# ppppppppp
# [('Type', (7, 7)), ('Type', (14, 14)), ('Temporal', (15, 17)), ('Amount', (26, 26)), ('Type', (27, 28)), ('Location', (35, 36)), ('Location', (41, 46)), ('Location', (54, 56)), ('Amount', (67, 70)), ('Location', (80, 80)), ('Amount', (87, 87)), ('Type', (92, 93))]
# prs: ('Type', (7, 7))
# prs: ('Type', (14, 14))
# prs: ('Temporal', (15, 17))
# prs: ('Amount', (26, 26))
# prs: ('Type', (27, 28))
# prs: ('Location', (35, 36))
# prs: ('Location', (41, 46))
# prs: ('Location', (54, 56))
# prs: ('Amount', (67, 70))
# Match
# prs: ('Location', (80, 80))
# prs: ('Amount', (87, 87))
# prs: ('Type', (92, 93))
# ################
# Role
# rle: (74, 81, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (6, 6)), ('Status', (31, 31)), ('Status', (38, 38)), ('Status', (49, 49)), ('Status', (62, 62)), ('Status', (75, 76)), ('Status', (84, 85)), ('Status', (89, 90))]
# prs: ('Status', (6, 6))
# prs: ('Status', (31, 31))
# prs: ('Status', (38, 38))
# prs: ('Status', (49, 49))
# prs: ('Status', (62, 62))
# prs: ('Status', (75, 76))
# Match
# prs: ('Status', (84, 85))
# prs: ('Status', (89, 90))
# ################
# Role
# rle: (78, 81, 'QuitHistory')
# ppppppppp
# [('Type', (7, 7)), ('Type', (14, 14)), ('Temporal', (15, 17)), ('Amount', (26, 26)), ('Type', (27, 28)), ('Location', (35, 36)), ('Location', (41, 46)), ('Location', (54, 56)), ('Amount', (67, 70)), ('Location', (80, 80)), ('Amount', (87, 87)), ('Type', (92, 93))]
# prs: ('Type', (7, 7))
# prs: ('Type', (14, 14))
# prs: ('Temporal', (15, 17))
# prs: ('Amount', (26, 26))
# prs: ('Type', (27, 28))
# prs: ('Location', (35, 36))
# prs: ('Location', (41, 46))
# prs: ('Location', (54, 56))
# prs: ('Amount', (67, 70))
# prs: ('Location', (80, 80))
# Match
# prs: ('Amount', (87, 87))
# prs: ('Type', (92, 93))
# pes: ('Alcohol', (86, 86))
# --------------------------------------------------
# Entity
# rlb: 26
# rlb: 28
# --------------------------------------------------
# Entity
# rlb: 84
# rlb: 86
# Entity Match
# ################
# Role
# rle: (84, 85, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (6, 6)), ('Status', (31, 31)), ('Status', (38, 38)), ('Status', (49, 49)), ('Status', (62, 62)), ('Status', (75, 76)), ('Status', (84, 85)), ('Status', (89, 90))]
# prs: ('Status', (6, 6))
# prs: ('Status', (31, 31))
# prs: ('Status', (38, 38))
# prs: ('Status', (49, 49))
# prs: ('Status', (62, 62))
# prs: ('Status', (75, 76))
# prs: ('Status', (84, 85))
# Match
# prs: ('Status', (89, 90))
# ################
# Role
# rle: (87, 87, 'Amount')
# ppppppppp
# [('Type', (7, 7)), ('Type', (14, 14)), ('Temporal', (15, 17)), ('Amount', (26, 26)), ('Type', (27, 28)), ('Location', (35, 36)), ('Location', (41, 46)), ('Location', (54, 56)), ('Amount', (67, 70)), ('Location', (80, 80)), ('Amount', (87, 87)), ('Type', (92, 93))]
# prs: ('Type', (7, 7))
# prs: ('Type', (14, 14))
# prs: ('Temporal', (15, 17))
# prs: ('Amount', (26, 26))
# prs: ('Type', (27, 28))
# prs: ('Location', (35, 36))
# prs: ('Location', (41, 46))
# prs: ('Location', (54, 56))
# prs: ('Amount', (67, 70))
# prs: ('Location', (80, 80))
# prs: ('Amount', (87, 87))
# Match
# prs: ('Type', (92, 93))
# pes: ('Drug', (94, 94))
# --------------------------------------------------
# Entity
# rlb: 26
# rlb: 28
# --------------------------------------------------
# Entity
# rlb: 84
# rlb: 86
# --------------------------------------------------
# Entity
# rlb: 94
# rlb: 94
# Entity Match
# ################
# Role
# rle: (92, 93, 'Type')
# ppppppppp
# [('Type', (7, 7)), ('Type', (14, 14)), ('Temporal', (15, 17)), ('Amount', (26, 26)), ('Type', (27, 28)), ('Location', (35, 36)), ('Location', (41, 46)), ('Location', (54, 56)), ('Amount', (67, 70)), ('Location', (80, 80)), ('Amount', (87, 87)), ('Type', (92, 93))]
# prs: ('Type', (7, 7))
# prs: ('Type', (14, 14))
# prs: ('Temporal', (15, 17))
# prs: ('Amount', (26, 26))
# prs: ('Type', (27, 28))
# prs: ('Location', (35, 36))
# prs: ('Location', (41, 46))
# prs: ('Location', (54, 56))
# prs: ('Amount', (67, 70))
# prs: ('Location', (80, 80))
# prs: ('Amount', (87, 87))
# prs: ('Type', (92, 93))
# Match
# ################
# Role
# rle: (89, 90, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (6, 6)), ('Status', (31, 31)), ('Status', (38, 38)), ('Status', (49, 49)), ('Status', (62, 62)), ('Status', (75, 76)), ('Status', (84, 85)), ('Status', (89, 90))]
# prs: ('Status', (6, 6))
# prs: ('Status', (31, 31))
# prs: ('Status', (38, 38))
# prs: ('Status', (49, 49))
# prs: ('Status', (62, 62))
# prs: ('Status', (75, 76))
# prs: ('Status', (84, 85))
# prs: ('Status', (89, 90))
# Match
# {(('Family', (14, 14)), ('Type', (7, 7))): 'No Relation', (('Family', (14, 14)), ('Type', (14, 14))): 'No Relation', (('Family', (14, 14)), ('Temporal', (15, 17))): 'No Relation', (('Family', (14, 14)), ('Amount', (26, 26))): 'No Relation', (('Family', (14, 14)), ('Type', (27, 28))): 'No Relation', (('Family', (14, 14)), ('Location', (35, 36))): 'No Relation', (('Family', (14, 14)), ('Location', (41, 46))): 'No Relation', (('Family', (14, 14)), ('Location', (54, 56))): 'No Relation', (('Family', (14, 14)), ('Amount', (67, 70))): 'No Relation', (('Family', (14, 14)), ('Location', (80, 80))): 'No Relation', (('Family', (14, 14)), ('Amount', (87, 87))): 'No Relation', (('Family', (14, 14)), ('Type', (92, 93))): 'No Relation', (('Family', (26, 28)), ('Type', (7, 7))): 'No Relation', (('Family', (26, 28)), ('Type', (14, 14))): 'No Relation', (('Family', (26, 28)), ('Temporal', (15, 17))): 'No Relation', (('Family', (26, 28)), ('Amount', (26, 26))): 'Relation', (('Family', (26, 28)), ('Type', (27, 28))): 'Relation', (('Family', (26, 28)), ('Location', (35, 36))): 'No Relation', (('Family', (26, 28)), ('Location', (41, 46))): 'No Relation', (('Family', (26, 28)), ('Location', (54, 56))): 'No Relation', (('Family', (26, 28)), ('Amount', (67, 70))): 'No Relation', (('Family', (26, 28)), ('Location', (80, 80))): 'No Relation', (('Family', (26, 28)), ('Amount', (87, 87))): 'No Relation', (('Family', (26, 28)), ('Type', (92, 93))): 'No Relation', (('Tobacco', (62, 62)), ('Type', (7, 7))): 'No Relation', (('Tobacco', (62, 62)), ('Type', (14, 14))): 'No Relation', (('Tobacco', (62, 62)), ('Temporal', (15, 17))): 'No Relation', (('Tobacco', (62, 62)), ('Amount', (26, 26))): 'No Relation', (('Tobacco', (62, 62)), ('Type', (27, 28))): 'No Relation', (('Tobacco', (62, 62)), ('Location', (35, 36))): 'No Relation', (('Tobacco', (62, 62)), ('Location', (41, 46))): 'No Relation', (('Tobacco', (62, 62)), ('Location', (54, 56))): 'No Relation', (('Tobacco', (62, 62)), ('Amount', (67, 70))): 'Relation', (('Tobacco', (62, 62)), ('Location', (80, 80))): 'Relation', (('Tobacco', (62, 62)), ('Amount', (87, 87))): 'No Relation', (('Tobacco', (62, 62)), ('Type', (92, 93))): 'No Relation', (('Alcohol', (86, 86)), ('Type', (7, 7))): 'No Relation', (('Alcohol', (86, 86)), ('Type', (14, 14))): 'No Relation', (('Alcohol', (86, 86)), ('Temporal', (15, 17))): 'No Relation', (('Alcohol', (86, 86)), ('Amount', (26, 26))): 'No Relation', (('Alcohol', (86, 86)), ('Type', (27, 28))): 'No Relation', (('Alcohol', (86, 86)), ('Location', (35, 36))): 'No Relation', (('Alcohol', (86, 86)), ('Location', (41, 46))): 'No Relation', (('Alcohol', (86, 86)), ('Location', (54, 56))): 'No Relation', (('Alcohol', (86, 86)), ('Amount', (67, 70))): 'No Relation', (('Alcohol', (86, 86)), ('Location', (80, 80))): 'No Relation', (('Alcohol', (86, 86)), ('Amount', (87, 87))): 'Relation', (('Alcohol', (86, 86)), ('Type', (92, 93))): 'No Relation', (('Drug', (94, 94)), ('Type', (7, 7))): 'No Relation', (('Drug', (94, 94)), ('Type', (14, 14))): 'No Relation', (('Drug', (94, 94)), ('Temporal', (15, 17))): 'No Relation', (('Drug', (94, 94)), ('Amount', (26, 26))): 'No Relation', (('Drug', (94, 94)), ('Type', (27, 28))): 'No Relation', (('Drug', (94, 94)), ('Location', (35, 36))): 'No Relation', (('Drug', (94, 94)), ('Location', (41, 46))): 'No Relation', (('Drug', (94, 94)), ('Location', (54, 56))): 'No Relation', (('Drug', (94, 94)), ('Amount', (67, 70))): 'No Relation', (('Drug', (94, 94)), ('Location', (80, 80))): 'No Relation', (('Drug', (94, 94)), ('Amount', (87, 87))): 'No Relation', (('Drug', (94, 94)), ('Type', (92, 93))): 'Relation', (('Family', (14, 14)), ('Status', (6, 6))): 'No Relation', (('Family', (14, 14)), ('Status', (31, 31))): 'No Relation', (('Family', (14, 14)), ('Status', (38, 38))): 'No Relation', (('Family', (14, 14)), ('Status', (49, 49))): 'No Relation', (('Family', (14, 14)), ('Status', (62, 62))): 'No Relation', (('Family', (14, 14)), ('Status', (75, 76))): 'No Rela ...

# %%
rlb
# Out:
# {(15, 16, 'Family'): [(15, 16, 'Type'), (15, 15, 'Amount')],
#  (19, 20, 'Tobacco'): [(19, 19, 'Status'),
#   (21, 23, 'QuitHistory'),
#   (26, 31, 'ExposureHistory')],
#  (36, 37, 'Alcohol'): [(34, 35, 'Status')]}

# %%
relation_df1=pd.DataFrame(rel_dt_lst1)
relation_df1['predict_relation']=relation_df1['text'].apply(predict_relation)
relation_df1[relation_df1['label']!=relation_df1['predict_relation']]
# Out:
#                                            file_name  \
# 4  285_Consult-HistoryandPhy.-IschemicCecum-Consu...
#
#                                                 text   Entity    Role  \
# 4  SOCIAL HISTORY:  The patient had a long  [SPAN...  Tobacco  Status
#
#          label predict_relation
# 4  No Relation         Relation

# %%
relation_df1[relation_df1['label']!=relation_df1['predict_relation']]['text'].iloc[0]
# Out:
# 'SOCIAL HISTORY:  The patient had a long  [SPAN2_START] history of [SPAN2_END]   [SPAN1_START] smoking [SPAN1_END]  but quit many years ago. He does have chronic alcohol use.\n\n'

# %%
relation_data_list=[]
missed_rel_perc_list=[]
identified_all_rel_doc=[]
total_missed_rel=0
total_relations_present=0
for tst_doc in test_dataset:
  rel_dt_lst,rel_present,identified_rel,missed_rel_perc=generate_relation_data(tst_doc['text'],tst_doc['file_name'],entity_dict[tst_doc['file_name']],role_dict[tst_doc['file_name']],status_dict[tst_doc['file_name']],method_dict[tst_doc['file_name']],id_label_ent,id_label_method,id_label_role,id_label_status,relation_labels=tst_doc['relation_labels'])
  if rel_dt_lst:
    #if missed_rel_perc<0:
    # missed_rel_perc=0
    relation_data_list.extend(rel_dt_lst)
    total_missed_rel += missed_rel_perc
    total_relations_present += rel_present
    if missed_rel_perc>0:
      missed_rel_perc_list.append([tst_doc['file_name'],rel_present,missed_rel_perc])
    elif missed_rel_perc==0:
      identified_all_rel_doc.append([tst_doc['file_name'],rel_present,identified_rel])
# Out:
# 27
# [('Family', (15, 16)), ('Tobacco', (20, 20)), ('Alcohol', (36, 37))]
# pes: ('Family', (15, 16))
# --------------------------------------------------
# Entity
# rlb: 15
# rlb: 16
# Entity Match
# ################
# Role
# rle: (15, 16, 'Type')
# ppppppppp
# [('Type', (11, 11)), ('Amount', (15, 15)), ('Type', (16, 16)), ('QuitHistory', (21, 23)), ('ExposureHistory', (26, 28))]
# prs: ('Type', (11, 11))
# prs: ('Amount', (15, 15))
# Match
# prs: ('Type', (16, 16))
# Match
# prs: ('QuitHistory', (21, 23))
# prs: ('ExposureHistory', (26, 28))
# ################
# Role
# rle: (15, 15, 'Amount')
# ppppppppp
# [('Type', (11, 11)), ('Amount', (15, 15)), ('Type', (16, 16)), ('QuitHistory', (21, 23)), ('ExposureHistory', (26, 28))]
# prs: ('Type', (11, 11))
# prs: ('Amount', (15, 15))
# Match
# prs: ('Type', (16, 16))
# Match
# prs: ('QuitHistory', (21, 23))
# prs: ('ExposureHistory', (26, 28))
# pes: ('Tobacco', (20, 20))
# --------------------------------------------------
# Entity
# rlb: 15
# rlb: 16
# --------------------------------------------------
# Entity
# rlb: 19
# rlb: 20
# Entity Match
# ################
# Role
# rle: (19, 19, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (6, 6)), ('Status', (10, 10)), ('Status', (34, 35))]
# prs: ('Status', (6, 6))
# prs: ('Status', (10, 10))
# prs: ('Status', (34, 35))
# ################
# Role
# rle: (21, 23, 'QuitHistory')
# ppppppppp
# [('Type', (11, 11)), ('Amount', (15, 15)), ('Type', (16, 16)), ('QuitHistory', (21, 23)), ('ExposureHistory', (26, 28))]
# prs: ('Type', (11, 11))
# prs: ('Amount', (15, 15))
# prs: ('Type', (16, 16))
# prs: ('QuitHistory', (21, 23))
# Match
# prs: ('ExposureHistory', (26, 28))
# ################
# Role
# rle: (26, 31, 'ExposureHistory')
# ppppppppp
# [('Type', (11, 11)), ('Amount', (15, 15)), ('Type', (16, 16)), ('QuitHistory', (21, 23)), ('ExposureHistory', (26, 28))]
# prs: ('Type', (11, 11))
# prs: ('Amount', (15, 15))
# prs: ('Type', (16, 16))
# prs: ('QuitHistory', (21, 23))
# prs: ('ExposureHistory', (26, 28))
# Match
# pes: ('Alcohol', (36, 37))
# --------------------------------------------------
# Entity
# rlb: 15
# rlb: 16
# --------------------------------------------------
# Entity
# rlb: 19
# rlb: 20
# --------------------------------------------------
# Entity
# rlb: 36
# rlb: 37
# Entity Match
# ################
# Role
# rle: (34, 35, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (6, 6)), ('Status', (10, 10)), ('Status', (34, 35))]
# prs: ('Status', (6, 6))
# prs: ('Status', (10, 10))
# prs: ('Status', (34, 35))
# Match
# {(('Family', (15, 16)), ('Type', (11, 11))): 'No Relation', (('Family', (15, 16)), ('Amount', (15, 15))): 'Relation', (('Family', (15, 16)), ('Type', (16, 16))): 'Relation', (('Family', (15, 16)), ('QuitHistory', (21, 23))): 'No Relation', (('Family', (15, 16)), ('ExposureHistory', (26, 28))): 'No Relation', (('Tobacco', (20, 20)), ('Type', (11, 11))): 'No Relation', (('Tobacco', (20, 20)), ('Amount', (15, 15))): 'No Relation', (('Tobacco', (20, 20)), ('Type', (16, 16))): 'No Relation', (('Tobacco', (20, 20)), ('QuitHistory', (21, 23))): 'Relation', (('Tobacco', (20, 20)), ('ExposureHistory', (26, 28))): 'Relation', (('Alcohol', (36, 37)), ('Type', (11, 11))): 'No Relation', (('Alcohol', (36, 37)), ('Amount', (15, 15))): 'No Relation', (('Alcohol', (36, 37)), ('Type', (16, 16))): 'No Relation', (('Alcohol', (36, 37)), ('QuitHistory', (21, 23))): 'No Relation', (('Alcohol', (36, 37)), ('ExposureHistory', (26, 28))): 'No Relation', (('Family', (15, 16)), ('Status', (6, 6))): 'No Relation', (('Family', (15, 16)), ('Status', (10, 10))): 'No Relation', (('Family', (15, 16)), ('Status', (34, 35))): 'No Relation', (('Tobacco', (20, 20)), ('Status', (6, 6))): 'No Relation', (('Tobacco', (20, 20)), ('Status', (10, 10))): 'No Relation', (('Tobacco', (20, 20)), ('Status', (34, 35))): 'No Relation', (('Alcohol', (36, 37)), ('Status', (6, 6))): 'No Relation', (('Alcohol', (36, 37)), ('Status', (10, 10))): 'No Relation', (('Alcohol', (36, 37)), ('Status', (34, 35))): 'Relation', (('Family', (15, 16)), ('Method', (7, 7))): 'No Relation', (('Tobacco', (20, 20)), ('Method', (7, 7))): 'No Relation', (('Alcohol', (36, 37)), ('Method', (7, 7))): 'No Relation'}
# 21
# [('Tobacco', (9, 10)), ('Drug', (19, 19)), ('Alcohol', (35, 35))]
# pes: ('Tobacco', (9, 10))
# --------------------------------------------------
# Entity
# rlb: 9
# rlb: 10
# Entity Match
# ################
# Role
# rle: (8, 8, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (8, 8)), ('Status', (33, 34))]
# prs: ('Status', (8, 8))
# Match
# prs: ('Status', (33, 34))
# ################
# Role
# rle: (14, 15, 'QuitHistory')
# ppppppppp
# [('QuitHistory', (14, 15)), ('Type', (19, 19)), ('QuitHistory', (26, 27)), ('Amount', (36, 36)), ('QuitHistory', (41, 45))]
# prs: ('QuitHistory', (14, 15))
# Match
# prs: ('Type', (19, 19))
# prs: ('QuitHistory', (26, 27))
# prs: ('Amount', (36, 36))
# prs: ('QuitHistory', (41, 45))
# pes: ('Drug', (19, 19))
# --------------------------------------------------
# Entity
# rlb: 9
# rlb: 10
# --------------------------------------------------
# Entity
# rlb: 19
# rlb: 19
# Entity Match
# ################
# Role
# rle: (19, 19, 'Type')
# ppppppppp
# [('QuitHistory', (14, 15)), ('Type', (19, 19)), ('QuitHistory', (26, 27)), ('Amount', (36, 36)), ('QuitHistory', (41, 45))]
# prs: ('QuitHistory', (14, 15))
# prs: ('Type', (19, 19))
# Match
# prs: ('QuitHistory', (26, 27))
# prs: ('Amount', (36, 36))
# prs: ('QuitHistory', (41, 45))
# ################
# Role
# rle: (20, 22, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (8, 8)), ('Status', (33, 34))]
# prs: ('Status', (8, 8))
# prs: ('Status', (33, 34))
# ################
# Role
# rle: (26, 27, 'QuitHistory')
# ppppppppp
# [('QuitHistory', (14, 15)), ('Type', (19, 19)), ('QuitHistory', (26, 27)), ('Amount', (36, 36)), ('QuitHistory', (41, 45))]
# prs: ('QuitHistory', (14, 15))
# prs: ('Type', (19, 19))
# prs: ('QuitHistory', (26, 27))
# Match
# prs: ('Amount', (36, 36))
# prs: ('QuitHistory', (41, 45))
# pes: ('Alcohol', (35, 35))
# --------------------------------------------------
# Entity
# rlb: 9
# rlb: 10
# --------------------------------------------------
# Entity
# rlb: 19
# rlb: 19
# --------------------------------------------------
# Entity
# rlb: 35
# rlb: 35
# Entity Match
# ################
# Role
# rle: (36, 36, 'Amount')
# ppppppppp
# [('QuitHistory', (14, 15)), ('Type', (19, 19)), ('QuitHistory', (26, 27)), ('Amount', (36, 36)), ('QuitHistory', (41, 45))]
# prs: ('QuitHistory', (14, 15))
# prs: ('Type', (19, 19))
# prs: ('QuitHistory', (26, 27))
# prs: ('Amount', (36, 36))
# Match
# prs: ('QuitHistory', (41, 45))
# ################
# Role
# rle: (33, 34, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (8, 8)), ('Status', (33, 34))]
# prs: ('Status', (8, 8))
# prs: ('Status', (33, 34))
# Match
# ################
# Role
# rle: (41, 45, 'QuitHistory')
# ppppppppp
# [('QuitHistory', (14, 15)), ('Type', (19, 19)), ('QuitHistory', (26, 27)), ('Amount', (36, 36)), ('QuitHistory', (41, 45))]
# prs: ('QuitHistory', (14, 15))
# prs: ('Type', (19, 19))
# prs: ('QuitHistory', (26, 27))
# prs: ('Amount', (36, 36))
# prs: ('QuitHistory', (41, 45))
# Match
# {(('Tobacco', (9, 10)), ('QuitHistory', (14, 15))): 'Relation', (('Tobacco', (9, 10)), ('Type', (19, 19))): 'No Relation', (('Tobacco', (9, 10)), ('QuitHistory', (26, 27))): 'No Relation', (('Tobacco', (9, 10)), ('Amount', (36, 36))): 'No Relation', (('Tobacco', (9, 10)), ('QuitHistory', (41, 45))): 'No Relation', (('Drug', (19, 19)), ('QuitHistory', (14, 15))): 'No Relation', (('Drug', (19, 19)), ('Type', (19, 19))): 'Relation', (('Drug', (19, 19)), ('QuitHistory', (26, 27))): 'Relation', (('Drug', (19, 19)), ('Amount', (36, 36))): 'No Relation', (('Drug', (19, 19)), ('QuitHistory', (41, 45))): 'No Relation', (('Alcohol', (35, 35)), ('QuitHistory', (14, 15))): 'No Relation', (('Alcohol', (35, 35)), ('Type', (19, 19))): 'No Relation', (('Alcohol', (35, 35)), ('QuitHistory', (26, 27))): 'No Relation', (('Alcohol', (35, 35)), ('Amount', (36, 36))): 'Relation', (('Alcohol', (35, 35)), ('QuitHistory', (41, 45))): 'Relation', (('Tobacco', (9, 10)), ('Status', (8, 8))): 'Relation', (('Tobacco', (9, 10)), ('Status', (33, 34))): 'No Relation', (('Drug', (19, 19)), ('Status', (8, 8))): 'No Relation', (('Drug', (19, 19)), ('Status', (33, 34))): 'No Relation', (('Alcohol', (35, 35)), ('Status', (8, 8))): 'No Relation', (('Alcohol', (35, 35)), ('Status', (33, 34))): 'Relation'}
# 14
# [('Alcohol', (9, 10)), ('Tobacco', (26, 27))]
# pes: ('Alcohol', (9, 10))
# --------------------------------------------------
# Entity
# rlb: 9
# rlb: 9
# Entity Match
# ################
# Role
# rle: (8, 8, 'Amount')
# ppppppppp
# [('Amount', (8, 8)), ('QuitHistory', (16, 18)), ('Type', (25, 25)), ('QuitHistory', (30, 32))]
# prs: ('Amount', (8, 8))
# Match
# prs: ('QuitHistory', (16, 18))
# prs: ('Type', (25, 25))
# prs: ('QuitHistory', (30, 32))
# ################
# Role
# rle: (11, 13, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (7, 7)), ('Status', (11, 13)), ('Status', (24, 24))]
# prs: ('Status', (7, 7))
# prs: ('Status', (11, 13))
# Match
# prs: ('Status', (24, 24))
# ################
# Role
# rle: (16, 18, 'QuitHistory')
# ppppppppp
# [('Amount', (8, 8)), ('QuitHistory', (16, 18)), ('Type', (25, 25)), ('QuitHistory', (30, 32))]
# prs: ('Amount', (8, 8))
# prs: ('QuitHistory', (16, 18))
# Match
# prs: ('Type', (25, 25))
# prs: ('QuitHistory', (30, 32))
# pes: ('Tobacco', (26, 27))
# --------------------------------------------------
# Entity
# rlb: 9
# rlb: 9
# --------------------------------------------------
# Entity
# rlb: 26
# rlb: 27
# Entity Match
# ################
# Role
# rle: (24, 24, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (7, 7)), ('Status', (11, 13)), ('Status', (24, 24))]
# prs: ('Status', (7, 7))
# prs: ('Status', (11, 13))
# prs: ('Status', (24, 24))
# Match
# ################
# Role
# rle: (25, 25, 'Type')
# ppppppppp
# [('Amount', (8, 8)), ('QuitHistory', (16, 18)), ('Type', (25, 25)), ('QuitHistory', (30, 32))]
# prs: ('Amount', (8, 8))
# prs: ('QuitHistory', (16, 18))
# prs: ('Type', (25, 25))
# Match
# prs: ('QuitHistory', (30, 32))
# ################
# Role
# rle: (30, 32, 'QuitHistory')
# ppppppppp
# [('Amount', (8, 8)), ('QuitHistory', (16, 18)), ('Type', (25, 25)), ('QuitHistory', (30, 32))]
# prs: ('Amount', (8, 8))
# prs: ('QuitHistory', (16, 18))
# prs: ('Type', (25, 25))
# prs: ('QuitHistory', (30, 32))
# Match
# {(('Alcohol', (9, 10)), ('Amount', (8, 8))): 'Relation', (('Alcohol', (9, 10)), ('QuitHistory', (16, 18))): 'Relation', (('Alcohol', (9, 10)), ('Type', (25, 25))): 'No Relation', (('Alcohol', (9, 10)), ('QuitHistory', (30, 32))): 'No Relation', (('Tobacco', (26, 27)), ('Amount', (8, 8))): 'No Relation', (('Tobacco', (26, 27)), ('QuitHistory', (16, 18))): 'No Relation', (('Tobacco', (26, 27)), ('Type', (25, 25))): 'Relation', (('Tobacco', (26, 27)), ('QuitHistory', (30, 32))): 'Relation', (('Alcohol', (9, 10)), ('Status', (7, 7))): 'No Relation', (('Alcohol', (9, 10)), ('Status', (11, 13))): 'Relation', (('Alcohol', (9, 10)), ('Status', (24, 24))): 'No Relation', (('Tobacco', (26, 27)), ('Status', (7, 7))): 'No Relation', (('Tobacco', (26, 27)), ('Status', (11, 13))): 'No Relation', (('Tobacco', (26, 27)), ('Status', (24, 24))): 'Relation'}
# 8
# [('Tobacco', (17, 17))]
# pes: ('Tobacco', (17, 17))
# --------------------------------------------------
# Entity
# rlb: 17
# rlb: 17
# Entity Match
# ################
# Role
# rle: (23, 23, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (5, 5)), ('Status', (15, 16)), ('Status', (28, 28))]
# prs: ('Status', (5, 5))
# prs: ('Status', (15, 16))
# prs: ('Status', (28, 28))
# ################
# Role
# rle: (18, 19, 'Amount')
# ppppppppp
# [('Type', (6, 6)), ('Amount', (18, 19)), ('Frequency', (20, 21)), ('QuitHistory', (25, 25))]
# prs: ('Type', (6, 6))
# prs: ('Amount', (18, 19))
# Match
# prs: ('Frequency', (20, 21))
# Match
# prs: ('QuitHistory', (25, 25))
# ################
# Role
# rle: (20, 21, 'Frequency')
# ppppppppp
# [('Type', (6, 6)), ('Amount', (18, 19)), ('Frequency', (20, 21)), ('QuitHistory', (25, 25))]
# prs: ('Type', (6, 6))
# prs: ('Amount', (18, 19))
# Match
# prs: ('Frequency', (20, 21))
# Match
# prs: ('QuitHistory', (25, 25))
# ################
# Role
# rle: (24, 25, 'QuitHistory')
# ppppppppp
# [('Type', (6, 6)), ('Amount', (18, 19)), ('Frequency', (20, 21)), ('QuitHistory', (25, 25))]
# prs: ('Type', (6, 6))
# prs: ('Amount', (18, 19))
# prs: ('Frequency', (20, 21))
# prs: ('QuitHistory', (25, 25))
# Match
# {(('Tobacco', (17, 17)), ('Type', (6, 6))): 'No Relation', (('Tobacco', (17, 17)), ('Amount', (18, 19))): 'Relation', (('Tobacco', (17, 17)), ('Frequency', (20, 21))): 'Relation', (('Tobacco', (17, 17)), ('QuitHistory', (25, 25))): 'Relation', (('Tobacco', (17, 17)), ('Status', (5, 5))): 'No Relation', (('Tobacco', (17, 17)), ('Status', (15, 16))): 'No Relation', (('Tobacco', (17, 17)), ('Status', (28, 28))): 'No Relation', (('Tobacco', (17, 17)), ('Method', (29, 29))): 'No Relation'}
# 120
# [('Family', (14, 14)), ('Family', (26, 28)), ('Tobacco', (62, 62)), ('Alcohol', (86, 86)), ('Drug', (94, 94))]
# pes: ('Family', (14, 14))
# --------------------------------------------------
# Entity
# rlb: 26
# rlb: 28
# --------------------------------------------------
# Entity
# rlb: 84
# rlb: 86
# --------------------------------------------------
# Entity
# rlb: 94
# rlb: 94
# --------------------------------------------------
# Entity
# rlb: 62
# rlb: 62
# pes: ('Family', (26, 28))
# --------------------------------------------------
# Entity
# rlb: 26
# rlb: 28
# Entity Match
# ################
# Role
# rle: (27, 28, 'Type')
# ppppppppp
# [('Type', (7, 7)), ('Type', (14, 14)), ('Temporal', (15, 17)), ('Amount', (26, 26)), ('Type', (27, 28)), ('Location', (35, 36)), ('Location', (41, 46)), ('Location', (54, 56)), ('Amount', (67, 70)), ('Location', (80, 80)), ('Amount', (87, 87)), ('Type', (92, 93))]
# prs: ('Type', (7, 7))
# prs: ('Type', (14, 14))
# prs: ('Temporal', (15, 17))
# prs: ('Amount', (26, 26))
# Match
# prs: ('Type', (27, 28))
# Match
# prs: ('Location', (35, 36))
# prs: ('Location', (41, 46))
# prs: ('Location', (54, 56))
# prs: ('Amount', (67, 70))
# prs: ('Location', (80, 80))
# prs: ('Amount', (87, 87))
# prs: ('Type', (92, 93))
# ################
# Role
# rle: (26, 26, 'Amount')
# ppppppppp
# [('Type', (7, 7)), ('Type', (14, 14)), ('Temporal', (15, 17)), ('Amount', (26, 26)), ('Type', (27, 28)), ('Location', (35, 36)), ('Location', (41, 46)), ('Location', (54, 56)), ('Amount', (67, 70)), ('Location', (80, 80)), ('Amount', (87, 87)), ('Type', (92, 93))]
# prs: ('Type', (7, 7))
# prs: ('Type', (14, 14))
# prs: ('Temporal', (15, 17))
# prs: ('Amount', (26, 26))
# Match
# prs: ('Type', (27, 28))
# Match
# prs: ('Location', (35, 36))
# prs: ('Location', (41, 46))
# prs: ('Location', (54, 56))
# prs: ('Amount', (67, 70))
# prs: ('Location', (80, 80))
# prs: ('Amount', (87, 87))
# prs: ('Type', (92, 93))
# pes: ('Tobacco', (62, 62))
# --------------------------------------------------
# Entity
# rlb: 26
# rlb: 28
# --------------------------------------------------
# Entity
# rlb: 84
# rlb: 86
# --------------------------------------------------
# Entity
# rlb: 94
# rlb: 94
# --------------------------------------------------
# Entity
# rlb: 62
# rlb: 62
# Entity Match
# ################
# Role
# rle: (67, 70, 'Amount')
# ppppppppp
# [('Type', (7, 7)), ('Type', (14, 14)), ('Temporal', (15, 17)), ('Amount', (26, 26)), ('Type', (27, 28)), ('Location', (35, 36)), ('Location', (41, 46)), ('Location', (54, 56)), ('Amount', (67, 70)), ('Location', (80, 80)), ('Amount', (87, 87)), ('Type', (92, 93))]
# prs: ('Type', (7, 7))
# prs: ('Type', (14, 14))
# prs: ('Temporal', (15, 17))
# prs: ('Amount', (26, 26))
# prs: ('Type', (27, 28))
# prs: ('Location', (35, 36))
# prs: ('Location', (41, 46))
# prs: ('Location', (54, 56))
# prs: ('Amount', (67, 70))
# Match
# prs: ('Location', (80, 80))
# prs: ('Amount', (87, 87))
# prs: ('Type', (92, 93))
# ################
# Role
# rle: (74, 81, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (6, 6)), ('Status', (31, 31)), ('Status', (38, 38)), ('Status', (49, 49)), ('Status', (62, 62)), ('Status', (75, 76)), ('Status', (84, 85)), ('Status', (89, 90))]
# prs: ('Status', (6, 6))
# prs: ('Status', (31, 31))
# prs: ('Status', (38, 38))
# prs: ('Status', (49, 49))
# prs: ('Status', (62, 62))
# prs: ('Status', (75, 76))
# Match
# prs: ('Status', (84, 85))
# prs: ('Status', (89, 90))
# ################
# Role
# rle: (78, 81, 'QuitHistory')
# ppppppppp
# [('Type', (7, 7)), ('Type', (14, 14)), ('Temporal', (15, 17)), ('Amount', (26, 26)), ('Type', (27, 28)), ('Location', (35, 36)), ('Location', (41, 46)), ('Location', (54, 56)), ('Amount', (67, 70)), ('Location', (80, 80)), ('Amount', (87, 87)), ('Type', (92, 93))]
# prs: ('Type', (7, 7))
# prs: ('Type', (14, 14))
# prs: ('Temporal', (15, 17))
# prs: ('Amount', (26, 26))
# prs: ('Type', (27, 28))
# prs: ('Location', (35, 36))
# prs: ('Location', (41, 46))
# prs: ('Location', (54, 56))
# prs: ('Amount', (67, 70))
# prs: ('Location', (80, 80))
# Match
# prs: ('Amount', (87, 87))
# prs: ('Type', (92, 93))
# pes: ('Alcohol', (86, 86))
# --------------------------------------------------
# Entity
# rlb: 26
# rlb: 28
# --------------------------------------------------
# Entity
# rlb: 84
# rlb: 86
# Entity Match
# ################
# Role
# rle: (84, 85, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (6, 6)), ('Status', (31, 31)), ('Status', (38, 38)), ('Status', (49, 49)), ('Status', (62, 62)), ('Status', (75, 76)), ('Status', (84, 85)), ('Status', (89, 90))]
# prs: ('Status', (6, 6))
# prs: ('Status', (31, 31))
# prs: ('Status', (38, 38))
# prs: ('Status', (49, 49))
# prs: ('Status', (62, 62))
# prs: ('Status', (75, 76))
# prs: ('Status', (84, 85))
# Match
# prs: ('Status', (89, 90))
# ################
# Role
# rle: (87, 87, 'Amount')
# ppppppppp
# [('Type', (7, 7)), ('Type', (14, 14)), ('Temporal', (15, 17)), ('Amount', (26, 26)), ('Type', (27, 28)), ('Location', (35, 36)), ('Location', (41, 46)), ('Location', (54, 56)), ('Amount', (67, 70)), ('Location', (80, 80)), ('Amount', (87, 87)), ('Type', (92, 93))]
# prs: ('Type', (7, 7))
# prs: ('Type', (14, 14))
# prs: ('Temporal', (15, 17))
# prs: ('Amount', (26, 26))
# prs: ('Type', (27, 28))
# prs: ('Location', (35, 36))
# prs: ('Location', (41, 46))
# prs: ('Location', (54, 56))
# prs: ('Amount', (67, 70))
# prs: ('Location', (80, 80))
# prs: ('Amount', (87, 87))
# Match
# prs: ('Type', (92, 93))
# pes: ('Drug', (94, 94))
# --------------------------------------------------
# Entity
# rlb: 26
# rlb: 28
# --------------------------------------------------
# Entity
# rlb: 84
# rlb: 86
# --------------------------------------------------
# Entity
# rlb: 94
# rlb: 94
# Entity Match
# ################
# Role
# rle: (92, 93, 'Type')
# ppppppppp
# [('Type', (7, 7)), ('Type', (14, 14)), ('Temporal', (15, 17)), ('Amount', (26, 26)), ('Type', (27, 28)), ('Location', (35, 36)), ('Location', (41, 46)), ('Location', (54, 56)), ('Amount', (67, 70)), ('Location', (80, 80)), ('Amount', (87, 87)), ('Type', (92, 93))]
# prs: ('Type', (7, 7))
# prs: ('Type', (14, 14))
# prs: ('Temporal', (15, 17))
# prs: ('Amount', (26, 26))
# prs: ('Type', (27, 28))
# prs: ('Location', (35, 36))
# prs: ('Location', (41, 46))
# prs: ('Location', (54, 56))
# prs: ('Amount', (67, 70))
# prs: ('Location', (80, 80))
# prs: ('Amount', (87, 87))
# prs: ('Type', (92, 93))
# Match
# ################
# Role
# rle: (89, 90, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (6, 6)), ('Status', (31, 31)), ('Status', (38, 38)), ('Status', (49, 49)), ('Status', (62, 62)), ('Status', (75, 76)), ('Status', (84, 85)), ('Status', (89, 90))]
# prs: ('Status', (6, 6))
# prs: ('Status', (31, 31))
# prs: ('Status', (38, 38))
# prs: ('Status', (49, 49))
# prs: ('Status', (62, 62))
# prs: ('Status', (75, 76))
# prs: ('Status', (84, 85))
# prs: ('Status', (89, 90))
# Match
# {(('Family', (14, 14)), ('Type', (7, 7))): 'No Relation', (('Family', (14, 14)), ('Type', (14, 14))): 'No Relation', (('Family', (14, 14)), ('Temporal', (15, 17))): 'No Relation', (('Family', (14, 14)), ('Amount', (26, 26))): 'No Relation', (('Family', (14, 14)), ('Type', (27, 28))): 'No Relation', (('Family', (14, 14)), ('Location', (35, 36))): 'No Relation', (('Family', (14, 14)), ('Location', (41, 46))): 'No Relation', (('Family', (14, 14)), ('Location', (54, 56))): 'No Relation', (('Family', (14, 14)), ('Amount', (67, 70))): 'No Relation', (('Family', (14, 14)), ('Location', (80, 80))): 'No Relation', (('Family', (14, 14)), ('Amount', (87, 87))): 'No Relation', (('Family', (14, 14)), ('Type', (92, 93))): 'No Relation', (('Family', (26, 28)), ('Type', (7, 7))): 'No Relation', (('Family', (26, 28)), ('Type', (14, 14))): 'No Relation', (('Family', (26, 28)), ('Temporal', (15, 17))): 'No Relation', (('Family', (26, 28)), ('Amount', (26, 26))): 'Relation', (('Family', (26, 28)), ('Type', (27, 28))): 'Relation', (('Family', (26, 28)), ('Location', (35, 36))): 'No Relation', (('Family', (26, 28)), ('Location', (41, 46))): 'No Relation', (('Family', (26, 28)), ('Location', (54, 56))): 'No Relation', (('Family', (26, 28)), ('Amount', (67, 70))): 'No Relation', (('Family', (26, 28)), ('Location', (80, 80))): 'No Relation', (('Family', (26, 28)), ('Amount', (87, 87))): 'No Relation', (('Family', (26, 28)), ('Type', (92, 93))): 'No Relation', (('Tobacco', (62, 62)), ('Type', (7, 7))): 'No Relation', (('Tobacco', (62, 62)), ('Type', (14, 14))): 'No Relation', (('Tobacco', (62, 62)), ('Temporal', (15, 17))): 'No Relation', (('Tobacco', (62, 62)), ('Amount', (26, 26))): 'No Relation', (('Tobacco', (62, 62)), ('Type', (27, 28))): 'No Relation', (('Tobacco', (62, 62)), ('Location', (35, 36))): 'No Relation', (('Tobacco', (62, 62)), ('Location', (41, 46))): 'No Relation', (('Tobacco', (62, 62)), ('Location', (54, 56))): 'No Relation', (('Tobacco', (62, 62)), ('Amount', (67, 70))): 'Relation', (('Tobacco', (62, 62)), ('Location', (80, 80))): 'Relation', (('Tobacco', (62, 62)), ('Amount', (87, 87))): 'No Relation', (('Tobacco', (62, 62)), ('Type', (92, 93))): 'No Relation', (('Alcohol', (86, 86)), ('Type', (7, 7))): 'No Relation', (('Alcohol', (86, 86)), ('Type', (14, 14))): 'No Relation', (('Alcohol', (86, 86)), ('Temporal', (15, 17))): 'No Relation', (('Alcohol', (86, 86)), ('Amount', (26, 26))): 'No Relation', (('Alcohol', (86, 86)), ('Type', (27, 28))): 'No Relation', (('Alcohol', (86, 86)), ('Location', (35, 36))): 'No Relation', (('Alcohol', (86, 86)), ('Location', (41, 46))): 'No Relation', (('Alcohol', (86, 86)), ('Location', (54, 56))): 'No Relation', (('Alcohol', (86, 86)), ('Amount', (67, 70))): 'No Relation', (('Alcohol', (86, 86)), ('Location', (80, 80))): 'No Relation', (('Alcohol', (86, 86)), ('Amount', (87, 87))): 'Relation', (('Alcohol', (86, 86)), ('Type', (92, 93))): 'No Relation', (('Drug', (94, 94)), ('Type', (7, 7))): 'No Relation', (('Drug', (94, 94)), ('Type', (14, 14))): 'No Relation', (('Drug', (94, 94)), ('Temporal', (15, 17))): 'No Relation', (('Drug', (94, 94)), ('Amount', (26, 26))): 'No Relation', (('Drug', (94, 94)), ('Type', (27, 28))): 'No Relation', (('Drug', (94, 94)), ('Location', (35, 36))): 'No Relation', (('Drug', (94, 94)), ('Location', (41, 46))): 'No Relation', (('Drug', (94, 94)), ('Location', (54, 56))): 'No Relation', (('Drug', (94, 94)), ('Amount', (67, 70))): 'No Relation', (('Drug', (94, 94)), ('Location', (80, 80))): 'No Relation', (('Drug', (94, 94)), ('Amount', (87, 87))): 'No Relation', (('Drug', (94, 94)), ('Type', (92, 93))): 'Relation', (('Family', (14, 14)), ('Status', (6, 6))): 'No Relation', (('Family', (14, 14)), ('Status', (31, 31))): 'No Relation', (('Family', (14, 14)), ('Status', (38, 38))): 'No Relation', (('Family', (14, 14)), ('Status', (49, 49))): 'No Relation', (('Family', (14, 14)), ('Status', (62, 62))): 'No Relation', (('Family', (14, 14)), ('Status', (75, 76))): 'No Rela ...
# 6
# [('Tobacco', (11, 11)), ('Alcohol', (22, 22))]
# pes: ('Tobacco', (11, 11))
# --------------------------------------------------
# Entity
# rlb: 22
# rlb: 22
# --------------------------------------------------
# Entity
# rlb: 11
# rlb: 11
# Entity Match
# ################
# Role
# rle: (6, 6, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (9, 10))]
# prs: ('Status', (9, 10))
# ################
# Role
# rle: (7, 9, 'ExposureHistory')
# ppppppppp
# [('QuitHistory', (14, 16)), ('Frequency', (21, 21))]
# prs: ('QuitHistory', (14, 16))
# prs: ('Frequency', (21, 21))
# ################
# Role
# rle: (14, 16, 'QuitHistory')
# ppppppppp
# [('QuitHistory', (14, 16)), ('Frequency', (21, 21))]
# prs: ('QuitHistory', (14, 16))
# Match
# prs: ('Frequency', (21, 21))
# pes: ('Alcohol', (22, 22))
# --------------------------------------------------
# Entity
# rlb: 22
# rlb: 22
# Entity Match
# ################
# Role
# rle: (21, 21, 'Frequency')
# ppppppppp
# [('QuitHistory', (14, 16)), ('Frequency', (21, 21))]
# prs: ('QuitHistory', (14, 16))
# prs: ('Frequency', (21, 21))
# Match
# ################
# Role
# rle: (20, 21, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (9, 10))]
# prs: ('Status', (9, 10))
# {(('Tobacco', (11, 11)), ('QuitHistory', (14, 16))): 'Relation', (('Tobacco', (11, 11)), ('Frequency', (21, 21))): 'No Relation', (('Alcohol', (22, 22)), ('QuitHistory', (14, 16))): 'No Relation', (('Alcohol', (22, 22)), ('Frequency', (21, 21))): 'Relation', (('Tobacco', (11, 11)), ('Status', (9, 10))): 'No Relation', (('Alcohol', (22, 22)), ('Status', (9, 10))): 'No Relation'}
# 16
# [('Tobacco', (8, 8)), ('Alcohol', (17, 17))]
# pes: ('Tobacco', (8, 8))
# --------------------------------------------------
# Entity
# rlb: 8
# rlb: 8
# Entity Match
# ################
# Role
# rle: (6, 7, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (6, 7)), ('Status', (17, 17)), ('Status', (24, 24))]
# prs: ('Status', (6, 7))
# Match
# prs: ('Status', (17, 17))
# prs: ('Status', (24, 24))
# ################
# Role
# rle: (12, 14, 'QuitHistory')
# ppppppppp
# [('QuitHistory', (12, 14)), ('Amount', (18, 18)), ('Type', (19, 19)), ('Frequency', (20, 21)), ('Type', (27, 30))]
# prs: ('QuitHistory', (12, 14))
# Match
# prs: ('Amount', (18, 18))
# prs: ('Type', (19, 19))
# prs: ('Frequency', (20, 21))
# prs: ('Type', (27, 30))
# pes: ('Alcohol', (17, 17))
# --------------------------------------------------
# Entity
# rlb: 8
# rlb: 8
# --------------------------------------------------
# Entity
# rlb: 17
# rlb: 17
# Entity Match
# ################
# Role
# rle: (18, 19, 'Amount')
# ppppppppp
# [('QuitHistory', (12, 14)), ('Amount', (18, 18)), ('Type', (19, 19)), ('Frequency', (20, 21)), ('Type', (27, 30))]
# prs: ('QuitHistory', (12, 14))
# prs: ('Amount', (18, 18))
# Match
# prs: ('Type', (19, 19))
# Match
# prs: ('Frequency', (20, 21))
# Match
# prs: ('Type', (27, 30))
# ################
# Role
# rle: (20, 21, 'Frequency')
# ppppppppp
# [('QuitHistory', (12, 14)), ('Amount', (18, 18)), ('Type', (19, 19)), ('Frequency', (20, 21)), ('Type', (27, 30))]
# prs: ('QuitHistory', (12, 14))
# prs: ('Amount', (18, 18))
# Match
# prs: ('Type', (19, 19))
# Match
# prs: ('Frequency', (20, 21))
# Match
# prs: ('Type', (27, 30))
# ################
# Role
# rle: (17, 17, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (6, 7)), ('Status', (17, 17)), ('Status', (24, 24))]
# prs: ('Status', (6, 7))
# prs: ('Status', (17, 17))
# Match
# prs: ('Status', (24, 24))
# {(('Tobacco', (8, 8)), ('QuitHistory', (12, 14))): 'Relation', (('Tobacco', (8, 8)), ('Amount', (18, 18))): 'No Relation', (('Tobacco', (8, 8)), ('Type', (19, 19))): 'No Relation', (('Tobacco', (8, 8)), ('Frequency', (20, 21))): 'No Relation', (('Tobacco', (8, 8)), ('Type', (27, 30))): 'No Relation', (('Alcohol', (17, 17)), ('QuitHistory', (12, 14))): 'No Relation', (('Alcohol', (17, 17)), ('Amount', (18, 18))): 'Relation', (('Alcohol', (17, 17)), ('Type', (19, 19))): 'Relation', (('Alcohol', (17, 17)), ('Frequency', (20, 21))): 'Relation', (('Alcohol', (17, 17)), ('Type', (27, 30))): 'No Relation', (('Tobacco', (8, 8)), ('Status', (6, 7))): 'Relation', (('Tobacco', (8, 8)), ('Status', (17, 17))): 'No Relation', (('Tobacco', (8, 8)), ('Status', (24, 24))): 'No Relation', (('Alcohol', (17, 17)), ('Status', (6, 7))): 'No Relation', (('Alcohol', (17, 17)), ('Status', (17, 17))): 'Relation', (('Alcohol', (17, 17)), ('Status', (24, 24))): 'No Relation'}
# 16
# [('Tobacco', (19, 20)), ('Alcohol', (33, 33))]
# pes: ('Tobacco', (19, 20))
# --------------------------------------------------
# Entity
# rlb: 19
# rlb: 20
# Entity Match
# ################
# Role
# rle: (17, 18, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (6, 6)), ('Status', (10, 10)), ('Status', (34, 34))]
# prs: ('Status', (6, 6))
# prs: ('Status', (10, 10))
# prs: ('Status', (34, 34))
# ################
# Role
# rle: (22, 26, 'Amount')
# ppppppppp
# [('Type', (7, 7)), ('Amount', (22, 26)), ('ExposureHistory', (27, 29)), ('Frequency', (32, 32))]
# prs: ('Type', (7, 7))
# prs: ('Amount', (22, 26))
# Match
# prs: ('ExposureHistory', (27, 29))
# prs: ('Frequency', (32, 32))
# ################
# Role
# rle: (27, 29, 'ExposureHistory')
# ppppppppp
# [('Type', (7, 7)), ('Amount', (22, 26)), ('ExposureHistory', (27, 29)), ('Frequency', (32, 32))]
# prs: ('Type', (7, 7))
# prs: ('Amount', (22, 26))
# prs: ('ExposureHistory', (27, 29))
# Match
# prs: ('Frequency', (32, 32))
# pes: ('Alcohol', (33, 33))
# --------------------------------------------------
# Entity
# rlb: 19
# rlb: 20
# --------------------------------------------------
# Entity
# rlb: 33
# rlb: 33
# Entity Match
# ################
# Role
# rle: (32, 32, 'Frequency')
# ppppppppp
# [('Type', (7, 7)), ('Amount', (22, 26)), ('ExposureHistory', (27, 29)), ('Frequency', (32, 32))]
# prs: ('Type', (7, 7))
# prs: ('Amount', (22, 26))
# prs: ('ExposureHistory', (27, 29))
# prs: ('Frequency', (32, 32))
# Match
# ################
# Role
# rle: (34, 34, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (6, 6)), ('Status', (10, 10)), ('Status', (34, 34))]
# prs: ('Status', (6, 6))
# prs: ('Status', (10, 10))
# prs: ('Status', (34, 34))
# Match
# {(('Tobacco', (19, 20)), ('Type', (7, 7))): 'No Relation', (('Tobacco', (19, 20)), ('Amount', (22, 26))): 'Relation', (('Tobacco', (19, 20)), ('ExposureHistory', (27, 29))): 'Relation', (('Tobacco', (19, 20)), ('Frequency', (32, 32))): 'No Relation', (('Alcohol', (33, 33)), ('Type', (7, 7))): 'No Relation', (('Alcohol', (33, 33)), ('Amount', (22, 26))): 'No Relation', (('Alcohol', (33, 33)), ('ExposureHistory', (27, 29))): 'No Relation', (('Alcohol', (33, 33)), ('Frequency', (32, 32))): 'Relation', (('Tobacco', (19, 20)), ('Status', (6, 6))): 'No Relation', (('Tobacco', (19, 20)), ('Status', (10, 10))): 'No Relation', (('Tobacco', (19, 20)), ('Status', (34, 34))): 'No Relation', (('Alcohol', (33, 33)), ('Status', (6, 6))): 'No Relation', (('Alcohol', (33, 33)), ('Status', (10, 10))): 'No Relation', (('Alcohol', (33, 33)), ('Status', (34, 34))): 'Relation', (('Tobacco', (19, 20)), ('Method', (11, 11))): 'No Relation', (('Alcohol', (33, 33)), ('Method', (11, 11))): 'No Relation'}
# 95
# [('Tobacco', (5, 6)), ('Tobacco', (26, 26)), ('Alcohol', (35, 35)), ('Family', (42, 43)), ('Family', (51, 51))]
# pes: ('Tobacco', (5, 6))
# --------------------------------------------------
# Entity
# rlb: 26
# rlb: 26
# --------------------------------------------------
# Entity
# rlb: 35
# rlb: 35
# --------------------------------------------------
# Entity
# rlb: 42
# rlb: 43
# --------------------------------------------------
# Entity
# rlb: 51
# rlb: 51
# --------------------------------------------------
# Entity
# rlb: 5
# rlb: 6
# Entity Match
# ################
# Role
# rle: (5, 6, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (5, 6)), ('Status', (25, 25)), ('Status', (34, 34)), ('Status', (38, 38)), ('Status', (46, 46)), ('Status', (54, 56))]
# prs: ('Status', (5, 6))
# Match
# prs: ('Status', (25, 25))
# prs: ('Status', (34, 34))
# prs: ('Status', (38, 38))
# prs: ('Status', (46, 46))
# prs: ('Status', (54, 56))
# ################
# Role
# rle: (8, 10, 'Amount')
# ppppppppp
# [('Amount', (8, 10)), ('Type', (11, 11)), ('Frequency', (12, 13)), ('ExposureHistory', (18, 22)), ('QuitHistory', (28, 30)), ('Frequency', (33, 33)), ('Type', (39, 39)), ('Amount', (42, 42)), ('Type', (43, 43)), ('Type', (51, 51)), ('Type', (59, 60)), ('Location', (62, 66))]
# prs: ('Amount', (8, 10))
# Match
# prs: ('Type', (11, 11))
# Match
# prs: ('Frequency', (12, 13))
# prs: ('ExposureHistory', (18, 22))
# prs: ('QuitHistory', (28, 30))
# prs: ('Frequency', (33, 33))
# prs: ('Type', (39, 39))
# prs: ('Amount', (42, 42))
# prs: ('Type', (43, 43))
# prs: ('Type', (51, 51))
# prs: ('Type', (59, 60))
# prs: ('Location', (62, 66))
# ################
# Role
# rle: (11, 11, 'Type')
# ppppppppp
# [('Amount', (8, 10)), ('Type', (11, 11)), ('Frequency', (12, 13)), ('ExposureHistory', (18, 22)), ('QuitHistory', (28, 30)), ('Frequency', (33, 33)), ('Type', (39, 39)), ('Amount', (42, 42)), ('Type', (43, 43)), ('Type', (51, 51)), ('Type', (59, 60)), ('Location', (62, 66))]
# prs: ('Amount', (8, 10))
# prs: ('Type', (11, 11))
# Match
# prs: ('Frequency', (12, 13))
# Match
# prs: ('ExposureHistory', (18, 22))
# prs: ('QuitHistory', (28, 30))
# prs: ('Frequency', (33, 33))
# prs: ('Type', (39, 39))
# prs: ('Amount', (42, 42))
# prs: ('Type', (43, 43))
# prs: ('Type', (51, 51))
# prs: ('Type', (59, 60))
# prs: ('Location', (62, 66))
# ################
# Role
# rle: (12, 13, 'Frequency')
# ppppppppp
# [('Amount', (8, 10)), ('Type', (11, 11)), ('Frequency', (12, 13)), ('ExposureHistory', (18, 22)), ('QuitHistory', (28, 30)), ('Frequency', (33, 33)), ('Type', (39, 39)), ('Amount', (42, 42)), ('Type', (43, 43)), ('Type', (51, 51)), ('Type', (59, 60)), ('Location', (62, 66))]
# prs: ('Amount', (8, 10))
# prs: ('Type', (11, 11))
# Match
# prs: ('Frequency', (12, 13))
# Match
# prs: ('ExposureHistory', (18, 22))
# prs: ('QuitHistory', (28, 30))
# prs: ('Frequency', (33, 33))
# prs: ('Type', (39, 39))
# prs: ('Amount', (42, 42))
# prs: ('Type', (43, 43))
# prs: ('Type', (51, 51))
# prs: ('Type', (59, 60))
# prs: ('Location', (62, 66))
# ################
# Role
# rle: (18, 22, 'ExposureHistory')
# ppppppppp
# [('Amount', (8, 10)), ('Type', (11, 11)), ('Frequency', (12, 13)), ('ExposureHistory', (18, 22)), ('QuitHistory', (28, 30)), ('Frequency', (33, 33)), ('Type', (39, 39)), ('Amount', (42, 42)), ('Type', (43, 43)), ('Type', (51, 51)), ('Type', (59, 60)), ('Location', (62, 66))]
# prs: ('Amount', (8, 10))
# prs: ('Type', (11, 11))
# prs: ('Frequency', (12, 13))
# prs: ('ExposureHistory', (18, 22))
# Match
# prs: ('QuitHistory', (28, 30))
# prs: ('Frequency', (33, 33))
# prs: ('Type', (39, 39))
# prs: ('Amount', (42, 42))
# prs: ('Type', (43, 43))
# prs: ('Type', (51, 51))
# prs: ('Type', (59, 60))
# prs: ('Location', (62, 66))
# pes: ('Tobacco', (26, 26))
# --------------------------------------------------
# Entity
# rlb: 26
# rlb: 26
# Entity Match
# ################
# Role
# rle: (25, 26, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (5, 6)), ('Status', (25, 25)), ('Status', (34, 34)), ('Status', (38, 38)), ('Status', (46, 46)), ('Status', (54, 56))]
# prs: ('Status', (5, 6))
# prs: ('Status', (25, 25))
# Match
# prs: ('Status', (34, 34))
# prs: ('Status', (38, 38))
# prs: ('Status', (46, 46))
# prs: ('Status', (54, 56))
# ################
# Role
# rle: (28, 30, 'QuitHistory')
# ppppppppp
# [('Amount', (8, 10)), ('Type', (11, 11)), ('Frequency', (12, 13)), ('ExposureHistory', (18, 22)), ('QuitHistory', (28, 30)), ('Frequency', (33, 33)), ('Type', (39, 39)), ('Amount', (42, 42)), ('Type', (43, 43)), ('Type', (51, 51)), ('Type', (59, 60)), ('Location', (62, 66))]
# prs: ('Amount', (8, 10))
# prs: ('Type', (11, 11))
# prs: ('Frequency', (12, 13))
# prs: ('ExposureHistory', (18, 22))
# prs: ('QuitHistory', (28, 30))
# Match
# prs: ('Frequency', (33, 33))
# prs: ('Type', (39, 39))
# prs: ('Amount', (42, 42))
# prs: ('Type', (43, 43))
# prs: ('Type', (51, 51))
# prs: ('Type', (59, 60))
# prs: ('Location', (62, 66))
# pes: ('Alcohol', (35, 35))
# --------------------------------------------------
# Entity
# rlb: 26
# rlb: 26
# --------------------------------------------------
# Entity
# rlb: 35
# rlb: 35
# Entity Match
# ################
# Role
# rle: (33, 33, 'Frequency')
# ppppppppp
# [('Amount', (8, 10)), ('Type', (11, 11)), ('Frequency', (12, 13)), ('ExposureHistory', (18, 22)), ('QuitHistory', (28, 30)), ('Frequency', (33, 33)), ('Type', (39, 39)), ('Amount', (42, 42)), ('Type', (43, 43)), ('Type', (51, 51)), ('Type', (59, 60)), ('Location', (62, 66))]
# prs: ('Amount', (8, 10))
# prs: ('Type', (11, 11))
# prs: ('Frequency', (12, 13))
# prs: ('ExposureHistory', (18, 22))
# prs: ('QuitHistory', (28, 30))
# prs: ('Frequency', (33, 33))
# Match
# prs: ('Type', (39, 39))
# prs: ('Amount', (42, 42))
# prs: ('Type', (43, 43))
# prs: ('Type', (51, 51))
# prs: ('Type', (59, 60))
# prs: ('Location', (62, 66))
# ################
# Role
# rle: (33, 33, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (5, 6)), ('Status', (25, 25)), ('Status', (34, 34)), ('Status', (38, 38)), ('Status', (46, 46)), ('Status', (54, 56))]
# prs: ('Status', (5, 6))
# prs: ('Status', (25, 25))
# prs: ('Status', (34, 34))
# Match
# prs: ('Status', (38, 38))
# prs: ('Status', (46, 46))
# prs: ('Status', (54, 56))
# pes: ('Family', (42, 43))
# --------------------------------------------------
# Entity
# rlb: 26
# rlb: 26
# --------------------------------------------------
# Entity
# rlb: 35
# rlb: 35
# --------------------------------------------------
# Entity
# rlb: 42
# rlb: 43
# Entity Match
# ################
# Role
# rle: (43, 43, 'Type')
# ppppppppp
# [('Amount', (8, 10)), ('Type', (11, 11)), ('Frequency', (12, 13)), ('ExposureHistory', (18, 22)), ('QuitHistory', (28, 30)), ('Frequency', (33, 33)), ('Type', (39, 39)), ('Amount', (42, 42)), ('Type', (43, 43)), ('Type', (51, 51)), ('Type', (59, 60)), ('Location', (62, 66))]
# prs: ('Amount', (8, 10))
# prs: ('Type', (11, 11))
# prs: ('Frequency', (12, 13))
# prs: ('ExposureHistory', (18, 22))
# prs: ('QuitHistory', (28, 30))
# prs: ('Frequency', (33, 33))
# prs: ('Type', (39, 39))
# prs: ('Amount', (42, 42))
# Match
# prs: ('Type', (43, 43))
# Match
# prs: ('Type', (51, 51))
# prs: ('Type', (59, 60))
# prs: ('Location', (62, 66))
# ################
# Role
# rle: (42, 42, 'Amount')
# ppppppppp
# [('Amount', (8, 10)), ('Type', (11, 11)), ('Frequency', (12, 13)), ('ExposureHistory', (18, 22)), ('QuitHistory', (28, 30)), ('Frequency', (33, 33)), ('Type', (39, 39)), ('Amount', (42, 42)), ('Type', (43, 43)), ('Type', (51, 51)), ('Type', (59, 60)), ('Location', (62, 66))]
# prs: ('Amount', (8, 10))
# prs: ('Type', (11, 11))
# prs: ('Frequency', (12, 13))
# prs: ('ExposureHistory', (18, 22))
# prs: ('QuitHistory', (28, 30))
# prs: ('Frequency', (33, 33))
# prs: ('Type', (39, 39))
# prs: ('Amount', (42, 42))
# Match
# prs: ('Type', (43, 43))
# Match
# prs: ('Type', (51, 51))
# prs: ('Type', (59, 60))
# prs: ('Location', (62, 66))
# pes: ('Family', (51, 51))
# --------------------------------------------------
# Entity
# rlb: 26
# rlb: 26
# --------------------------------------------------
# Entity
# rlb: 35
# rlb: 35
# --------------------------------------------------
# Entity
# rlb: 42
# rlb: 43
# --------------------------------------------------
# Entity
# rlb: 51
# rlb: 51
# Entity Match
# ################
# Role
# rle: (51, 51, 'Type')
# ppppppppp
# [('Amount', (8, 10)), ('Type', (11, 11)), ('Frequency', (12, 13)), ('ExposureHistory', (18, 22)), ('QuitHistory', (28, 30)), ('Frequency', (33, 33)), ('Type', (39, 39)), ('Amount', (42, 42)), ('Type', (43, 43)), ('Type', (51, 51)), ('Type', (59, 60)), ('Location', (62, 66))]
# prs: ('Amount', (8, 10))
# prs: ('Type', (11, 11))
# prs: ('Frequency', (12, 13))
# prs: ('ExposureHistory', (18, 22))
# prs: ('QuitHistory', (28, 30))
# prs: ('Frequency', (33, 33))
# prs: ('Type', (39, 39))
# prs: ('Amount', (42, 42))
# prs: ('Type', (43, 43))
# prs: ('Type', (51, 51))
# Match
# prs: ('Type', (59, 60))
# prs: ('Location', (62, 66))
# {(('Tobacco', (5, 6)), ('Amount', (8, 10))): 'Relation', (('Tobacco', (5, 6)), ('Type', (11, 11))): 'Relation', (('Tobacco', (5, 6)), ('Frequency', (12, 13))): 'Relation', (('Tobacco', (5, 6)), ('ExposureHistory', (18, 22))): 'Relation', (('Tobacco', (5, 6)), ('QuitHistory', (28, 30))): 'No Relation', (('Tobacco', (5, 6)), ('Frequency', (33, 33))): 'No Relation', (('Tobacco', (5, 6)), ('Type', (39, 39))): 'No Relation', (('Tobacco', (5, 6)), ('Amount', (42, 42))): 'No Relation', (('Tobacco', (5, 6)), ('Type', (43, 43))): 'No Relation', (('Tobacco', (5, 6)), ('Type', (51, 51))): 'No Relation', (('Tobacco', (5, 6)), ('Type', (59, 60))): 'No Relation', (('Tobacco', (5, 6)), ('Location', (62, 66))): 'No Relation', (('Tobacco', (26, 26)), ('Amount', (8, 10))): 'No Relation', (('Tobacco', (26, 26)), ('Type', (11, 11))): 'No Relation', (('Tobacco', (26, 26)), ('Frequency', (12, 13))): 'No Relation', (('Tobacco', (26, 26)), ('ExposureHistory', (18, 22))): 'No Relation', (('Tobacco', (26, 26)), ('QuitHistory', (28, 30))): 'Relation', (('Tobacco', (26, 26)), ('Frequency', (33, 33))): 'No Relation', (('Tobacco', (26, 26)), ('Type', (39, 39))): 'No Relation', (('Tobacco', (26, 26)), ('Amount', (42, 42))): 'No Relation', (('Tobacco', (26, 26)), ('Type', (43, 43))): 'No Relation', (('Tobacco', (26, 26)), ('Type', (51, 51))): 'No Relation', (('Tobacco', (26, 26)), ('Type', (59, 60))): 'No Relation', (('Tobacco', (26, 26)), ('Location', (62, 66))): 'No Relation', (('Alcohol', (35, 35)), ('Amount', (8, 10))): 'No Relation', (('Alcohol', (35, 35)), ('Type', (11, 11))): 'No Relation', (('Alcohol', (35, 35)), ('Frequency', (12, 13))): 'No Relation', (('Alcohol', (35, 35)), ('ExposureHistory', (18, 22))): 'No Relation', (('Alcohol', (35, 35)), ('QuitHistory', (28, 30))): 'No Relation', (('Alcohol', (35, 35)), ('Frequency', (33, 33))): 'Relation', (('Alcohol', (35, 35)), ('Type', (39, 39))): 'No Relation', (('Alcohol', (35, 35)), ('Amount', (42, 42))): 'No Relation', (('Alcohol', (35, 35)), ('Type', (43, 43))): 'No Relation', (('Alcohol', (35, 35)), ('Type', (51, 51))): 'No Relation', (('Alcohol', (35, 35)), ('Type', (59, 60))): 'No Relation', (('Alcohol', (35, 35)), ('Location', (62, 66))): 'No Relation', (('Family', (42, 43)), ('Amount', (8, 10))): 'No Relation', (('Family', (42, 43)), ('Type', (11, 11))): 'No Relation', (('Family', (42, 43)), ('Frequency', (12, 13))): 'No Relation', (('Family', (42, 43)), ('ExposureHistory', (18, 22))): 'No Relation', (('Family', (42, 43)), ('QuitHistory', (28, 30))): 'No Relation', (('Family', (42, 43)), ('Frequency', (33, 33))): 'No Relation', (('Family', (42, 43)), ('Type', (39, 39))): 'No Relation', (('Family', (42, 43)), ('Amount', (42, 42))): 'Relation', (('Family', (42, 43)), ('Type', (43, 43))): 'Relation', (('Family', (42, 43)), ('Type', (51, 51))): 'No Relation', (('Family', (42, 43)), ('Type', (59, 60))): 'No Relation', (('Family', (42, 43)), ('Location', (62, 66))): 'No Relation', (('Family', (51, 51)), ('Amount', (8, 10))): 'No Relation', (('Family', (51, 51)), ('Type', (11, 11))): 'No Relation', (('Family', (51, 51)), ('Frequency', (12, 13))): 'No Relation', (('Family', (51, 51)), ('ExposureHistory', (18, 22))): 'No Relation', (('Family', (51, 51)), ('QuitHistory', (28, 30))): 'No Relation', (('Family', (51, 51)), ('Frequency', (33, 33))): 'No Relation', (('Family', (51, 51)), ('Type', (39, 39))): 'No Relation', (('Family', (51, 51)), ('Amount', (42, 42))): 'No Relation', (('Family', (51, 51)), ('Type', (43, 43))): 'No Relation', (('Family', (51, 51)), ('Type', (51, 51))): 'Relation', (('Family', (51, 51)), ('Type', (59, 60))): 'No Relation', (('Family', (51, 51)), ('Location', (62, 66))): 'No Relation', (('Tobacco', (5, 6)), ('Status', (5, 6))): 'Relation', (('Tobacco', (5, 6)), ('Status', (25, 25))): 'No Relation', (('Tobacco', (5, 6)), ('Status', (34, 34))): 'No Relation', (('Tobacco', (5, 6)), ('Status', (38, 38))): 'No Relation', (('Tobacco', (5, 6)), ('Status', (46, 46))): 'No Relation', (('T ...
# 56
# [('Tobacco', (35, 35)), ('Alcohol', (55, 55)), ('Drug', (59, 59)), ('Family', (66, 66))]
# pes: ('Tobacco', (35, 35))
# --------------------------------------------------
# Entity
# rlb: 55
# rlb: 55
# --------------------------------------------------
# Entity
# rlb: 59
# rlb: 59
# --------------------------------------------------
# Entity
# rlb: 35
# rlb: 35
# Entity Match
# ################
# Role
# rle: (34, 34, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (5, 5)), ('Status', (34, 34)), ('Status', (54, 54)), ('Status', (63, 63))]
# prs: ('Status', (5, 5))
# prs: ('Status', (34, 34))
# Match
# prs: ('Status', (54, 54))
# prs: ('Status', (63, 63))
# ################
# Role
# rle: (37, 38, 'Amount')
# ppppppppp
# [('Location', (9, 9)), ('Temporal', (16, 18)), ('Amount', (37, 38)), ('Type', (40, 40)), ('Frequency', (41, 41)), ('ExposureHistory', (42, 44)), ('QuitHistory', (49, 51)), ('Type', (57, 58))]
# prs: ('Location', (9, 9))
# prs: ('Temporal', (16, 18))
# prs: ('Amount', (37, 38))
# Match
# prs: ('Type', (40, 40))
# Match
# prs: ('Frequency', (41, 41))
# prs: ('ExposureHistory', (42, 44))
# prs: ('QuitHistory', (49, 51))
# prs: ('Type', (57, 58))
# ################
# Role
# rle: (40, 40, 'Type')
# ppppppppp
# [('Location', (9, 9)), ('Temporal', (16, 18)), ('Amount', (37, 38)), ('Type', (40, 40)), ('Frequency', (41, 41)), ('ExposureHistory', (42, 44)), ('QuitHistory', (49, 51)), ('Type', (57, 58))]
# prs: ('Location', (9, 9))
# prs: ('Temporal', (16, 18))
# prs: ('Amount', (37, 38))
# prs: ('Type', (40, 40))
# Match
# prs: ('Frequency', (41, 41))
# Match
# prs: ('ExposureHistory', (42, 44))
# Match
# prs: ('QuitHistory', (49, 51))
# prs: ('Type', (57, 58))
# ################
# Role
# rle: (42, 44, 'ExposureHistory')
# ppppppppp
# [('Location', (9, 9)), ('Temporal', (16, 18)), ('Amount', (37, 38)), ('Type', (40, 40)), ('Frequency', (41, 41)), ('ExposureHistory', (42, 44)), ('QuitHistory', (49, 51)), ('Type', (57, 58))]
# prs: ('Location', (9, 9))
# prs: ('Temporal', (16, 18))
# prs: ('Amount', (37, 38))
# prs: ('Type', (40, 40))
# Match
# prs: ('Frequency', (41, 41))
# Match
# prs: ('ExposureHistory', (42, 44))
# Match
# prs: ('QuitHistory', (49, 51))
# prs: ('Type', (57, 58))
# ################
# Role
# rle: (48, 51, 'QuitHistory')
# ppppppppp
# [('Location', (9, 9)), ('Temporal', (16, 18)), ('Amount', (37, 38)), ('Type', (40, 40)), ('Frequency', (41, 41)), ('ExposureHistory', (42, 44)), ('QuitHistory', (49, 51)), ('Type', (57, 58))]
# prs: ('Location', (9, 9))
# prs: ('Temporal', (16, 18))
# prs: ('Amount', (37, 38))
# prs: ('Type', (40, 40))
# prs: ('Frequency', (41, 41))
# prs: ('ExposureHistory', (42, 44))
# prs: ('QuitHistory', (49, 51))
# Match
# prs: ('Type', (57, 58))
# pes: ('Alcohol', (55, 55))
# --------------------------------------------------
# Entity
# rlb: 55
# rlb: 55
# Entity Match
# ################
# Role
# rle: (54, 54, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (5, 5)), ('Status', (34, 34)), ('Status', (54, 54)), ('Status', (63, 63))]
# prs: ('Status', (5, 5))
# prs: ('Status', (34, 34))
# prs: ('Status', (54, 54))
# Match
# prs: ('Status', (63, 63))
# pes: ('Drug', (59, 59))
# --------------------------------------------------
# Entity
# rlb: 55
# rlb: 55
# --------------------------------------------------
# Entity
# rlb: 59
# rlb: 59
# Entity Match
# ################
# Role
# rle: (57, 58, 'Type')
# ppppppppp
# [('Location', (9, 9)), ('Temporal', (16, 18)), ('Amount', (37, 38)), ('Type', (40, 40)), ('Frequency', (41, 41)), ('ExposureHistory', (42, 44)), ('QuitHistory', (49, 51)), ('Type', (57, 58))]
# prs: ('Location', (9, 9))
# prs: ('Temporal', (16, 18))
# prs: ('Amount', (37, 38))
# prs: ('Type', (40, 40))
# prs: ('Frequency', (41, 41))
# prs: ('ExposureHistory', (42, 44))
# prs: ('QuitHistory', (49, 51))
# prs: ('Type', (57, 58))
# Match
# ################
# Role
# rle: (54, 54, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (5, 5)), ('Status', (34, 34)), ('Status', (54, 54)), ('Status', (63, 63))]
# prs: ('Status', (5, 5))
# prs: ('Status', (34, 34))
# prs: ('Status', (54, 54))
# Match
# prs: ('Status', (63, 63))
# pes: ('Family', (66, 66))
# --------------------------------------------------
# Entity
# rlb: 55
# rlb: 55
# --------------------------------------------------
# Entity
# rlb: 59
# rlb: 59
# --------------------------------------------------
# Entity
# rlb: 35
# rlb: 35
# ...
# 10
# [('Tobacco', (15, 15)), ('Alcohol', (17, 17))]
# pes: ('Tobacco', (15, 15))
# --------------------------------------------------
# Entity
# rlb: 15
# rlb: 15
# Entity Match
# ################
# Role
# rle: (14, 14, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (6, 6)), ('Status', (10, 10)), ('Status', (14, 14))]
# prs: ('Status', (6, 6))
# prs: ('Status', (10, 10))
# prs: ('Status', (14, 14))
# Match
# pes: ('Alcohol', (17, 17))
# --------------------------------------------------
# Entity
# rlb: 15
# rlb: 15
# Entity Match
# ################
# Role
# rle: (14, 14, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (6, 6)), ('Status', (10, 10)), ('Status', (14, 14))]
# prs: ('Status', (6, 6))
# prs: ('Status', (10, 10))
# prs: ('Status', (14, 14))
# Match
# {(('Tobacco', (15, 15)), ('Type', (7, 7))): 'No Relation', (('Tobacco', (15, 15)), ('Type', (12, 12))): 'No Relation', (('Alcohol', (17, 17)), ('Type', (7, 7))): 'No Relation', (('Alcohol', (17, 17)), ('Type', (12, 12))): 'No Relation', (('Tobacco', (15, 15)), ('Status', (6, 6))): 'No Relation', (('Tobacco', (15, 15)), ('Status', (10, 10))): 'No Relation', (('Tobacco', (15, 15)), ('Status', (14, 14))): 'Relation', (('Alcohol', (17, 17)), ('Status', (6, 6))): 'No Relation', (('Alcohol', (17, 17)), ('Status', (10, 10))): 'No Relation', (('Alcohol', (17, 17)), ('Status', (14, 14))): 'Relation'}
# 44
# [('Tobacco', (5, 5)), ('Alcohol', (7, 7)), ('Drug', (11, 11)), ('Family', (31, 32))]
# pes: ('Tobacco', (5, 5))
# --------------------------------------------------
# Entity
# rlb: 5
# rlb: 5
# Entity Match
# ################
# Role
# rle: (4, 4, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (4, 4)), ('Status', (15, 15)), ('Status', (24, 25)), ('Status', (29, 29)), ('Status', (36, 36))]
# prs: ('Status', (4, 4))
# Match
# prs: ('Status', (15, 15))
# prs: ('Status', (24, 25))
# prs: ('Status', (29, 29))
# prs: ('Status', (36, 36))
# pes: ('Alcohol', (7, 7))
# --------------------------------------------------
# Entity
# rlb: 5
# rlb: 5
# Entity Match
# ################
# Role
# rle: (4, 4, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (4, 4)), ('Status', (15, 15)), ('Status', (24, 25)), ('Status', (29, 29)), ('Status', (36, 36))]
# prs: ('Status', (4, 4))
# Match
# prs: ('Status', (15, 15))
# prs: ('Status', (24, 25))
# prs: ('Status', (29, 29))
# prs: ('Status', (36, 36))
# pes: ('Drug', (11, 11))
# --------------------------------------------------
# Entity
# rlb: 5
# rlb: 5
# --------------------------------------------------
# Entity
# rlb: 7
# rlb: 7
# --------------------------------------------------
# Entity
# rlb: 11
# rlb: 11
# Entity Match
# ################
# Role
# rle: (9, 10, 'Type')
# ppppppppp
# [('Type', (9, 10)), ('Location', (20, 22)), ('Type', (29, 29)), ('Amount', (31, 31)), ('Type', (32, 32))]
# prs: ('Type', (9, 10))
# Match
# prs: ('Location', (20, 22))
# prs: ('Type', (29, 29))
# prs: ('Amount', (31, 31))
# prs: ('Type', (32, 32))
# ################
# Role
# rle: (4, 4, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (4, 4)), ('Status', (15, 15)), ('Status', (24, 25)), ('Status', (29, 29)), ('Status', (36, 36))]
# prs: ('Status', (4, 4))
# Match
# prs: ('Status', (15, 15))
# prs: ('Status', (24, 25))
# prs: ('Status', (29, 29))
# prs: ('Status', (36, 36))
# pes: ('Family', (31, 32))
# --------------------------------------------------
# Entity
# rlb: 5
# rlb: 5
# --------------------------------------------------
# Entity
# rlb: 7
# rlb: 7
# --------------------------------------------------
# Entity
# rlb: 11
# rlb: 11
# --------------------------------------------------
# Entity
# rlb: 31
# rlb: 32
# Entity Match
# ################
# Role
# rle: (32, 32, 'Type')
# ppppppppp
# [('Type', (9, 10)), ('Location', (20, 22)), ('Type', (29, 29)), ('Amount', (31, 31)), ('Type', (32, 32))]
# prs: ('Type', (9, 10))
# prs: ('Location', (20, 22))
# prs: ('Type', (29, 29))
# prs: ('Amount', (31, 31))
# Match
# prs: ('Type', (32, 32))
# Match
# ################
# Role
# rle: (31, 31, 'Amount')
# ppppppppp
# [('Type', (9, 10)), ('Location', (20, 22)), ('Type', (29, 29)), ('Amount', (31, 31)), ('Type', (32, 32))]
# prs: ('Type', (9, 10))
# prs: ('Location', (20, 22))
# prs: ('Type', (29, 29))
# Match
# prs: ('Amount', (31, 31))
# Match
# prs: ('Type', (32, 32))
# Match
# {(('Tobacco', (5, 5)), ('Type', (9, 10))): 'No Relation', (('Tobacco', (5, 5)), ('Location', (20, 22))): 'No Relation', (('Tobacco', (5, 5)), ('Type', (29, 29))): 'No Relation', (('Tobacco', (5, 5)), ('Amount', (31, 31))): 'No Relation', (('Tobacco', (5, 5)), ('Type', (32, 32))): 'No Relation', (('Alcohol', (7, 7)), ('Type', (9, 10))): 'No Relation', (('Alcohol', (7, 7)), ('Location', (20, 22))): 'No Relation', (('Alcohol', (7, 7)), ('Type', (29, 29))): 'No Relation', (('Alcohol', (7, 7)), ('Amount', (31, 31))): 'No Relation', (('Alcohol', (7, 7)), ('Type', (32, 32))): 'No Relation', (('Drug', (11, 11)), ('Type', (9, 10))): 'Relation', (('Drug', (11, 11)), ('Location', (20, 22))): 'No Relation', (('Drug', (11, 11)), ('Type', (29, 29))): 'No Relation', (('Drug', (11, 11)), ('Amount', (31, 31))): 'No Relation', (('Drug', (11, 11)), ('Type', (32, 32))): 'No Relation', (('Family', (31, 32)), ('Type', (9, 10))): 'No Relation', (('Family', (31, 32)), ('Location', (20, 22))): 'No Relation', (('Family', (31, 32)), ('Type', (29, 29))): 'Relation', (('Family', (31, 32)), ('Amount', (31, 31))): 'Relation', (('Family', (31, 32)), ('Type', (32, 32))): 'Relation', (('Tobacco', (5, 5)), ('Status', (4, 4))): 'Relation', (('Tobacco', (5, 5)), ('Status', (15, 15))): 'No Relation', (('Tobacco', (5, 5)), ('Status', (24, 25))): 'No Relation', (('Tobacco', (5, 5)), ('Status', (29, 29))): 'No Relation', (('Tobacco', (5, 5)), ('Status', (36, 36))): 'No Relation', (('Alcohol', (7, 7)), ('Status', (4, 4))): 'Relation', (('Alcohol', (7, 7)), ('Status', (15, 15))): 'No Relation', (('Alcohol', (7, 7)), ('Status', (24, 25))): 'No Relation', (('Alcohol', (7, 7)), ('Status', (29, 29))): 'No Relation', (('Alcohol', (7, 7)), ('Status', (36, 36))): 'No Relation', (('Drug', (11, 11)), ('Status', (4, 4))): 'Relation', (('Drug', (11, 11)), ('Status', (15, 15))): 'No Relation', (('Drug', (11, 11)), ('Status', (24, 25))): 'No Relation', (('Drug', (11, 11)), ('Status', (29, 29))): 'No Relation', (('Drug', (11, 11)), ('Status', (36, 36))): 'No Relation', (('Family', (31, 32)), ('Status', (4, 4))): 'No Relation', (('Family', (31, 32)), ('Status', (15, 15))): 'No Relation', (('Family', (31, 32)), ('Status', (24, 25))): 'No Relation', (('Family', (31, 32)), ('Status', (29, 29))): 'No Relation', (('Family', (31, 32)), ('Status', (36, 36))): 'No Relation', (('Tobacco', (5, 5)), ('Method', (17, 18))): 'No Relation', (('Alcohol', (7, 7)), ('Method', (17, 18))): 'No Relation', (('Drug', (11, 11)), ('Method', (17, 18))): 'No Relation', (('Family', (31, 32)), ('Method', (17, 18))): 'No Relation'}
# 6
# [('Alcohol', (20, 21))]
# pes: ('Alcohol', (20, 21))
# --------------------------------------------------
# Entity
# rlb: 8
# rlb: 15
# --------------------------------------------------
# Entity
# rlb: 20
# rlb: 22
# Entity Match
# ################
# Role
# rle: (18, 18, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (6, 7)), ('Status', (18, 18))]
# prs: ('Status', (6, 7))
# prs: ('Status', (18, 18))
# Match
# {(('Alcohol', (20, 21)), ('Amount', (8, 10))): 'No Relation', (('Alcohol', (20, 21)), ('Type', (12, 12))): 'No Relation', (('Alcohol', (20, 21)), ('Amount', (13, 13))): 'No Relation', (('Alcohol', (20, 21)), ('Frequency', (14, 15))): 'No Relation', (('Alcohol', (20, 21)), ('Status', (6, 7))): 'No Relation', (('Alcohol', (20, 21)), ('Status', (18, 18))): 'Relation'}
# 12
# [('Tobacco', (11, 12)), ('Family', (17, 17))]
# pes: ('Tobacco', (11, 12))
# --------------------------------------------------
# Entity
# rlb: 11
# rlb: 12
# Entity Match
# ################
# Role
# rle: (10, 10, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (5, 5)), ('Status', (10, 10)), ('Status', (14, 14))]
# prs: ('Status', (5, 5))
# prs: ('Status', (10, 10))
# Match
# prs: ('Status', (14, 14))
# pes: ('Family', (17, 17))
# --------------------------------------------------
# Entity
# rlb: 11
# rlb: 12
# --------------------------------------------------
# Entity
# rlb: 17
# rlb: 17
# Entity Match
# ################
# Role
# rle: (17, 17, 'Type')
# ppppppppp
# [('Type', (6, 6)), ('Type', (17, 17))]
# prs: ('Type', (6, 6))
# prs: ('Type', (17, 17))
# Match
# {(('Tobacco', (11, 12)), ('Type', (6, 6))): 'No Relation', (('Tobacco', (11, 12)), ('Type', (17, 17))): 'No Relation', (('Family', (17, 17)), ('Type', (6, 6))): 'No Relation', (('Family', (17, 17)), ('Type', (17, 17))): 'Relation', (('Tobacco', (11, 12)), ('Status', (5, 5))): 'No Relation', (('Tobacco', (11, 12)), ('Status', (10, 10))): 'Relation', (('Tobacco', (11, 12)), ('Status', (14, 14))): 'No Relation', (('Family', (17, 17)), ('Status', (5, 5))): 'No Relation', (('Family', (17, 17)), ('Status', (10, 10))): 'No Relation', (('Family', (17, 17)), ('Status', (14, 14))): 'No Relation', (('Tobacco', (11, 12)), ('Method', (14, 17))): 'No Relation', (('Family', (17, 17)), ('Method', (14, 17))): 'No Relation'}
# 18
# [('Alcohol', (21, 21)), ('Tobacco', (23, 23)), ('Family', (34, 39))]
# pes: ('Alcohol', (21, 21))
# --------------------------------------------------
# Entity
# rlb: 21
# rlb: 21
# Entity Match
# ################
# Role
# rle: (19, 19, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (18, 19)), ('Status', (27, 28))]
# prs: ('Status', (18, 19))
# Match
# prs: ('Status', (27, 28))
# pes: ('Tobacco', (23, 23))
# --------------------------------------------------
# Entity
# rlb: 21
# rlb: 21
# Entity Match
# ################
# Role
# rle: (19, 19, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (18, 19)), ('Status', (27, 28))]
# prs: ('Status', (18, 19))
# Match
# prs: ('Status', (27, 28))
# pes: ('Family', (34, 39))
# --------------------------------------------------
# Entity
# rlb: 21
# rlb: 21
# --------------------------------------------------
# Entity
# rlb: 23
# rlb: 23
# --------------------------------------------------
# Entity
# rlb: 34
# rlb: 40
# Entity Match
# ################
# Role
# rle: (34, 38, 'Amount')
# ppppppppp
# [('Location', (13, 15)), ('Type', (29, 29)), ('Amount', (34, 38)), ('Type', (39, 39))]
# prs: ('Location', (13, 15))
# prs: ('Type', (29, 29))
# prs: ('Amount', (34, 38))
# Match
# prs: ('Type', (39, 39))
# Match
# ################
# Role
# rle: (39, 39, 'Type')
# ppppppppp
# [('Location', (13, 15)), ('Type', (29, 29)), ('Amount', (34, 38)), ('Type', (39, 39))]
# prs: ('Location', (13, 15))
# prs: ('Type', (29, 29))
# prs: ('Amount', (34, 38))
# prs: ('Type', (39, 39))
# Match
# {(('Alcohol', (21, 21)), ('Location', (13, 15))): 'No Relation', (('Alcohol', (21, 21)), ('Type', (29, 29))): 'No Relation', (('Alcohol', (21, 21)), ('Amount', (34, 38))): 'No Relation', (('Alcohol', (21, 21)), ('Type', (39, 39))): 'No Relation', (('Tobacco', (23, 23)), ('Location', (13, 15))): 'No Relation', (('Tobacco', (23, 23)), ('Type', (29, 29))): 'No Relation', (('Tobacco', (23, 23)), ('Amount', (34, 38))): 'No Relation', (('Tobacco', (23, 23)), ('Type', (39, 39))): 'No Relation', (('Family', (34, 39)), ('Location', (13, 15))): 'No Relation', (('Family', (34, 39)), ('Type', (29, 29))): 'No Relation', (('Family', (34, 39)), ('Amount', (34, 38))): 'Relation', (('Family', (34, 39)), ('Type', (39, 39))): 'Relation', (('Alcohol', (21, 21)), ('Status', (18, 19))): 'Relation', (('Alcohol', (21, 21)), ('Status', (27, 28))): 'No Relation', (('Tobacco', (23, 23)), ('Status', (18, 19))): 'Relation', (('Tobacco', (23, 23)), ('Status', (27, 28))): 'No Relation', (('Family', (34, 39)), ('Status', (18, 19))): 'No Relation', (('Family', (34, 39)), ('Status', (27, 28))): 'No Relation'}
# 30
# [('Tobacco', (8, 9)), ('Alcohol', (13, 15)), ('Family', (26, 27))]
# pes: ('Tobacco', (8, 9))
# --------------------------------------------------
# Entity
# rlb: 8
# rlb: 9
# Entity Match
# ################
# Role
# rle: (7, 7, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (7, 7)), ('Status', (13, 13)), ('Status', (21, 21))]
# prs: ('Status', (7, 7))
# Match
# prs: ('Status', (13, 13))
# prs: ('Status', (21, 21))
# pes: ('Alcohol', (13, 15))
# --------------------------------------------------
# Entity
# rlb: 8
# rlb: 9
# --------------------------------------------------
# Entity
# rlb: 14
# rlb: 15
# Entity Match
# ################
# Role
# rle: (13, 13, 'Status')
# ppppppppp
# preictionspans_list: [('Status', (7, 7)), ('Status', (13, 13)), ('Status', (21, 21))]
# prs: ('Status', (7, 7))
# prs: ('Status', (13, 13))
# Match
# prs: ('Status', (21, 21))
# ################
# Role
# rle: (16, 18, 'Frequency')
# ppppppppp
# [('Frequency', (12, 12)), ('Frequency', (16, 18)), ('Type', (22, 22)), ('Amount', (26, 26)), ('Type', (27, 27)), ('Type', (31, 33)), ('Location', (35, 36))]
# prs: ('Frequency', (12, 12))
# prs: ('Frequency', (16, 18))
# Match
# prs: ('Type', (22, 22))
# prs: ('Amount', (26, 26))
# prs: ('Type', (27, 27))
# prs: ('Type', (31, 33))
# prs: ('Location', (35, 36))
# ################
# Role
# rle: (14, 15, 'Amount')
# ppppppppp
# [('Frequency', (12, 12)), ('Frequency', (16, 18)), ('Type', (22, 22)), ('Amount', (26, 26)), ('Type', (27, 27)), ('Type', (31, 33)), ('Location', (35, 36))]
# prs: ('Frequency', (12, 12))
# Match
# prs: ('Frequency', (16, 18))
# Match
# prs: ('Type', (22, 22))
# prs: ('Amount', (26, 26))
# prs: ('Type', (27, 27))
# prs: ('Type', (31, 33))
# prs: ('Location', (35, 36))
# pes: ('Family', (26, 27))
# --------------------------------------------------
# Entity
# rlb: 8
# rlb: 9
# --------------------------------------------------
# Entity
# rlb: 14
# rlb: 15
# --------------------------------------------------
# Entity
# rlb: 26
# rlb: 27
# Entity Match
# ################
# Role
# rle: (26, 26, 'Amount')
# ppppppppp
# [('Frequency', (12, 12)), ('Frequency', (16, 18)), ('Type', (22, 22)), ('Amount', (26, 26)), ('Type', (27, 27)), ('Type', (31, 33)), ('Location', (35, 36))]
# prs: ('Frequency', (12, 12))
# prs: ('Frequency', (16, 18))
# prs: ('Type', (22, 22))
# prs: ('Amount', (26, 26))
# Match
# prs: ('Type', (27, 27))
# Match
# prs: ('Type', (31, 33))
# prs: ('Location', (35, 36))
# ################
# Role
# rle: (27, 27, 'Type')
# ppppppppp
# [('Frequency', (12, 12)), ('Frequency', (16, 18)), ('Type', (22, 22)), ('Amount', (26, 26)), ('Type', (27, 27)), ('Type', (31, 33)), ('Location', (35, 36))]
# prs: ('Frequency', (12, 12))
# prs: ('Frequency', (16, 18))
# prs: ('Type', (22, 22))
# prs: ('Amount', (26, 26))
# Match
# prs: ('Type', (27, 27))
# Match
# prs: ('Type', (31, 33))
# prs: ('Location', (35, 36))
# {(('Tobacco', (8, 9)), ('Frequency', (12, 12))): 'No Relation', (('Tobacco', (8, 9)), ('Frequency', (16, 18))): 'No Relation', (('Tobacco', (8, 9)), ('Type', (22, 22))): 'No Relation', (('Tobacco', (8, 9)), ('Amount', (26, 26))): 'No Relation', (('Tobacco', (8, 9)), ('Type', (27, 27))): 'No Relation', (('Tobacco', (8, 9)), ('Type', (31, 33))): 'No Relation', (('Tobacco', (8, 9)), ('Location', (35, 36))): 'No Relation', (('Alcohol', (13, 15)), ('Frequency', (12, 12))): 'Relation', (('Alcohol', (13, 15)), ('Frequency', (16, 18))): 'Relation', (('Alcohol', (13, 15)), ('Type', (22, 22))): 'No Relation', (('Alcohol', (13, 15)), ('Amount', (26, 26))): 'No Relation', (('Alcohol', (13, 15)), ('Type', (27, 27))): 'No Relation', (('Alcohol', (13, 15)), ('Type', (31, 33))): 'No Relation', (('Alcohol', (13, 15)), ('Location', (35, 36))): 'No Relation', (('Family', (26, 27)), ('Frequency', (12, 12))): 'No Relation', (('Family', (26, 27)), ('Frequency', (16, 18))): 'No Relation', (('Family', (26, 27)), ('Type', (22, 22))): 'No Relation', (('Family', (26, 27)), ('Amount', (26, 26))): 'Relation', (('Family', (26, 27)), ('Type', (27, 27))): 'Relation', (('Family', (26, 27)), ('Type', (31, 33))): 'No Relation', (('Family', (26, 27)), ('Location', (35, 36))): 'No Relation', (('Tobacco', (8, 9)), ('Status', (7, 7))): 'Relation', (('Tobacco', (8, 9)), ('Status', (13, 13))): 'No Relation', (('Tobacco', (8, 9)), ('Status', (21, 21))): 'No Relation', (('Alcohol', (13, 15)), ('Status', (7, 7))): 'No Relation', (('Alcohol', (13, 15)), ('Status', (13, 13))): 'Relation', (('Alcohol', (13, 15)), ('Status', (21, 21))): 'No Relation', (('Family', (26, 27)), ('Status', (7, 7))): 'No Relation', (('Family', (26, 27)), ('Status', (13, 13))): 'No Relation', (('Family', (26, 27)), ('Status', (21, 21))): 'No Relation'}

# %%
missed_rel_perc_list
# Out:
# [['116_Consult-HistoryandPhy.-Consult-Sepsis_6', 8, 1],
#  ['285_Consult-HistoryandPhy.-IschemicCecum-Consult_8', 5, 3],
#  ['162_Consult-HistoryandPhy.-ENTConsult_14', 5, 1],
#  ['405_Consult-HistoryandPhy.-PainManagementConsult-2_7', 8, 3],
#  ['419_Consult-HistoryandPhy.-PreopCardiacConsult_9', 7, 2],
#  ['430_Consult-HistoryandPhy.-PsychConsult-Depression-1_9', 17, 12],
#  ["270_Consult-HistoryandPhy.-Huntington'sDisease-Consult_11", 7, 6],
#  ['28_Consult-HistoryandPhy.-AttemptedSuicide-Consult_10', 6, 5],
#  ['407_Consult-HistoryandPhy.-PediatricRheumatologyConsult_8', 4, 3],
#  ["514_Consult-HistoryandPhy.-Worker'sCompensationInjury_9", 3, 1],
#  ['233_Consult-HistoryandPhy.-GenMedConsult-52_7', 1, 1],
#  ['325_Consult-HistoryandPhy.-Murmur&Bacteremia._9', 4, 1],
#  ['132_Consult-HistoryandPhy.-DetoxfromHeroin_7', 7, 4],
#  ['399_Consult-HistoryandPhy.-OrthopedicConsult-3_9', 1, 1],
#  ['8_Consult-HistoryandPhy.-AcuteInferiorMyocardialInfarction_7', 6, 3],
#  ['524_Consult-HistoryandPhy.-AcuteInferiorMyocardialInfarction_7', 6, 3],
#  ['290_Consult-HistoryandPhy.-Kyphoplasty-Consult_9', 4, 1],
#  ['451_Consult-HistoryandPhy.-RecordsReview-Orthopedic_8', 5, 4]]

# %%
relation_df=pd.DataFrame(relation_data_list)

# %%
relation_df['label'].value_counts()
# Out:
# No Relation    1172
# Relation        261
# Name: label, dtype: int64

# %%
rel_classifier_pth='/content/drive/MyDrive/PHD_assessment_gmu/models/final_models/Indepent_relation_classifier_v6/'

# %%
from transformers import BertForSequenceClassification
tokenizer2=BertTokenizerFast.from_pretrained(rel_classifier_pth)
rel_model=BertForSequenceClassification.from_pretrained(rel_classifier_pth)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
rel_model.to(device)
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(29000, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
def predict_relation(text):
  rel_model.eval()
  inputs=tokenizer2(text, add_special_tokens=True, padding='max_length',max_length=max_len , truncation=True,return_tensors='pt')
  with torch.no_grad():
    inp={k: v.to(device) for k, v in inputs.items()}
    outputs = rel_model(**inp)
  logits = outputs.logits
  raw_predictions = torch.argmax(logits, dim=-1)
  prediction=id_label_event[raw_predictions.item()]
  return prediction

# %%
relation_df['predict_relation']=relation_df['text'].apply(predict_relation)

# %%
relation_df.shape
# Out:
# (1433, 5)

# %%
relation_df
# Out:
#                                               file_name  \
# 0     112_Consult-HistoryandPhy.-Consult-RectalBleed...
# 1     112_Consult-HistoryandPhy.-Consult-RectalBleed...
# 2     112_Consult-HistoryandPhy.-Consult-RectalBleed...
# 3     112_Consult-HistoryandPhy.-Consult-RectalBleed...
# 4     112_Consult-HistoryandPhy.-Consult-RectalBleed...
# ...                                                 ...
# 1428  185_Consult-HistoryandPhy.-GastrointestinalBle...
# 1429  185_Consult-HistoryandPhy.-GastrointestinalBle...
# 1430  185_Consult-HistoryandPhy.-GastrointestinalBle...
# 1431  185_Consult-HistoryandPhy.-GastrointestinalBle...
# 1432  185_Consult-HistoryandPhy.-GastrointestinalBle...
#
#                                                    text   Entity  \
# 0     SOCIAL HISTORY:  The patient is retired. He is...   Family
# 1     SOCIAL HISTORY:  The patient is retired. He is...   Family
# 2     SOCIAL HISTORY:  The patient is retired. He is...   Family
# 3     SOCIAL HISTORY:  The patient is retired. He is...   Family
# 4     SOCIAL HISTORY:  The patient is retired. He is...   Family
# ...                                                 ...      ...
# 1428  SOCIAL HISTORY: She is a nonsmoker. She occasi...  Alcohol
# 1429  SOCIAL HISTORY: She is a nonsmoker. She occasi...  Alcohol
# 1430  SOCIAL HISTORY: She is a  [SPAN2_START] non [S...   Family
# 1431  SOCIAL HISTORY: She is a nonsmoker. She occasi...   Family
# 1432  SOCIAL HISTORY: She is a nonsmoker. She occasi...   Family
#
#                  Role        label predict_relation
# 0                Type  No Relation      No Relation
# 1              Amount     Relation         Relation
# 2                Type     Relation         Relation
# 3         QuitHistory  No Relation      No Relation
# 4     ExposureHistory  No Relation      No Relation
# ...               ...          ...              ...
# 1428           Status     Relation         Relation
# 1429           Status  No Relation      No Relation
# 1430           Status  No Relation      No Relation
# 1431           Status  No Relation      No Relation
# 1432           Status  No Relation      No Relation
#
# [1433 rows x 6 columns]

# %%
missed_rel_perc_list
# Out:
# [['116_Consult-HistoryandPhy.-Consult-Sepsis_6', 8, 1],
#  ['285_Consult-HistoryandPhy.-IschemicCecum-Consult_8', 5, 3],
#  ['162_Consult-HistoryandPhy.-ENTConsult_14', 5, 1],
#  ['405_Consult-HistoryandPhy.-PainManagementConsult-2_7', 8, 3],
#  ['419_Consult-HistoryandPhy.-PreopCardiacConsult_9', 7, 2],
#  ['430_Consult-HistoryandPhy.-PsychConsult-Depression-1_9', 17, 12],
#  ["270_Consult-HistoryandPhy.-Huntington'sDisease-Consult_11", 7, 6],
#  ['28_Consult-HistoryandPhy.-AttemptedSuicide-Consult_10', 6, 5],
#  ['407_Consult-HistoryandPhy.-PediatricRheumatologyConsult_8', 4, 3],
#  ["514_Consult-HistoryandPhy.-Worker'sCompensationInjury_9", 3, 1],
#  ['233_Consult-HistoryandPhy.-GenMedConsult-52_7', 1, 1],
#  ['325_Consult-HistoryandPhy.-Murmur&Bacteremia._9', 4, 1],
#  ['132_Consult-HistoryandPhy.-DetoxfromHeroin_7', 7, 4],
#  ['399_Consult-HistoryandPhy.-OrthopedicConsult-3_9', 1, 1],
#  ['8_Consult-HistoryandPhy.-AcuteInferiorMyocardialInfarction_7', 6, 3],
#  ['524_Consult-HistoryandPhy.-AcuteInferiorMyocardialInfarction_7', 6, 3],
#  ['290_Consult-HistoryandPhy.-Kyphoplasty-Consult_9', 4, 1],
#  ['451_Consult-HistoryandPhy.-RecordsReview-Orthopedic_8', 5, 4]]

# %%
relation_df[relation_df['label']!=relation_df['predict_relation']].iloc[0]
# Out:
# file_name           112_Consult-HistoryandPhy.-Consult-RectalBleed...
# text                SOCIAL HISTORY:  The patient is retired. He is...
# Entity                                                         Family
# Role                                                             Type
# label                                                     No Relation
# predict_relation                                             Relation
# Name: 2, dtype: object

# %%
wrng_pred_file_nms=relation_df[relation_df['label']!=relation_df['predict_relation']]['file_name'].tolist()

# %%
set(wrng_pred_file_nms)
# Out:
# {'118_Consult-HistoryandPhy.-Consult-StasisUlcer_7',
#  '124_Consult-HistoryandPhy.-Consult_ERReport-OB_GYN_8',
#  '132_Consult-HistoryandPhy.-DetoxfromHeroin_7',
#  '184_Consult-HistoryandPhy.-GastricBypassDiscussion-3_7',
#  '190_Consult-HistoryandPhy.-GenMedConsult-13_8',
#  '19_Consult-HistoryandPhy.-AnkleSprain-H&P_9',
#  '204_Consult-HistoryandPhy.-GenMedConsult-26_9',
#  '233_Consult-HistoryandPhy.-GenMedConsult-52_7',
#  '259_Consult-HistoryandPhy.-Head&NeckCancerConsult_9',
#  '264_Consult-HistoryandPhy.-Hematuria-ERVisit_7',
#  '266_Consult-HistoryandPhy.-HipFracture-ERConsult_8',
#  '285_Consult-HistoryandPhy.-IschemicCecum-Consult_8',
#  '28_Consult-HistoryandPhy.-AttemptedSuicide-Consult_10',
#  '290_Consult-HistoryandPhy.-Kyphoplasty-Consult_9',
#  '301_Consult-HistoryandPhy.-LowBackPain-Consult_5',
#  '303_Consult-HistoryandPhy.-LowerQuadrantPain_10',
#  '326_Consult-HistoryandPhy.-Neck&BackPain_12',
#  '405_Consult-HistoryandPhy.-PainManagementConsult-2_7',
#  '407_Consult-HistoryandPhy.-PediatricRheumatologyConsult_8',
#  '419_Consult-HistoryandPhy.-PreopCardiacConsult_9',
#  '432_Consult-HistoryandPhy.-PsychConsult-Lethargy_11',
#  '457_Consult-HistoryandPhy.-RenalFailureEvaluation_8',
#  '510_Consult-HistoryandPhy.-Well-ChildCheck-5_6',
#  '524_Consult-HistoryandPhy.-AcuteInferiorMyocardialInfarction_7',
#  '8_Consult-HistoryandPhy.-AcuteInferiorMyocardialInfarction_7'}

# %%
for e in missed_rel_perc_list:
  if e[0] in wrng_pred_file_nms:
    print(e)
# Out:
# ['285_Consult-HistoryandPhy.-IschemicCecum-Consult_8', 5, 3]
# ['405_Consult-HistoryandPhy.-PainManagementConsult-2_7', 8, 3]
# ['419_Consult-HistoryandPhy.-PreopCardiacConsult_9', 7, 2]
# ['28_Consult-HistoryandPhy.-AttemptedSuicide-Consult_10', 6, 5]
# ['407_Consult-HistoryandPhy.-PediatricRheumatologyConsult_8', 4, 3]
# ['233_Consult-HistoryandPhy.-GenMedConsult-52_7', 1, 1]
# ['132_Consult-HistoryandPhy.-DetoxfromHeroin_7', 7, 4]
# ['8_Consult-HistoryandPhy.-AcuteInferiorMyocardialInfarction_7', 6, 3]
# ['524_Consult-HistoryandPhy.-AcuteInferiorMyocardialInfarction_7', 6, 3]
# ['290_Consult-HistoryandPhy.-Kyphoplasty-Consult_9', 4, 1]

# %%
relation_df[relation_df['file_name']=='285_Consult-HistoryandPhy.-IschemicCecum-Consult_8']
# Out:
#                                              file_name  \
# 190  285_Consult-HistoryandPhy.-IschemicCecum-Consu...
# 191  285_Consult-HistoryandPhy.-IschemicCecum-Consu...
# 192  285_Consult-HistoryandPhy.-IschemicCecum-Consu...
# 193  285_Consult-HistoryandPhy.-IschemicCecum-Consu...
# 194  285_Consult-HistoryandPhy.-IschemicCecum-Consu...
# 195  285_Consult-HistoryandPhy.-IschemicCecum-Consu...
#
#                                                   text   Entity         Role  \
# 190  SOCIAL HISTORY:  The patient had a long histor...  Tobacco  QuitHistory
# 191  SOCIAL HISTORY:  The patient had a long histor...  Tobacco    Frequency
# 192  SOCIAL HISTORY:  The patient had a long histor...  Alcohol  QuitHistory
# 193  SOCIAL HISTORY:  The patient had a long histor...  Alcohol    Frequency
# 194  SOCIAL HISTORY:  The patient had a long  [SPAN...  Tobacco       Status
# 195  SOCIAL HISTORY:  The patient had a long  [SPAN...  Alcohol       Status
#
#            label predict_relation
# 190     Relation         Relation
# 191  No Relation      No Relation
# 192  No Relation      No Relation
# 193     Relation         Relation
# 194  No Relation         Relation
# 195  No Relation      No Relation

# %%
relation_df[relation_df['label']!=relation_df['predict_relation']]
# Out:
#                                               file_name  \
# 56     118_Consult-HistoryandPhy.-Consult-StasisUlcer_7
# 67        190_Consult-HistoryandPhy.-GenMedConsult-13_8
# 71    259_Consult-HistoryandPhy.-Head&NeckCancerCons...
# 103   259_Consult-HistoryandPhy.-Head&NeckCancerCons...
# 150   259_Consult-HistoryandPhy.-Head&NeckCancerCons...
# 151   259_Consult-HistoryandPhy.-Head&NeckCancerCons...
# 194   285_Consult-HistoryandPhy.-IschemicCecum-Consu...
# 196     303_Consult-HistoryandPhy.-LowerQuadrantPain_10
# 440   405_Consult-HistoryandPhy.-PainManagementConsu...
# 453   405_Consult-HistoryandPhy.-PainManagementConsu...
# 484    419_Consult-HistoryandPhy.-PreopCardiacConsult_9
# 485    419_Consult-HistoryandPhy.-PreopCardiacConsult_9
# 486    419_Consult-HistoryandPhy.-PreopCardiacConsult_9
# 566   28_Consult-HistoryandPhy.-AttemptedSuicide-Con...
# 573   432_Consult-HistoryandPhy.-PsychConsult-Lethar...
# 589   432_Consult-HistoryandPhy.-PsychConsult-Lethar...
# 698   124_Consult-HistoryandPhy.-Consult_ERReport-OB...
# 705   124_Consult-HistoryandPhy.-Consult_ERReport-OB...
# 706   124_Consult-HistoryandPhy.-Consult_ERReport-OB...
# 707   124_Consult-HistoryandPhy.-Consult_ERReport-OB...
# 746   124_Consult-HistoryandPhy.-Consult_ERReport-OB...
# 751   124_Consult-HistoryandPhy.-Consult_ERReport-OB...
# 755   124_Consult-HistoryandPhy.-Consult_ERReport-OB...
# 776   184_Consult-HistoryandPhy.-GastricBypassDiscus...
# 791   407_Consult-HistoryandPhy.-PediatricRheumatolo...
# 834         19_Consult-HistoryandPhy.-AnkleSprain-H&P_9
# 836         19_Consult-HistoryandPhy.-AnkleSprain-H&P_9
# 847       233_Consult-HistoryandPhy.-GenMedConsult-52_7
# 967   266_Consult-HistoryandPhy.-HipFracture-ERConsu...
# 1019       132_Consult-HistoryandPhy.-DetoxfromHeroin_7
# 1021       132_Consult-HistoryandPhy.-DetoxfromHeroin_7
# 1028       132_Consult-HistoryandPhy.-DetoxfromHeroin_7
# 1029       132_Consult-HistoryandPhy.-DetoxfromHeroin_7
# 1042  457_Consult-HistoryandPhy.-RenalFailureEvaluat...
# 1056        326_Consult-HistoryandPhy.-Neck&BackPain_12
# 1071        326_Consult-HistoryandPhy.-Neck&BackPain_12
# 1096  8_Consult-HistoryandPhy.-AcuteInferiorMyocardi...
# 1097  8_Consult-HistoryandPhy.-AcuteInferiorMyocardi...
# 1098  8_Consult-HistoryandPhy.-AcuteInferiorMyocardi...
# 1106  8_Consult-HistoryandPhy.-AcuteInferiorMyocardi...
# 1107  8_Consult-HistoryandPhy.-AcuteInferiorMyocardi...
# 1142   301_Consult-HistoryandPhy.-LowBackPain-Consult_5
# 1143   301_Consult-HistoryandPhy.-LowBackPain-Consult_5
# 1167  524_Consult-HistoryandPhy.-AcuteInferiorMyocar...
# 1168  524_Consult-HistoryandPhy.-AcuteInferiorMyocar...
# 1169  524_Consult-HistoryandPhy.-AcuteInferiorMyocar...
# 1177  524_Consult-HistoryandPhy.-AcuteInferiorMyocar...
# 1178  524_Consult-HistoryandPhy.-AcuteInferiorMyocar...
# 1226     264_Consult-HistoryandPhy.-Hematuria-ERVisit_7
# 1234   290_Consult-HistoryandPhy.-Kyphoplasty-Consult_9
# 1241     510_Consult-HistoryandPhy.-Well-ChildCheck-5_6
# 1242     510_Consult-HistoryandPhy.-Well-ChildCheck-5_6
# 1260     510_Consult-HistoryandPhy.-Well-ChildCheck-5_6
# 1261     510_Consult-HistoryandPhy.-Well-ChildCheck-5_6
# 1340      204_Consult-HistoryandPhy.-GenMedConsult-26_9
#
#                                                    text   Entity         Role  \
# 56    SOCIAL HISTORY:  The patient admits  [SPAN2_ST...  Alcohol       Status
# 67    SOCIAL HISTORY: She is married. A 76-year-old ...  Tobacco       Status
# 71    SOCIAL HISTORY:  The patient is married but ha...   Family         Type
# 103   SOCIAL HISTORY:  The patient is married but ha...  Tobacco     Location
# 150   SOCIAL HISTORY:  The patient is married but ha...  Tobacco       Status
# 151   SOCIAL HISTORY:  The patient is married but ha...  Tobacco       Status
# 194   SOCIAL HISTORY:  The patient had a long  [SPAN...  Tobacco       Status
# 196   SOCIAL HISTORY: The patient does not  [SPAN1_S...  Tobacco  QuitHistory
# 440   PERSONAL AND SOCIAL HISTORY: Marital status: M...  Alcohol       Amount
# 453   PERSONAL AND SOCIAL HISTORY: Marital status: M...  Alcohol       Status
# 484   SOCIAL HISTORY: She used to smoke cigarettes a...   Family         Type
# 485   SOCIAL HISTORY: She  [SPAN2_START] used to [SP...  Tobacco       Status
# 486   SOCIAL HISTORY: She used to  [SPAN1_START] smo...  Tobacco       Status
# 566   SOCIAL HISTORY: The patient lives with his gir...     Drug       Amount
# 573   SOCIAL AND DEVELOPMENTAL HISTORY: Currently li...   Family     Location
# 589   SOCIAL AND DEVELOPMENTAL HISTORY: Currently li...   Family         Type
# 698   SOCIAL HISTORY: The patient denies tobacco, et...   Family         Type
# 705   SOCIAL HISTORY: The patient denies tobacco, et...   Family         Type
# 706   SOCIAL HISTORY: The patient denies tobacco, et...   Family       Amount
# 707   SOCIAL HISTORY: The patient denies tobacco, et...   Family         Type
# 746   SOCIAL HISTORY: The patient denies tobacco, et...   Family       Method
# 751   SOCIAL HISTORY: The patient denies tobacco, et...   Family       Method
# 755   SOCIAL HISTORY: The patient denies tobacco, et...   Family       Method
# 776   SOCIAL HISTORY:  The patient is a life long no...   Family         Type
# 791   SOCIAL HISTORY:  He lives with  [SPAN1_START] ...   Family         Type
# 834   SOCIAL HISTORY:  The patient lives here locall...  Alcohol       Amount
# 836   SOCIAL HISTORY:  The patient lives here locall...     Drug       Amount
# 847   SOCIAL HISTORY:  [SPAN2_START] History of [SPA...  Alcohol       Status
# 967   SOCIAL HISTORY:  Denies any tobacco or alcohol...   Family         Type
# 1019  SOCIAL HISTORY:  The patient is a smoker. Admi...     Drug       Amount
# 1021  SOCIAL HISTORY:  The patient is a smoker. Admi...  Alcohol         Type
# 1028  SOCIAL HISTORY:  The patient is a smoker.  [SP...     Drug       Status
# 1029  SOCIAL HISTORY:  The patient is a smoker.  [SP...  Alcohol       Status
# 1042  SOCIAL HISTORY:  He is married. He does smoke ...  Alcohol         Type
# 1056  SOCIAL HISTORY: The patient is retired. She is...   Family         Type
# 1071  SOCIAL HISTORY: The patient is retired. She is...     Drug         Type
# 1096  SOCIAL HISTORY:  Denies alcohol or drugs.  [SP...  Tobacco       Amount
# 1097  SOCIAL HISTORY:  Denies alcohol or drugs.  [SP...  Tobacco         Type
# 1098  SOCIAL HISTORY:  Denies alcohol or drugs.  [SP...  Tobacco    Frequency
# 1106  SOCIAL HISTORY:   [SPAN2_START] Denies [SPAN2_...  Tobacco       Status
# 1107  SOCIAL HISTORY:  Denies alcohol or drugs.  [SP...  Tobacco       Status
# 1142  SOCIAL HISTORY: He is married and has support ...  Alcohol       Amount
# 1143  SOCIAL HISTORY: He is married and has support ...  Alcohol    Frequency
# 1167  SOCIAL HISTORY:  Denies alcohol or drugs.  [SP...  Tobacco       Amount
# 1168  SOCIAL HISTORY:  Denies alcohol or drugs.  [SP...  Tobacco         Type
# 1169  SOCIAL HISTORY:  Denies alcohol or drugs.  [SP...  Tobacco    Frequency
# 1177  SOCIAL HISTORY:   [SPAN2_START] Denies [SPAN2_...  Tobacco       Status
# 1178  SOCIAL HISTORY:  Denies alcohol or drugs.  [SP...  Tobacco       Status
# 1226  SOCIAL HISTORY:  The patient lives at home wit...  Alcohol       Status
# 1234  PERSONAL AND SOCIAL HISTORY:  The patient live...     Drug         Type
# 1241  SOCIAL HISTORY: The patient lives at home with...   Family       Amount
# 1242  SOCIAL HISTORY: The patient lives at home with...   Family         Type
# 1260  SOCIAL HISTORY: The patient lives at home with...   Family       Amount
# 1261  SOCIAL HISTORY: The patient lives at home with...   Family         Type
# 1340  SOCIAL HISTORY: No tobacco, alcohol or illicit...   Family         Type
#
#             label predict_relation
# 56    No Relation         Relation
# 67    No Relation         Relation
# 71    No Relation         Relation
# 103      Relation      No Relation
# 150   No Relation         Relation
# 151      Relation      No Relation
# 194   No Relation         Relation
# 196      Relation      No Relation
# 440   No Relation         Relation
# 453   No Relation         Relation
# 484   No Relation         Relation
# 485   No Relation         Relation
# 486   No Relation         Relation
# 566   No Relation         Relation
# 573   No Relation         Relation
# 589   No Relation         Relation
# 698   No Relation         Relation
# 705   No Relation         Relation
# 706   No Relation         Relation
# 707   No Relation         Relation
# 746   No Relation         Relation
# 751   No Relation         Relation
# 755   No Relation         Relation
# 776      Relation      No Relation
# 791      Relation      No Relation
# 834   No Relation         Relation
# 836   No Relation         Relation
# 847   No Relation         Relation
# 967      Relation      No Relation
# 1019  No Relation         Relation
# 1021  No Relation         Relation
# 1028  No Relation         Relation
# 1029  No Relation         Relation
# 1042  No Relation         Relation
# 1056     Relation      No Relation
# 1071  No Relation         Relation
# 1096  No Relation         Relation
# 1097  No Relation         Relation
# 1098  No Relation         Relation
# 1106     Relation      No Relation
# 1107  No Relation         Relation
# 1142  No Relation         Relation
# 1143  No Relation         Relation
# 1167  No Relation         Relation
# 1168  No Relation         Relation
# 1169  No Relation         Relation
# 1177     Relation      No Relation
# 1178  No Relation         Relation
# 1226  No Relation         Relation
# 1234  No Relation         Relation
# 1241  No Relation         Relation
# 1242  No Relation         Relation
# 1260  No Relation         Relation
# 1261  No Relation         Relation
# 1340     Relation      No Relation

# %%
Pos = relation_df[relation_df['label']=='Relation']
Neg = relation_df[relation_df['label']=='No Relation']

# %%
TP=Pos[Pos['label']==Pos['predict_relation']]

# %%
FN = Pos[Pos['label']!=Pos['predict_relation']]
FN
# Out:
#                                               file_name  \
# 103   259_Consult-HistoryandPhy.-Head&NeckCancerCons...
# 151   259_Consult-HistoryandPhy.-Head&NeckCancerCons...
# 196     303_Consult-HistoryandPhy.-LowerQuadrantPain_10
# 776   184_Consult-HistoryandPhy.-GastricBypassDiscus...
# 791   407_Consult-HistoryandPhy.-PediatricRheumatolo...
# 967   266_Consult-HistoryandPhy.-HipFracture-ERConsu...
# 1056        326_Consult-HistoryandPhy.-Neck&BackPain_12
# 1106  8_Consult-HistoryandPhy.-AcuteInferiorMyocardi...
# 1177  524_Consult-HistoryandPhy.-AcuteInferiorMyocar...
# 1340      204_Consult-HistoryandPhy.-GenMedConsult-26_9
#
#                                                    text   Entity         Role  \
# 103   SOCIAL HISTORY:  The patient is married but ha...  Tobacco     Location
# 151   SOCIAL HISTORY:  The patient is married but ha...  Tobacco       Status
# 196   SOCIAL HISTORY: The patient does not  [SPAN1_S...  Tobacco  QuitHistory
# 776   SOCIAL HISTORY:  The patient is a life long no...   Family         Type
# 791   SOCIAL HISTORY:  He lives with  [SPAN1_START] ...   Family         Type
# 967   SOCIAL HISTORY:  Denies any tobacco or alcohol...   Family         Type
# 1056  SOCIAL HISTORY: The patient is retired. She is...   Family         Type
# 1106  SOCIAL HISTORY:   [SPAN2_START] Denies [SPAN2_...  Tobacco       Status
# 1177  SOCIAL HISTORY:   [SPAN2_START] Denies [SPAN2_...  Tobacco       Status
# 1340  SOCIAL HISTORY: No tobacco, alcohol or illicit...   Family         Type
#
#          label predict_relation
# 103   Relation      No Relation
# 151   Relation      No Relation
# 196   Relation      No Relation
# 776   Relation      No Relation
# 791   Relation      No Relation
# 967   Relation      No Relation
# 1056  Relation      No Relation
# 1106  Relation      No Relation
# 1177  Relation      No Relation
# 1340  Relation      No Relation

# %%
FP=Neg[Neg['label']!=Neg['predict_relation']]
FP
# Out:
#                                               file_name  \
# 56     118_Consult-HistoryandPhy.-Consult-StasisUlcer_7
# 67        190_Consult-HistoryandPhy.-GenMedConsult-13_8
# 71    259_Consult-HistoryandPhy.-Head&NeckCancerCons...
# 150   259_Consult-HistoryandPhy.-Head&NeckCancerCons...
# 194   285_Consult-HistoryandPhy.-IschemicCecum-Consu...
# 440   405_Consult-HistoryandPhy.-PainManagementConsu...
# 453   405_Consult-HistoryandPhy.-PainManagementConsu...
# 484    419_Consult-HistoryandPhy.-PreopCardiacConsult_9
# 485    419_Consult-HistoryandPhy.-PreopCardiacConsult_9
# 486    419_Consult-HistoryandPhy.-PreopCardiacConsult_9
# 566   28_Consult-HistoryandPhy.-AttemptedSuicide-Con...
# 573   432_Consult-HistoryandPhy.-PsychConsult-Lethar...
# 589   432_Consult-HistoryandPhy.-PsychConsult-Lethar...
# 698   124_Consult-HistoryandPhy.-Consult_ERReport-OB...
# 705   124_Consult-HistoryandPhy.-Consult_ERReport-OB...
# 706   124_Consult-HistoryandPhy.-Consult_ERReport-OB...
# 707   124_Consult-HistoryandPhy.-Consult_ERReport-OB...
# 746   124_Consult-HistoryandPhy.-Consult_ERReport-OB...
# 751   124_Consult-HistoryandPhy.-Consult_ERReport-OB...
# 755   124_Consult-HistoryandPhy.-Consult_ERReport-OB...
# 834         19_Consult-HistoryandPhy.-AnkleSprain-H&P_9
# 836         19_Consult-HistoryandPhy.-AnkleSprain-H&P_9
# 847       233_Consult-HistoryandPhy.-GenMedConsult-52_7
# 1019       132_Consult-HistoryandPhy.-DetoxfromHeroin_7
# 1021       132_Consult-HistoryandPhy.-DetoxfromHeroin_7
# 1028       132_Consult-HistoryandPhy.-DetoxfromHeroin_7
# 1029       132_Consult-HistoryandPhy.-DetoxfromHeroin_7
# 1042  457_Consult-HistoryandPhy.-RenalFailureEvaluat...
# 1071        326_Consult-HistoryandPhy.-Neck&BackPain_12
# 1096  8_Consult-HistoryandPhy.-AcuteInferiorMyocardi...
# 1097  8_Consult-HistoryandPhy.-AcuteInferiorMyocardi...
# 1098  8_Consult-HistoryandPhy.-AcuteInferiorMyocardi...
# 1107  8_Consult-HistoryandPhy.-AcuteInferiorMyocardi...
# 1142   301_Consult-HistoryandPhy.-LowBackPain-Consult_5
# 1143   301_Consult-HistoryandPhy.-LowBackPain-Consult_5
# 1167  524_Consult-HistoryandPhy.-AcuteInferiorMyocar...
# 1168  524_Consult-HistoryandPhy.-AcuteInferiorMyocar...
# 1169  524_Consult-HistoryandPhy.-AcuteInferiorMyocar...
# 1178  524_Consult-HistoryandPhy.-AcuteInferiorMyocar...
# 1226     264_Consult-HistoryandPhy.-Hematuria-ERVisit_7
# 1234   290_Consult-HistoryandPhy.-Kyphoplasty-Consult_9
# 1241     510_Consult-HistoryandPhy.-Well-ChildCheck-5_6
# 1242     510_Consult-HistoryandPhy.-Well-ChildCheck-5_6
# 1260     510_Consult-HistoryandPhy.-Well-ChildCheck-5_6
# 1261     510_Consult-HistoryandPhy.-Well-ChildCheck-5_6
#
#                                                    text   Entity       Role  \
# 56    SOCIAL HISTORY:  The patient admits  [SPAN2_ST...  Alcohol     Status
# 67    SOCIAL HISTORY: She is married. A 76-year-old ...  Tobacco     Status
# 71    SOCIAL HISTORY:  The patient is married but ha...   Family       Type
# 150   SOCIAL HISTORY:  The patient is married but ha...  Tobacco     Status
# 194   SOCIAL HISTORY:  The patient had a long  [SPAN...  Tobacco     Status
# 440   PERSONAL AND SOCIAL HISTORY: Marital status: M...  Alcohol     Amount
# 453   PERSONAL AND SOCIAL HISTORY: Marital status: M...  Alcohol     Status
# 484   SOCIAL HISTORY: She used to smoke cigarettes a...   Family       Type
# 485   SOCIAL HISTORY: She  [SPAN2_START] used to [SP...  Tobacco     Status
# 486   SOCIAL HISTORY: She used to  [SPAN1_START] smo...  Tobacco     Status
# 566   SOCIAL HISTORY: The patient lives with his gir...     Drug     Amount
# 573   SOCIAL AND DEVELOPMENTAL HISTORY: Currently li...   Family   Location
# 589   SOCIAL AND DEVELOPMENTAL HISTORY: Currently li...   Family       Type
# 698   SOCIAL HISTORY: The patient denies tobacco, et...   Family       Type
# 705   SOCIAL HISTORY: The patient denies tobacco, et...   Family       Type
# 706   SOCIAL HISTORY: The patient denies tobacco, et...   Family     Amount
# 707   SOCIAL HISTORY: The patient denies tobacco, et...   Family       Type
# 746   SOCIAL HISTORY: The patient denies tobacco, et...   Family     Method
# 751   SOCIAL HISTORY: The patient denies tobacco, et...   Family     Method
# 755   SOCIAL HISTORY: The patient denies tobacco, et...   Family     Method
# 834   SOCIAL HISTORY:  The patient lives here locall...  Alcohol     Amount
# 836   SOCIAL HISTORY:  The patient lives here locall...     Drug     Amount
# 847   SOCIAL HISTORY:  [SPAN2_START] History of [SPA...  Alcohol     Status
# 1019  SOCIAL HISTORY:  The patient is a smoker. Admi...     Drug     Amount
# 1021  SOCIAL HISTORY:  The patient is a smoker. Admi...  Alcohol       Type
# 1028  SOCIAL HISTORY:  The patient is a smoker.  [SP...     Drug     Status
# 1029  SOCIAL HISTORY:  The patient is a smoker.  [SP...  Alcohol     Status
# 1042  SOCIAL HISTORY:  He is married. He does smoke ...  Alcohol       Type
# 1071  SOCIAL HISTORY: The patient is retired. She is...     Drug       Type
# 1096  SOCIAL HISTORY:  Denies alcohol or drugs.  [SP...  Tobacco     Amount
# 1097  SOCIAL HISTORY:  Denies alcohol or drugs.  [SP...  Tobacco       Type
# 1098  SOCIAL HISTORY:  Denies alcohol or drugs.  [SP...  Tobacco  Frequency
# 1107  SOCIAL HISTORY:  Denies alcohol or drugs.  [SP...  Tobacco     Status
# 1142  SOCIAL HISTORY: He is married and has support ...  Alcohol     Amount
# 1143  SOCIAL HISTORY: He is married and has support ...  Alcohol  Frequency
# 1167  SOCIAL HISTORY:  Denies alcohol or drugs.  [SP...  Tobacco     Amount
# 1168  SOCIAL HISTORY:  Denies alcohol or drugs.  [SP...  Tobacco       Type
# 1169  SOCIAL HISTORY:  Denies alcohol or drugs.  [SP...  Tobacco  Frequency
# 1178  SOCIAL HISTORY:  Denies alcohol or drugs.  [SP...  Tobacco     Status
# 1226  SOCIAL HISTORY:  The patient lives at home wit...  Alcohol     Status
# 1234  PERSONAL AND SOCIAL HISTORY:  The patient live...     Drug       Type
# 1241  SOCIAL HISTORY: The patient lives at home with...   Family     Amount
# 1242  SOCIAL HISTORY: The patient lives at home with...   Family       Type
# 1260  SOCIAL HISTORY: The patient lives at home with...   Family     Amount
# 1261  SOCIAL HISTORY: The patient lives at home with...   Family       Type
#
#             label predict_relation
# 56    No Relation         Relation
# 67    No Relation         Relation
# 71    No Relation         Relation
# 150   No Relation         Relation
# 194   No Relation         Relation
# 440   No Relation         Relation
# 453   No Relation         Relation
# 484   No Relation         Relation
# 485   No Relation         Relation
# 486   No Relation         Relation
# 566   No Relation         Relation
# 573   No Relation         Relation
# 589   No Relation         Relation
# 698   No Relation         Relation
# 705   No Relation         Relation
# 706   No Relation         Relation
# 707   No Relation         Relation
# 746   No Relation         Relation
# 751   No Relation         Relation
# 755   No Relation         Relation
# 834   No Relation         Relation
# 836   No Relation         Relation
# 847   No Relation         Relation
# 1019  No Relation         Relation
# 1021  No Relation         Relation
# 1028  No Relation         Relation
# 1029  No Relation         Relation
# 1042  No Relation         Relation
# 1071  No Relation         Relation
# 1096  No Relation         Relation
# 1097  No Relation         Relation
# 1098  No Relation         Relation
# 1107  No Relation         Relation
# 1142  No Relation         Relation
# 1143  No Relation         Relation
# 1167  No Relation         Relation
# 1168  No Relation         Relation
# 1169  No Relation         Relation
# 1178  No Relation         Relation
# 1226  No Relation         Relation
# 1234  No Relation         Relation
# 1241  No Relation         Relation
# 1242  No Relation         Relation
# 1260  No Relation         Relation
# 1261  No Relation         Relation

# %%
TN=Neg[Neg['label']==Neg['predict_relation1']]
TN

# %%
print(classification_report(relation_df['label'].tolist(), relation_df['predict_relation'].tolist()))
# Out:
#               precision    recall  f1-score   support
#
#  No Relation       0.99      0.96      0.98      1172
#     Relation       0.85      0.96      0.90       261
#
#     accuracy                           0.96      1433
#    macro avg       0.92      0.96      0.94      1433
# weighted avg       0.97      0.96      0.96      1433

# %%
print(classification_report(relation_df['label'].tolist(), relation_df['predict_relation'].tolist()))
# Out:
#               precision    recall  f1-score   support
#
#  No Relation       0.99      0.96      0.98      1172
#     Relation       0.85      0.96      0.90       261
#
#     accuracy                           0.96      1433
#    macro avg       0.92      0.96      0.94      1433
# weighted avg       0.97      0.96      0.96      1433
